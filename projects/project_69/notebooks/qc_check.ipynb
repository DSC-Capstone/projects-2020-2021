# %%
import os
import json
import glob
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# %%
def get_summary(group):
    summary = pd.DataFrame()
    samples = glob.glob(f"data/fastqc_results/{group}/unzipped/*")

    for sample in samples:
        with open(sample +"/summary.txt") as f:
            df = pd.read_csv(f, sep='\t', lineterminator='\n',header=None)

        filename = df[2].iloc[0]
        df.columns = [filename,'Sample','']
        df.index = df['Sample']
        df = df[filename].to_frame().transpose()

        summary = pd.concat([summary,df])
    return summary

# %%
esbl_summary = get_summary('esbl')
ctrl_summary = get_summary('ctrl')

# %%
esbl_summary.head()
# Out:
# Sample               Basic Statistics Per base sequence quality  \
# DRR242147_2.fastq.gz             PASS                      FAIL
# DRR242154_1.fastq.gz             PASS                      PASS
# DRR242157_2.fastq.gz             PASS                      FAIL
# DRR242158_2.fastq.gz             PASS                      FAIL
# DRR242167_2.fastq.gz             PASS                      FAIL
#
# Sample               Per sequence quality scores Per base sequence content  \
# DRR242147_2.fastq.gz                        PASS                      FAIL
# DRR242154_1.fastq.gz                        PASS                      FAIL
# DRR242157_2.fastq.gz                        PASS                      FAIL
# DRR242158_2.fastq.gz                        PASS                      FAIL
# DRR242167_2.fastq.gz                        PASS                      FAIL
#
# Sample               Per sequence GC content Per base N content  \
# DRR242147_2.fastq.gz                    WARN               PASS
# DRR242154_1.fastq.gz                    FAIL               PASS
# DRR242157_2.fastq.gz                    FAIL               PASS
# DRR242158_2.fastq.gz                    FAIL               PASS
# DRR242167_2.fastq.gz                    WARN               PASS
#
# Sample               Sequence Length Distribution Sequence Duplication Levels  \
# DRR242147_2.fastq.gz                         WARN                        PASS
# DRR242154_1.fastq.gz                         WARN                        PASS
# DRR242157_2.fastq.gz                         WARN                        PASS
# DRR242158_2.fastq.gz                         WARN                        PASS
# DRR242167_2.fastq.gz                         WARN                        PASS
#
# Sample               Overrepresented sequences Adapter Content Kmer Content
# DRR242147_2.fastq.gz                      WARN            PASS         WARN
# DRR242154_1.fastq.gz                      PASS            PASS         WARN
# DRR242157_2.fastq.gz                      PASS            PASS         WARN
# DRR242158_2.fastq.gz                      PASS            PASS         FAIL
# DRR242167_2.fastq.gz                      WARN            PASS         WARN

# %%
for col in esbl_summary.columns:
    plotdata = pd.DataFrame({
    "ESBL_Samples":esbl_summary[col].value_counts(),
    "CTRL_Samples":ctrl_summary[col].value_counts()},
    index = ['PASS','WARN','FAIL']
    )
    plotdata.plot(kind="bar")
    plt.title(col)
    plt.ylabel("Frequency")
    plt.xlabel("Flag")
    
plt.show()
