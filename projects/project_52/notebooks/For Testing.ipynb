# %%
import csv
import pandas as pd
import numpy as np
from pymongo import MongoClient
import requests
from bs4 import BeautifulSoup, Tag
import json

# %%
df = pd.read_csv('/Users/brian/Desktop/Rock-Climbing-Recommender/data/cleaned/climbs.csv')
df
# Out:
#        climb_id                       name  \
# 0     111004304                    The Jet
# 1     113689801                    Cupcake
# 2     107753089         Face, Ramp & Crack
# 3     110648065               Finger Crack
# 4     107753112        Wandering Albatross
# ...         ...                        ...
# 2113  105945535           Sacherer Cracker
# 2114  106284793             Short But Thin
# 2115  106410313        The Slack ( center)
# 2116  107032569            The Slack, Left
# 2117  107416757  West Buttress (pitch 1&2)
#
#                                             description  \
# 0      A cool small route with some big, dynamic moves.
# 1     The most obvious route up the small crag at Gl...
# 2     The route on the left at the H3 crag. Begin wi...
# 3     Steep finger crack - start off the ground isnt...
# 4     A super-fun and quality route with varied clim...
# ...                                                 ...
# 2113  One of the most classic pitches at its grade i...
# 2114  Sustained, technical, and thin. Creative footw...
# 2115  First or one of the first Yosemite free 5.11. ...
# 2116  This is a classic Chuck Pratt testpiece - a mu...
# 2117  So the West Buttress obviously isn't a "base r...
#
#                                               image_url   latitude  \
# 0     https://cdn2.apstatic.com/photos/climb/1110043...  37.985467
# 1     https://cdn2.apstatic.com/photos/climb/1136898...  37.729341
# 2     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# 3                                                   NaN  37.922100
# 4     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# ...                                                 ...        ...
# 2113  https://cdn2.apstatic.com/photos/climb/1076312...  37.730087
# 2114  https://cdn2.apstatic.com/photos/climb/1067710...  37.730087
# 2115  https://cdn2.apstatic.com/photos/climb/1189273...  37.730087
# 2116  https://cdn2.apstatic.com/photos/climb/1070326...  37.730087
# 2117                                                NaN  37.730087
#
#        longitude  avg_rating  num_ratings  \
# 0    -119.916808         3.0            3
# 1    -119.573661         1.0            2
# 2    -119.804456         2.5            6
# 3    -119.804456         2.0            1
# 4    -119.804456         2.7            3
# ...          ...         ...          ...
# 2113 -119.637863         3.9          248
# 2114 -119.637863         2.6           45
# 2115 -119.637863         2.7            9
# 2116 -119.637863         3.3            4
# 2117 -119.637863         3.5            8
#
#                                                     url       climb_type  \
# 0     https://www.mountainproject.com/route/11100430...      ['Boulder']
# 1     https://www.mountainproject.com/route/11368980...           ['TR']
# 2     https://www.mountainproject.com/route/10775308...           ['TR']
# 3     https://www.mountainproject.com/route/11064806...  ['Trad', ' TR']
# 4     https://www.mountainproject.com/route/10775311...  ['Trad', ' TR']
# ...                                                 ...              ...
# 2113  https://www.mountainproject.com/route/10594553...         ['Trad']
# 2114  https://www.mountainproject.com/route/10628479...         ['Trad']
# 2115  https://www.mountainproject.com/route/10641031...         ['Trad']
# 2116  https://www.mountainproject.com/route/10703256...         ['Trad']
# 2117  https://www.mountainproject.com/route/10741675...         ['Trad']
#
#       height_ft  height_m  pitches  grade  \
# 0           9.0       3.0      NaN    NaN
# 1          30.0       9.0      NaN    NaN
# 2          45.0      14.0      NaN    NaN
# 3          40.0      12.0      NaN    NaN
# 4          45.0      14.0      NaN    NaN
# ...         ...       ...      ...    ...
# 2113      150.0      45.0      NaN    NaN
# 2114       40.0      12.0      NaN    NaN
# 2115      400.0     121.0      4.0    NaN
# 2116      350.0     106.0      3.0    NaN
# 2117      300.0      91.0      2.0    NaN
#
#                                              protection  difficulty  \
# 0     Crash pad, as the ground next to the boulder i...          17
# 1     Easy walk to the top of the crag. Bring a long...           7
# 2     This route can also be led. Few protection opp...          11
# 3                          two bolt anchor - thin gear.          17
# 4     On toprope, there is big pendulum potential on...          13
# ...                                                 ...         ...
# 2113  Doubles to 3".  Most forego anything big for t...          13
# 2114  Fingers to micro-cams/nuts. Not often led as y...          18
# 2115  double from green Alien to #3. One each #4, #5...          16
# 2116           Pro to 6+ inches. Doubles from 2" to 5".          14
# 2117  Doubles from fingers to 2". A 6" piece protect...          13
#
#       rock_climb  boulder_climb
# 0              0              1
# 1              1              0
# 2              1              0
# 3              1              0
# 4              1              0
# ...          ...            ...
# 2113           1              0
# 2114           1              0
# 2115           1              0
# 2116           1              0
# 2117           1              0
#
# [2118 rows x 18 columns]

# %%
df.iloc[0].climb_type
# Out:
# "['Boulder']"

# %%
df[df['grade'].isna() == False]
# Out:
#        climb_id                             name  \
# 11    108178106    West Face of Mount Starr King
# 36    106042438                       Errett Out
# 45    114652887                        Side Dish
# 47    106498804                           Ursula
# 58    111312245                       High Times
# ...         ...                              ...
# 2044  106487486                Beggar's Buttress
# 2052  106669076                  Overhang Bypass
# 2057  112340396     Too Many Darts (Free Ascent)
# 2060  114237930                     Counterparts
# 2081  112178358  Mama (Free Voices of the Drown)
#
#                                             description  \
# 11    (old school beta)   At the base of the west fa...
# 36    This climb starts down and left of "Holdless H...
# 45    OK climbing; never a line; as a result, mossy ...
# 47    You will have plenty of time to think about th...
# 58    High Times starts on the far left side of Drug...
# ...                                                 ...
# 2044  Here's a bit more beta:    To find the route, ...
# 2052  A classic line up the western side of Lower Ca...
# 2057  A long free climb with only 2 semi-hard sectio...
# 2060  This seemingly neglected line is a quality 5 p...
# 2081  Mama is a truly wild climb. Come prepared for ...
#
#                                               image_url   latitude  \
# 11    https://cdn2.apstatic.com/photos/climb/1144567...  37.702707
# 36    https://cdn2.apstatic.com/photos/climb/1193313...  37.849422
# 45                                                  NaN  37.849422
# 47    https://cdn2.apstatic.com/photos/climb/1112072...  37.849422
# 58    https://cdn2.apstatic.com/photos/climb/1113149...  37.864607
# ...                                                 ...        ...
# 2044  https://cdn2.apstatic.com/photos/climb/1064897...  37.718427
# 2052  https://cdn2.apstatic.com/photos/climb/1118983...  37.718427
# 2057  https://cdn2.apstatic.com/photos/climb/1123408...  37.718427
# 2060                                                NaN  37.719322
# 2081  https://cdn2.apstatic.com/photos/climb/1121784...  37.716082
#
#        longitude  avg_rating  num_ratings  \
# 11   -119.517660         3.3            8
# 36   -119.431646         2.7           35
# 45   -119.431646         1.8            4
# 47   -119.431646         3.4            9
# 58   -119.422151         3.0            4
# ...          ...         ...          ...
# 2044 -119.646586         2.9           33
# 2052 -119.646586         3.0            9
# 2057 -119.646586         3.0            1
# 2060 -119.643388         3.0            1
# 2081 -119.647286         3.0            2
#
#                                                     url           climb_type  \
# 11    https://www.mountainproject.com/route/10817810...  ['Trad', ' Alpine']
# 36    https://www.mountainproject.com/route/10604243...            ['Sport']
# 45    https://www.mountainproject.com/route/11465288...             ['Trad']
# 47    https://www.mountainproject.com/route/10649880...             ['Trad']
# 58    https://www.mountainproject.com/route/11131224...             ['Trad']
# ...                                                 ...                  ...
# 2044  https://www.mountainproject.com/route/10648748...             ['Trad']
# 2052  https://www.mountainproject.com/route/10666907...             ['Trad']
# 2057  https://www.mountainproject.com/route/11234039...             ['Trad']
# 2060  https://www.mountainproject.com/route/11423793...            ['Sport']
# 2081  https://www.mountainproject.com/route/11217835...             ['Trad']
#
#       height_ft  height_m  pitches  grade  \
# 11          NaN       NaN      5.0    3.0
# 36        500.0     152.0      3.0    2.0
# 45        450.0     136.0      3.0    2.0
# 47        500.0     152.0      3.0    2.0
# 58        400.0     121.0      4.0    2.0
# ...         ...       ...      ...    ...
# 2044      700.0     212.0      9.0    2.0
# 2052      400.0     121.0      5.0    3.0
# 2057      780.0     236.0      7.0    3.0
# 2060      450.0     136.0      5.0    3.0
# 2081      700.0     212.0      9.0    4.0
#
#                                              protection  difficulty  \
# 11                                    Gear up to 1 inch          11
# 36                                   Draws, a few cams.          10
# 45         Modern rack; nuts, cams tiny to 4"; no bolts          11
# 47    Bring a light rack with a good selection of ge...          15
# 58    bring 10 + quick draws and slings   1 set of c...          26
# ...                                                 ...         ...
# 2044  singles from #00-#.5 doubles from #.75-2 Singl...          19
# 2052  Bring a standard rack of friends, stoppers, an...          10
# 2057  A rack of stoppers and cams from tiny to 4".  ...          17
# 2060                     All bolts. 14 draws is plenty.          27
# 2081  We took a set of nuts, doubles from .2-4 and a...          21
#
#       rock_climb  boulder_climb
# 11             1              0
# 36             1              0
# 45             1              0
# 47             1              0
# 58             1              0
# ...          ...            ...
# 2044           1              0
# 2052           1              0
# 2057           1              0
# 2060           1              0
# 2081           1              0
#
# [215 rows x 18 columns]

# %%
data = df.to_dict('records')
data
# Out:
# [{'climb_id': 111004304,
#   'name': 'The Jet',
#   'description': 'A cool small route with some big, dynamic moves.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/111004329_medium_1494337531.jpg',
#   'latitude': 37.98546707,
#   'longitude': -119.91680796,
#   'avg_rating': 3.0,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/111004304/the-jet',
#   'climb_type': "['Boulder']",
#   'height_ft': 9.0,
#   'height_m': 3.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Crash pad, as the ground next to the boulder is a bit steep',
#   'difficulty': 17,
#   'rock_climb': 0,
#   'boulder_climb': 1},
#  {'climb_id': 113689801,
#   'name': 'Cupcake',
#   'description': "The most obvious route up the small crag at Glacier Point.    Lowest third involves a bit of good footwork, then an easy scramble for the middle third, then the top bit is probably the crux and trickier than it looks.    The base is on the disabled trail to Glacier Point so be very careful not to obstruct it - however the trail is very wide at that point - easily wide enough for buggies with room left over for ropes and a belayer. It may be worth checking with the rangers in the gift shop that it's OK to do this, though a ranger was supportive of our efforts!    Suspect there are other routes up the same crag which could be done with a bit of tweaking of the same anchor.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/113689867_medium_1507613747.jpg',
#   'latitude': 37.72934089,
#   'longitude': -119.57366051,
#   'avg_rating': 1.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/113689801/cupcake',
#   'climb_type': "['TR']",
#   'height_ft': 30.0,
#   'height_m': 9.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Easy walk to the top of the crag. Bring a long static line to build an anchor from a tree (about 30 foot away) and a big obvious boulder.',
#   'difficulty': 7,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107753089,
#   'name': 'Face, Ramp & Crack',
#   'description': "The route on the left at the H3 crag. Begin with a few face moves to a fun mantel. After that, gain the obvious ramp on climber's left that leads up and right. A steep crack (hands, fists and a short wider section) with some face holds on the side awaits you and leads to the top.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107753109_medium_1494209211.jpg',
#   'latitude': 37.92210005,
#   'longitude': -119.80445567,
#   'avg_rating': 2.5,
#   'num_ratings': 6,
#   'url': 'https://www.mountainproject.com/route/107753089/face-ramp-crack',
#   'climb_type': "['TR']",
#   'height_ft': 45.0,
#   'height_m': 14.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'This route can also be led. Few protection opportunities in the beginning section and ramp (R), good protection in the 5.8 crack to finish. 2-5" cams.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 110648065,
#   'name': 'Finger Crack',
#   'description': "Steep finger crack - start off the ground isnt too bad with some bigger pockets you can really sink your fingers into but quickly steepens and feet become more precarious. Crux comes about 20 feet off the ground as the crack narrows to be tips only with little to say about feet. mantle out of this, then finish with some 'thank god' hand jams to the two-bolt anchor.",
#   'image_url': nan,
#   'latitude': 37.92210005,
#   'longitude': -119.80445567,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/110648065/finger-crack',
#   'climb_type': "['Trad', ' TR']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'two bolt anchor - thin gear.',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107753112,
#   'name': 'Wandering Albatross',
#   'description': 'A super-fun and quality route with varied climbing that makes the most of the short wall by wandering left and right! You will use face climbing, possibly a mantel, fingerlocks/ringlocks, awesome handjams and fists. Start on the large flake near the middle of the wall and work your way on it via a strenuous mantel or a long reach up and left. The lip on the flake is intermittent, so work out your sequence! Then follow the finger crack above to where it meets a horizontal crack. Another finger crack continues up, slightly further right - you gain that with a semi-blind reach. Follow the new finger crack till it meets a horizontal hand crack above. Now make a long traverse right with your hands in a sumptious hand crack (a little dirty, but good) and good feet. You will meet a short, vertical hand crack directly below the anchor, which widens near the top.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107753121_medium_1494209213.jpg',
#   'latitude': 37.92210005,
#   'longitude': -119.80445567,
#   'avg_rating': 2.7,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/107753112/wandering-albatross',
#   'climb_type': "['Trad', ' TR']",
#   'height_ft': 45.0,
#   'height_m': 14.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'On toprope, there is big pendulum potential on this route. The swing is "clean", but could be unnerving for some. If there are two of you, get your belayer to pay out a bunch of slack if you swing out to dampen the swing. If there are more than two, tie into the middle of the rope and set up a second belay with your rope end off to the left to stop the swing.    If leading, bring protection between 0.5"-3".',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119513779,
#   'name': 'Resurrection',
#   'description': nan,
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119514527_medium_1599489330.jpg',
#   'latitude': 37.96476865,
#   'longitude': -119.75488663,
#   'avg_rating': 4.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/119513779/resurrection',
#   'climb_type': "['Trad']",
#   'height_ft': 1800.0,
#   'height_m': 545.0,
#   'pitches': 17.0,
#   'grade': nan,
#   'protection': nan,
#   'difficulty': 23,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107751556,
#   'name': 'Camp Mather',
#   'description': 'Start on the step and follow the easiest route up. This is well to the right hand side of the broad arete, and a few feet right of where your toprope will be hanging. This warmup route features jugs, mantels and crimps.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107751575_medium_1494209091.jpg',
#   'latitude': 37.90397806,
#   'longitude': -119.83459415,
#   'avg_rating': 1.8,
#   'num_ratings': 6,
#   'url': 'https://www.mountainproject.com/route/107751556/camp-mather',
#   'climb_type': "['TR']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '2 bolts on top for anchoring. Walk-off.',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107751576,
#   'name': 'Variation',
#   'description': 'A number of variations exist to the left of Camp Mather. Pick your route according to the desired difficulty. An obvious variation is a lieback start followed by the face to the left of the broad arete once you have joined Camp Mather about half way up at the ledge.',
#   'image_url': nan,
#   'latitude': 37.90397806,
#   'longitude': -119.83459415,
#   'avg_rating': 1.7,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/107751576/variation',
#   'climb_type': "['TR']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Two bolts on top for anchoring. Walk-off.',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 118812991,
#   'name': 'Spliter handcrack',
#   'description': 'Thin hands to full hands at the top, negotiate the arete on the left and top out. A great place to learn hand jams close to the ground.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/118813002_medium_1588271764.jpg',
#   'latitude': 37.88227825,
#   'longitude': -119.86102258,
#   'avg_rating': 3.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/118812991/spliter-handcrack',
#   'climb_type': "['Boulder']",
#   'height_ft': 14.0,
#   'height_m': 4.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pads',
#   'difficulty': 12,
#   'rock_climb': 0,
#   'boulder_climb': 1},
#  {'climb_id': 108167876,
#   'name': "Amy's 5.3",
#   'description': "If you find yourself in the Illilouette looking for a nice moderate line, without time for a multipitch push up Starr King, this is just the thing.     A slabby left-facing dihedral has a series of cracks  at its back. Hop on, it's better than it looks from the ground! We thought it might go at 5.7 if cleaned up, but did 5.8ish moves to avoid loose blocks and vegetation. It takes a repertoire of moderate climbing moves to top out, very fun.     If you know of a prior history of this line  let me know and I'l update the description. I would be surprised to find nobody had climbed it yet, but for its long approach, and the fact most climbs recorded here are much more advanced than this.    Also check out the 30 foot vertical splitter hand crack, just right of the start of this one.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/108167953_medium_1494266997.jpg',
#   'latitude': 37.69999197,
#   'longitude': -119.53228411,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/108167876/amys-53',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 150.0,
#   'height_m': 45.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Trad rack.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 108165000,
#   'name': 'Southeast Face',
#   'description': 'Follow the path of least resistance - or whichever variation catches your eye - up two pitches, to where the summit can be approached by a class 3 scramble.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/108168362_medium_1494267016.jpg',
#   'latitude': 37.70270705,
#   'longitude': -119.51765953,
#   'avg_rating': 2.8,
#   'num_ratings': 17,
#   'url': 'https://www.mountainproject.com/route/108165000/southeast-face',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 350.0,
#   'height_m': 106.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'Standard rack. Not a lot of pro, but adequate and pretty typical of an alpine climb in the easy 5. range.',
#   'difficulty': 5,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 108178106,
#   'name': 'West Face of Mount Starr King',
#   'description': '(old school beta)   At the base of the west face are three prominent Jeffery pines and a bent lodge-pole pine just left of them. Rope up at the lodge-pole and follow a trough up and right to a belay bolt. Traverse right (5.8), then climb up and right to a very brush ledge. Continue up and right for about 200 feet, then traverse right 30 feet and climb straight up past loose flakes to a ledge. Proceed upward over more flakes and a few small overhangs for 300 feet to ledge on lower angle rock. And easy pitch ends at the summit slabs.     (modern beta from mtnyoung on supertopo)   Pitch 1: (5.6) Look for three pine trees grouped close to the base of The West Face of Mt. Starr King. Begin at the north-most of these trees (this north-most tree\x92s trunk forks partway up.) Follow a shallow, left facing corner/trough about 100 feet to an 18 inch wide roof (which is heavily marked by yellow lichen.) Good protection under the roof is followed by 25 feet of unprotected 5.6 slab, up and slightly left, ending at a two bolt belay on a lower angle section of face. (This pitch might be as long as 150 feet, depending on where a party ropes up.)    Pitch 2: (5.8) Traverse straight right for 25 feet to a right facing corner/flake (5.8). Go up and right along, and then over this. Continue toward a large bush which is on top of a thin ledge. Pass below the bush, moving onto the ledge just to its right. Belay 20 feet further up and right. (About 160 feet)    Pitch 3: (5.6) Unprotected 5.6 leads up and right 25 feet to the base of a prominent left facing corner. This \x93spreads out\x94 to become multiple corners higher. Belay not far above where the corners spread out. (140 feet)    Pitch 4: (5.8) Traverse left 30 feet across the tops of flakes and ledges to a single bolt. Three more well spaced bolts protect climbing straight up on a beautiful, golden slab to a point directly under a wide flake/roof. From the fourth bolt, move left five feet to a right facing corner (at a point where that right facing corner meets the roof.) Fun moves lead over the roof, then up and left 15 feet, to an excellent belay ledge. (150 feet)    Pitch 5: (5.8) Follow right facing corners upward, being careful to trend to the right, even though, in some places, leftward movement appears easier. Look for the best, most solid, crack system in which to belay. (170 feet, plus or minus)    Pitch 6: (5.5) Climb right and up a little, staying below blank and dirty sections of rock and roofs. After moving right, around a corner/roof, an up-and-left crack continues 50 feet; it starts at hand size and narrows to finger size. Belay on top of flakes above and right of the end of this crack. (170 feet)    Pitch 7: (5.0) Eighty more feet of easy flakes and face leads to the end of the climbing. Two hundred fifty feet more of class 3 and class 2 lead to the summit.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/114456738_medium_1528404142.jpg',
#   'latitude': 37.70270705,
#   'longitude': -119.51765953,
#   'avg_rating': 3.3,
#   'num_ratings': 8,
#   'url': 'https://www.mountainproject.com/route/108178106/west-face-of-mount-starr-king',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': nan,
#   'height_m': nan,
#   'pitches': 5.0,
#   'grade': 3.0,
#   'protection': 'Gear up to 1 inch',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 111866548,
#   'name': 'Northwest Arete',
#   'description': "A beautiful, sweeping, and exposed arete on solid & featured rock. I can't say I've done many Cl.4 routes in the Sierra that have old pitons and rap stations on route...",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/114602094_medium_1531852151.jpg',
#   'latitude': 37.6963101,
#   'longitude': -119.42857361,
#   'avg_rating': 3.3,
#   'num_ratings': 4,
#   'url': 'https://www.mountainproject.com/route/111866548/northwest-arete',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 1500.0,
#   'height_m': 455.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': "Solo, or bring a light rack and rope if you aren't comfortable on 4th+/easy 5th class.",
#   'difficulty': 1,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 109191270,
#   'name': 'Fuel Rod',
#   'description': 'Game on, rated 10b in an older guide and now rated 10d in the new guides, the bouldery crux of this route still felt hard for the rating. Clipping the second bolt will keep your attention but not as much as clipping the poorly placed 3rd bolt. The climbing remains sustained to the anchor and calling it 10 easy is misleading. A hand size optional piece in the older guide and small optional pro suggested in the Supertopo guide is only recommended if you like carrying extra weight. You could place a hand size piece before the anchor that might hold body weight but would send rock down on your belayer as it ripped out in the event of a fall. You might also get a smaller piece to the left that could hold a fall but you would be blocking what I felt was a crucial undercling hold. While fairly well bolted by TM standards this sport route constantly felt sporty.',
#   'image_url': nan,
#   'latitude': 37.84527246,
#   'longitude': -119.44647703,
#   'avg_rating': 2.6,
#   'num_ratings': 7,
#   'url': 'https://www.mountainproject.com/route/109191270/fuel-rod',
#   'climb_type': "['Sport']",
#   'height_ft': 75.0,
#   'height_m': 23.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '5 bolts and 2 closed shuts for an anchor. Also you can get good gear off the ground for a belay anchor to prevent going off the ledge in case the leader falls before clipping the first bolt(recommended).',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106482674,
#   'name': 'High Heels',
#   'description': "Not your typical Tuolumne climb.  If you're tired of running it out on glassy slabs and sketchy knobs go get on this thing.  This 20ft roof is super fun and pros up well.  A nice change from de rigueur of Tuolumne.    Was on the cover of the old Tuolumne guide.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119426183_medium_1598124459.jpg',
#   'latitude': 37.84527246,
#   'longitude': -119.44647703,
#   'avg_rating': 3.3,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/106482674/high-heels',
#   'climb_type': "['Trad']",
#   'height_ft': 35.0,
#   'height_m': 11.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'A few finger and hand size.  Bolts at the belay maybe sketchy.',
#   'difficulty': 22,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119426294,
#   'name': 'Public Enemy',
#   'description': nan,
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119426306_medium_1598125567.jpg',
#   'latitude': 37.84527246,
#   'longitude': -119.44647703,
#   'avg_rating': 3.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/119426294/public-enemy',
#   'climb_type': "['Sport']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '5 quickdraws plus 2 for the anchor.  Lower/rap off rings.',
#   'difficulty': 20,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106208624,
#   'name': 'Biscuit and Gravy',
#   'description': 'Tough start. Spotter recommended.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106830807_medium_1494144021.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.0,
#   'num_ratings': 28,
#   'url': 'https://www.mountainproject.com/route/106208624/biscuit-and-gravy',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 155.0,
#   'height_m': 47.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Mixed (Bolts and Gear)',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106486577,
#   'name': 'Black Diamond',
#   'description': '  This run-out route has an \x93R\x94 rating that denotes the likelihood of serious injury in the event of a fall; so it\x92s perhaps best to top-rope this climb after leading Wild in the Streaks just to the left. ',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110885733_medium_1494357433.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.3,
#   'num_ratings': 16,
#   'url': 'https://www.mountainproject.com/route/106486577/black-diamond',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 165.0,
#   'height_m': 50.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Widely (and perhaps not ideally) spaced bolts.   Shares bolted anchor with Wild in the Streaks',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106852893,
#   'name': 'Black Uhuru',
#   'description': 'Fun two-pitch slab climb up a black streak on knobs.  Recently updated with modern bolts.  Trad bolting may feel runout to new leaders.    First pitch: 2 bolts and 2" piece, 100\' to gear belay    Second pitch: 4 bolts, 160\' to two-bolt anchor with rap rings    Descent: Rappel the route to the main Bunny Slopes ledge.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106852902_medium_1494145703.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.2,
#   'num_ratings': 10,
#   'url': 'https://www.mountainproject.com/route/106852893/black-uhuru',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 260.0,
#   'height_m': 79.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': '1-3" cams for first belay, 4 quickdraws',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106852912,
#   'name': 'Hit or Miss',
#   'description': "Fun slab climb with newly-updated bolts.  Trad bolting may feel runout to new leaders.    First pitch: 0.5 camalot and 4 bolts, 165', 5.7    Second pitch: 2 bolts and 0.5 camalot, 160', 5.6    Both belays are at bolted anchors with rap rings.    Descent: Rappel the route.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110885468_medium_1494357421.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 1.6,
#   'num_ratings': 5,
#   'url': 'https://www.mountainproject.com/route/106852912/hit-or-miss',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 325.0,
#   'height_m': 98.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'single 0.5 camalot needed on both pitches, 4 quickdraws',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106208618,
#   'name': 'Hot Crossed Buns',
#   'description': 'Some long run outs on easy ground.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/108130267_medium_1494264750.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.0,
#   'num_ratings': 40,
#   'url': 'https://www.mountainproject.com/route/106208618/hot-crossed-buns',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 155.0,
#   'height_m': 47.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Mixed (Bolts and Gear)',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106222436,
#   'name': 'Mere Image',
#   'description': 'Face climb near a dike;  first on the right side of the dike and up over a steep black face, then cross back to the left to clip a bolt.  Follow the dike (or just left of it) up to an anchor & rappel.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110776724_medium_1494353812.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.4,
#   'num_ratings': 20,
#   'url': 'https://www.mountainproject.com/route/106222436/mere-image',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 130.0,
#   'height_m': 39.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Bolts (far enough apart to make it scary, not so far as to make it truly dangerous)',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107746818,
#   'name': 'Raindance',
#   'description': 'Knobby, slab climb. Good TR after climbing Mere Image.',
#   'image_url': nan,
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 1.5,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/107746818/raindance',
#   'climb_type': "['Sport', ' Alpine']",
#   'height_ft': 135.0,
#   'height_m': 41.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Bolt',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106208614,
#   'name': 'Wild in the Streaks',
#   'description': 'Thin start. Eases as you gain altitude.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/118899691_medium_1589949980.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.1,
#   'num_ratings': 28,
#   'url': 'https://www.mountainproject.com/route/106208614/wild-in-the-streaks',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 165.0,
#   'height_m': 50.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '5 bolts, bolted anchor',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106244996,
#   'name': 'Apex Predator',
#   'description': 'The crux is pulling the steep overhanging (ever so slightly) head wall while pulling on small vertical crimps.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/109336291_medium_1494347021.jpg',
#   'latitude': 37.84449214,
#   'longitude': -119.44701602,
#   'avg_rating': 2.7,
#   'num_ratings': 7,
#   'url': 'https://www.mountainproject.com/route/106244996/apex-predator',
#   'climb_type': "['Sport']",
#   'height_ft': 65.0,
#   'height_m': 20.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'The guide book says there are 6 bolts they are high quality Fixe anchors so no worries here in case you were to peel...',
#   'difficulty': 18,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106244914,
#   'name': 'Joe Mamba',
#   'description': 'The crux comes at the top as you pull the short but steep headwall to gain the ledge. The Falcon guide book shows 4 bolts, however the first one has since been chopped leaving a spicy (yet easy) climb to the 1st bolt',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106244920_medium_1494091119.jpg',
#   'latitude': 37.84449214,
#   'longitude': -119.44701602,
#   'avg_rating': 3.0,
#   'num_ratings': 8,
#   'url': 'https://www.mountainproject.com/route/106244914/joe-mamba',
#   'climb_type': "['Sport']",
#   'height_ft': 65.0,
#   'height_m': 20.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '3 bolts, no bolted anchors easy to setup anchors at the top though.',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106244986,
#   'name': 'Rodeo Revolution',
#   'description': 'The reason I gave this a bomb is that I would not want anyone to come here thinking they could do a nice 5.7 crack. It is filled with moss (at least from close inspection on the ground) and the pro looks sparse and questionable.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106245054_medium_1494091132.jpg',
#   'latitude': 37.84449214,
#   'longitude': -119.44701602,
#   'avg_rating': 1.3,
#   'num_ratings': 6,
#   'url': 'https://www.mountainproject.com/route/106244986/rodeo-revolution',
#   'climb_type': "['Trad']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Big (think #4 camalots and up) there might be some spots for smaller gear but it appeared to be full of moss',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 111207113,
#   'name': 'Angelic Upstart',
#   'description': 'Great face climbing on gold polish.   11A crux starts the third pitch, consistant 5.10 moves between every bolt.   Be aware the second pitch has a variation to the left called "Claim Jumper", it is 5.12.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/111207125_medium_1494342964.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/111207113/angelic-upstart',
#   'climb_type': "['Trad']",
#   'height_ft': 350.0,
#   'height_m': 106.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Mostly protected by bolts, bring some stoppers and small cams.  Some traversing too.   Tops out at the same spot as the top of Ursula.',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 113846498,
#   'name': 'Avocados and Tequila',
#   'description': 'To the left side of the Ripple boulder there is a small ledge.  Start there, put in a piece at the crack near the start of the dike and go up a bit to the first bolt (5.8R). Clip another bolt and continue straight up.  You can get another piece in the left facing feature before you get to bolt #3.  Continue up nice face climbing with another 5.8ish move at bolt #4.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 1.8,
#   'num_ratings': 4,
#   'url': 'https://www.mountainproject.com/route/113846498/avocados-and-tequila',
#   'climb_type': "['Trad']",
#   'height_ft': 150.0,
#   'height_m': 45.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '6 bolts to anchors, with a couple of pieces of gear in the 1-2" size.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106042441,
#   'name': 'Bit by Bit',
#   'description': 'This route starts to the Right of "Errett Out".   Climb a pitch past seven bolts to a two bolt anchor.   The second pitch leads past nine bolts to a two bolt anchor.   Rappel (two 60-meter ropes).',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106570455_medium_1494121336.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.7,
#   'num_ratings': 23,
#   'url': 'https://www.mountainproject.com/route/106042441/bit-by-bit',
#   'climb_type': "['Sport']",
#   'height_ft': nan,
#   'height_m': nan,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'Draws.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106510747,
#   'name': 'Bull Dozier',
#   'description': "Right leaning crack starts off ledge about 30' up   Climb 5.6 friction (no pro) straight up to slightly right-leaning crack [or it looks like a corner system just to the left is protectable - then traverse right].   First pitch - good pro & moves to sloping ledge - 195' 5.7   2nd & 3rd pitches As per J. Albers (from comments)   The first pitch belay is actually in a scoop about 30 feet below the bolts you mentioned, though using the bolts is fine as long as nobody is using them for the face climb they are there for.   The second pitch continues up the crack past a bulge (bring a 4 inch piece for the bulge) and up the nice hand crack to a another scoop to belay...maybe 120-130 feet from the bolts.   Third pitch continues until the crack ends and you are on 4th class, belay where you can. You can then climb out on 4th class from this belay, though many will want a belay for the last bit of 4th class to the top of the dome (it is exposed). Enjoyable climb.   Cheers.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106892243_medium_1494148939.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.8,
#   'num_ratings': 112,
#   'url': 'https://www.mountainproject.com/route/106510747/bull-dozier',
#   'climb_type': "['Trad']",
#   'height_ft': 400.0,
#   'height_m': 121.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Standard trad rack   Mostly finger to hand sizes',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106510756,
#   'name': 'Cheeseburgers  and Beer',
#   'description': "Left side of Dozier Dome @ black streak   Climb straight up through bolt-protected face (crux is about 50' up); pass some horizontals with supplemental pro.  make obvious trend to the right (join Scandalous Summer) at top to avoid chossy/lichen-covered rock   Belay/ 2-rope rapell from tree on ledge  ",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110856313_medium_1494355929.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.1,
#   'num_ratings': 48,
#   'url': 'https://www.mountainproject.com/route/106510756/cheeseburgers-and-beer',
#   'climb_type': "['Trad']",
#   'height_ft': 190.0,
#   'height_m': 58.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Several bolts (6 or 7)   Supplement with small to 2" gear',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106849248,
#   'name': 'Cheetos and Everclear',
#   'description': 'Start at the large white dike. Follow dike (fun easy moves) for 4 bolts then step right and head up nice thin face for 5 more bolts. Fun, balancy moves. About 180 feet from the ground (belay in the shade) or around 130 feet from the terrace (belay with the view).',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107232485_medium_1494175062.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.8,
#   'num_ratings': 31,
#   'url': 'https://www.mountainproject.com/route/106849248/cheetos-and-everclear',
#   'climb_type': "['Sport']",
#   'height_ft': 180.0,
#   'height_m': 55.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '9 draws, optional hand size piece and long sling to protect easy 5th crack. 2 bolts with rappel rings at top of climb.',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107124704,
#   'name': 'Dozier Dihedral',
#   'description': 'Dozier Dihedral is the right facing corner on the right side of Dozier Dome.  Layback and smear to a small roof.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 1.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/107124704/dozier-dihedral',
#   'climb_type': "['Trad']",
#   'height_ft': nan,
#   'height_m': nan,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Standard Rack, mostly small gear.',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 108256706,
#   'name': 'Dumpster Evangelist',
#   'description': 'Climb an easy, shallow right facing corner (gear needed) and then work left to bolts.  Climb up the nice knobby face.  This is a well bolted climb.  Crux is near the top.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.6,
#   'num_ratings': 13,
#   'url': 'https://www.mountainproject.com/route/108256706/dumpster-evangelist',
#   'climb_type': "['Trad']",
#   'height_ft': 115.0,
#   'height_m': 35.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': "Bolts.  Gear needed for the first 15 feet or so (yellow alien to #2 camalot sizes roughly).  A 70 meter rope works to lower the climber.  2 ropes are needed to get back to the ground from Blitzo's Balcony.",
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 108304345,
#   'name': 'Errett By Bit',
#   'description': "This seems to be the combo favored by most, linking up the better parts of Errett Out and Bit By Bit.    P1 coincides mostly with P1 of Errett Out, passing its low two-bolt anchor at 70 ft and continuing up the bolted face to the second-to-last bolt.  At that point, instead of heading up to the last bolt of that pitch, veer up and right onto a right-slanting ramp to connect to the P1 bolted anchor of Bit By Bit.    P2 goes up the entire P2 of Bit By Bit to that pitch's bolted rap anchor.  Either rap here, or continue up the 5.8 P3 of Bit By Bit (which is indicated as P3 of Loud & Obnoxious here on MP) to another bolted rap anchor.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/111357958_medium_1494348996.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.2,
#   'num_ratings': 62,
#   'url': 'https://www.mountainproject.com/route/108304345/errett-by-bit',
#   'climb_type': "['Trad']",
#   'height_ft': 260.0,
#   'height_m': 79.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'Bolts mostly, single rack to 1.5", bolted rap anchors.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106042438,
#   'name': 'Errett Out',
#   'description': 'This climb starts down and left of "Holdless Horror" and just left of a group of trees.    Climb a low angle slab, past one bolt and past a horizontal crack and seven more bolts to a two bolt belay.    Climb a 5.7 pitch past seven bolts to a two bolt anchor.    A 5.6 pitch leads past three bolts.    Rappel or walk off.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119331354_medium_1596597943.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.7,
#   'num_ratings': 35,
#   'url': 'https://www.mountainproject.com/route/106042438/errett-out',
#   'climb_type': "['Sport']",
#   'height_ft': 500.0,
#   'height_m': 152.0,
#   'pitches': 3.0,
#   'grade': 2.0,
#   'protection': 'Draws, a few cams.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107764132,
#   'name': 'Felsic',
#   'description': 'Roughly follows a left leaning dike up the face. Shares the first 4 bolts with "Cheetos and Everclear". Sustained at the 5.8/5.9 level. Mostly small knobs, some friction, and a couple of hand crack moves.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107764166_medium_1494210007.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.0,
#   'num_ratings': 34,
#   'url': 'https://www.mountainproject.com/route/107764132/felsic',
#   'climb_type': "['Sport']",
#   'height_ft': 160.0,
#   'height_m': 48.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '11 draws. Two bolts with chains. Optional small hand sized cam can be placed in the crack half way up where the bolts are a "little" wider spaced. 1-2" cams for the belay at the ledge.',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106014323,
#   'name': 'Holdless Horror',
#   'description': 'P1:  Start on the face just right of the bush growing out of the bottom of the crack.  Climb up to first horizontal ledge, or, further up to the next smaller one (80 or 100 feet?) and build a belay anchor.  5.6.   P2:  The "business" pitch.  Climb up and mitigate impending horror by using the "holdless" terrain rather than get engulfed in the people eatin\', imposing crack.  Busy, but, never hard and the pro is decent if you take the time to find the money spots.  5.7.   P3:  The fun 5.6 pitch.  Great climbing that gets steep and improbable looking, but, always a nice foot and/or hand hold to help you out.   P4:  Final easy fifth class romp to the top.  Can climb far enough up to set belay for a safe walk off following the pitch.  Low angle, one short roof near the end of the pitch.  Great gear, but, somewhat spread out between bomber placements.    Historically significant as the first technical rock climbing route on this Dome.  Great name, too.  Classic TMH.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/112011291_medium_1494316236.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.0,
#   'num_ratings': 193,
#   'url': 'https://www.mountainproject.com/route/106014323/holdless-horror',
#   'climb_type': "['Trad']",
#   'height_ft': 550.0,
#   'height_m': 167.0,
#   'pitches': 4.0,
#   'grade': nan,
#   'protection': 'Standard rack.  Nuts and single set of cams from small (1 TCU) to a #4 camalot.  No fixed gear.  No anchors.',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106556570,
#   'name': 'Isostacy',
#   'description': 'Beautiful rock with a great mix of face and crack climbing.  Second pitch requires some careful route finding for the easiest path. There is a bit of R-rated climbing, but the gear is there and the stances to place it from are comfortable.     50 feet of 4th class to a ledge. Gear anchor.    Climb a right trending ramp to an obvious downward pointing roof/flake, get gear, then pull onto the flake and face climb up and left to another right facing flake which takes gear.  Climb up and left to another, smaller right facing flake that takes a small cam and then go a ways up and left to a subtle right trending ramp in the area with the brightest white rock (a bit of small gear here). Follow the right trending ramp up and back right to the first bolt. Climb up past three more bolts to a double bolt anchor with chains.     The crux is well protected with bolts, but you do need to climb some 5.7R between gear placements before the bolts.  Excellent climbing. 160-170 feet.    Face climb up and right for 40 feet, aiming for a hand crack.  You can get some gear before the crack, but you need to use runners. This part is a bit run out, but very easy climbing, maybe 5.4.  Follow the pretty 5.6 hand crack to a two bolt anchor with chains. Full 200 feet.     Climb straight up from the belay over bulges past 3 bolts to a two bolt anchor with chains. 60 feet. ',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106904875_medium_1494150037.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.9,
#   'num_ratings': 56,
#   'url': 'https://www.mountainproject.com/route/106556570/isostacy',
#   'climb_type': "['Trad']",
#   'height_ft': 470.0,
#   'height_m': 142.0,
#   'pitches': 4.0,
#   'grade': nan,
#   'protection': 'Standard trad rack including nuts and small cams to 2 inches. Long runners for the somewhat wandering 2nd pitch and the start of the 3rd pitch.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107709957,
#   'name': 'Loud and Obnoxious',
#   'description': "This is the next route right of Bit By Bit. The first pitch starts up a 4th class slab to some flakes. There's optional gear placements here. Then a steep section of very tightly bolted knob climbing. Above the angle lessens and you cruise over to a bolted anchor. The next pitch climbs up to another anchor below the right side of an arching roof. Pitch 3 turns the roof and then it's easy 5th class to the final anchor. Rapping the route is the quickest way down, or you can walk off to the right.    This modern sport climb was bolted over the top of an old R/X route.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107709985_medium_1494206452.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.6,
#   'num_ratings': 20,
#   'url': 'https://www.mountainproject.com/route/107709957/loud-and-obnoxious',
#   'climb_type': "['Sport']",
#   'height_ft': 500.0,
#   'height_m': 152.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Bolts, optional 2" gear getting to the first bolt.',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107709974,
#   'name': 'Plutonics',
#   'description': 'This takes a line of strength up the blank section of wall between Holdless Horror and Bull Dozier. The first pitch is long and has many bolts. The difficulties gradually lessen as you work your way up the face. There is a bolted anchor just before a large ledge, or you can take a seat on the big ledge (no anchor) to belay. The second pitch climbs past a few bolts on easy terrain to another anchor. One more pitch of 4th class leads to the top.    Rap the route or walk off right.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.7,
#   'num_ratings': 15,
#   'url': 'https://www.mountainproject.com/route/107709974/plutonics',
#   'climb_type': "['Sport']",
#   'height_ft': 500.0,
#   'height_m': 152.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Bolts',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 108210693,
#   'name': 'Read Between the Lines',
#   'description': 'Fun toprope that shares the same anchor as "You, Me and the Dike". A slabby start leads to a good ledge, then climb knobby face to beautiful golden granite (crux). Thin incut edges can be found for you fingertips but it is mostly your feet that are doing the work. The route eases in difficulty if you go further to the right as there are more face features. Climb straight up to the anchor for the best value.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.0,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/108210693/read-between-the-lines',
#   'climb_type': "['TR']",
#   'height_ft': 180.0,
#   'height_m': 55.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'None, toprope only',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 107261451,
#   'name': 'Ripple',
#   'description': "Pitch 1 (5.7, 140'): 4 bolts + gear to bolted belay.    Pitch 2 (5.7, 180'): 6 bolts + gear to bolted belay (bit of a runout on easy terrain without gear). ",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107261457_medium_1494177039.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.6,
#   'num_ratings': 23,
#   'url': 'https://www.mountainproject.com/route/107261451/ripple',
#   'climb_type': "['Trad']",
#   'height_ft': 320.0,
#   'height_m': 97.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': '6 draws, cams from 0.6 to 1.25".',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 105870872,
#   'name': 'Scandalous Summer',
#   'description': 'A fun, easy climb at the far left of the wall.    Climb low angle knobs past bolts to a ledge with trees.     Crux is after the last bolt.    Rappel.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.3,
#   'num_ratings': 41,
#   'url': 'https://www.mountainproject.com/route/105870872/scandalous-summer',
#   'climb_type': "['Trad']",
#   'height_ft': 190.0,
#   'height_m': 58.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Draws.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 114652887,
#   'name': 'Side Dish',
#   'description': 'OK climbing; never a line; as a result, mossy character relative to its neighbors.The crux is a little like the start to West Crack on DAFF, but the holds are a little larger and the runout a little longer. There is some gear on the way to the start of the crack; offset cams and green alien/smaller are handy. The Reid/Falkenstein book shows this route connecting back to Holdless Horror, but it goes to the top if you want to take it there. Expect a little runout in a runnel. The obvious corner exit is highly vegetated; we took the crack system to its left. Walk off as for Holdless etc.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 1.8,
#   'num_ratings': 4,
#   'url': 'https://www.mountainproject.com/route/114652887/side-dish',
#   'climb_type': "['Trad']",
#   'height_ft': 450.0,
#   'height_m': 136.0,
#   'pitches': 3.0,
#   'grade': 2.0,
#   'protection': 'Modern rack; nuts, cams tiny to 4"; no bolts',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 108256698,
#   'name': "Tourette's",
#   'description': 'Cool knob climb that is very well bolted.  Mantle up past the first bolt, climb through a small roof, and work left to the nice knobby face.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/114421335_medium_1527597848.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.9,
#   'num_ratings': 19,
#   'url': 'https://www.mountainproject.com/route/108256698/tourettes',
#   'climb_type': "['Trad']",
#   'height_ft': 110.0,
#   'height_m': 33.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': "Bolts.  Bolted anchor at the top.  A 70 meter rope needed to lower.  2 ropes are necessary to get back to the ground from Blitzo's Balcony.",
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 106498804,
#   'name': 'Ursula',
#   'description': 'You will have plenty of time to think about the differences between PG and R on this excellent classic three pitch face route with lots of variety.    Pitch 1 runout up the very easy smooth apron to a right leaning, right facing thin dihedral with pretty good gear until it ends at a steep face with a horizontal crack.  Great cams can be found in this horizontal 3 feet either right or left to replace the missing pin, but you will have to work for it.  Make the wild crux mantle to clip a welcome bolt.  Golden edges and a mantle past 2 more bolts then make a wild thin traverse left to another horizontal and a bolted belay.  5.10c PG 50 meters.    Pitch 2 easy traverse 10 feet right to a thin 5.9 dihedral with good gear to horizontals.  Move left past a loose flake.  Further left and up past 2 bolts with great knobs 5.9+ to a 0.75" cam under a flake, wild face climbing to the right up the flake to a bolted belay 5.10-. 30 meters.    Pitch 3 starts left then goes right on unbelievable thin face and knobs past 7 bolts.  Most of the time will be spent making 5.10 moves with a bolt below your feet.  Finish up and right to a thin dihedral.  Gear belay here.  5.10b PG 50 meters.    Scramble 4th class to the top about 20 meters.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/111207250_medium_1494342965.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.4,
#   'num_ratings': 9,
#   'url': 'https://www.mountainproject.com/route/106498804/ursula',
#   'climb_type': "['Trad']",
#   'height_ft': 500.0,
#   'height_m': 152.0,
#   'pitches': 3.0,
#   'grade': 2.0,
#   'protection': 'Bring a light rack with a good selection of gear from thin nuts, TCU\'s to 2-1/2" cams.  I found an extra 0.5" to 2" cams particularly useful on the first pitch that has a bolted belay.  Pitch 2 has 2 bolts with plenty of supplemental gear, bolted belay.  Pitch 3 has 7 bolts and ends at a gear belay 0.5"-1.0" cams.    Rebolted by ASCA 2002 so all the bolts are new and shinny.  Long slings and double ropes help on this wandering route.',
#   'difficulty': 15,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 105870876,
#   'name': 'White Lie',
#   'description': 'To the right of "Scandalous Summer", climb past 6 bolts to a big ledge.',
#   'image_url': nan,
# ...
#   'boulder_climb': 0},
#  {'climb_id': 105860646,
#   'name': 'S Chimney',
#   'description': 'This route follows the prominent S-shaped chiminey, for two pitches.   Walk off to the right.',
#   'image_url': nan,
#   'latitude': 37.9163032,
#   'longitude': -119.42291422,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105860646/s-chimney',
#   'climb_type': "['Trad']",
#   'height_ft': nan,
#   'height_m': nan,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Cams and stoppers.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 105902964,
#   'name': 'Barefoot Bumpkin',
#   'description': '1. 5.8, climb up polished face (crux) to reach the bottom of the dihedral.   2. 5.6\\7, Follow the dihedral to the top.',
#   'image_url': nan,
#   'latitude': 37.91081774,
#   'longitude': -119.42044385,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105902964/barefoot-bumpkin',
#   'climb_type': "['Trad']",
#   'height_ft': 200.0,
#   'height_m': 61.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'Standard trad rack',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 105902968,
#   'name': 'Deep Space',
#   'description': "1. Follow the lower, left water streak past 4 bolts (crux) to a ledge and follow the ledge right to its end at a shallow corner (small gear belay).   2. Follow the upper, right water steak to the summit past one bolt. Don't expect to find much pro but the climbing gets easier as you go.",
#   'image_url': nan,
#   'latitude': 37.91081774,
#   'longitude': -119.42044385,
#   'avg_rating': 3.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105902968/deep-space',
#   'climb_type': "['Trad']",
#   'height_ft': 300.0,
#   'height_m': 91.0,
#   'pitches': 2.0,
#   'grade': 2.0,
#   'protection': "Draws, small tcu's and stoppers.",
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 105902973,
#   'name': 'Voyager',
#   'description': 'Incredible thin-edge face climbing on very hard gold-colored glacial-polished rock.    1. 5.10b/c. Climb up over a small roof (#2 cam) and to a small ledge above. Place a TCU and move left on face to a bolt, then follow a line of bolts straight up the water streak to a 3-bolt belay. Cruxes will be encountered under the final two protection bolts.    2. 5.8. Climb a long stretch straight up to a bolt, then another long stretch to another bolt somewhat to the left at a steeper and very gold-polished section. Then do the 5.8 crux, and with a little devious route finding, you can keep the grade at 5.8 to the top.',
#   'image_url': nan,
#   'latitude': 37.91081774,
#   'longitude': -119.42044385,
#   'avg_rating': 4.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105902973/voyager',
#   'climb_type': "['Trad']",
#   'height_ft': 300.0,
#   'height_m': 91.0,
#   'pitches': 2.0,
#   'grade': 2.0,
#   'protection': 'Small cams to 2 inch and draws. This is NOT a sport climb.',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 105902961,
#   'name': 'Weeping Moon',
#   'description': '1. 5.10a, follow unprotected face for miles past a single bolt to a small ledge on a shallow left facing half-moon shaped feature that has a water streak running out of the bottom.   2. 5.8, follow more uprotected face for miles to the top.    Good Luck',
#   'image_url': nan,
#   'latitude': 37.91081774,
#   'longitude': -119.42044385,
#   'avg_rating': 4.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105902961/weeping-moon',
#   'climb_type': "['Trad']",
#   'height_ft': 300.0,
#   'height_m': 91.0,
#   'pitches': 2.0,
#   'grade': 2.0,
#   'protection': 'No protection data',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119789986,
#   'name': 'Sheep Thrills',
#   'description': nan,
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119776166_medium_1603149990.jpg',
#   'latitude': 37.97787667,
#   'longitude': -119.33833784,
#   'avg_rating': 3.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119789986/sheep-thrills',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 700.0,
#   'height_m': 212.0,
#   'pitches': 5.0,
#   'grade': 3.0,
#   'protection': 'No protection data',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016203,
#   'name': 'A Boy and His Dog',
#   'description': 'Face climb through multiple cruxes to a two bolt anchor.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016203/a-boy-and-his-dog',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016038,
#   'name': 'Big Business',
#   'description': 'Wide crack in the corner..',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016038/big-business',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011421,
#   'name': 'Big Gulp',
#   'description': 'The crux is down low, just above the first bolt.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011421/big-gulp',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011588,
#   'name': 'Charge Card',
#   'description': 'Chimney with the crux about halfway up.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011588/charge-card',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016118,
#   'name': 'Cole Burner',
#   'description': 'From the left side of the ledge, face climb past bolts, run it out to the crack and follow it up and right to the top.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016118/cole-burner',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches and long slings',
#   'difficulty': 21,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016278,
#   'name': 'Discount Crack',
#   'description': 'Nice hand crack.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016278/discount-crack',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016093,
#   'name': 'Fat Boys',
#   'description': 'Nice traversing hand crack.\xa0 Start on the left side of the ledge and jam up and right to a belay on a ledge.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016093/fat-boys',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches.',
#   'difficulty': 15,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011566,
#   'name': "Grant's Gulch",
#   'description': 'A wide crack in the back of a corner.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 0.5,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/119011566/grants-gulch',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011576,
#   'name': 'Jiffy Pop',
#   'description': 'Beautiful rock!',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011576/jiffy-pop',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016071,
#   'name': 'Le Papillon',
#   'description': 'A sport route up outstanding rock.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016071/le-papillon',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016178,
#   'name': "Man's Best Friend",
#   'description': 'Follow bolts to a two bolt anchor.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016178/mans-best-friend',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 16,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011542,
#   'name': 'One Size Fits All',
#   'description': 'Nice hand crack. \xa0Crux protected by a bolt.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011542/one-size-fits-all',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016140,
#   'name': 'Party Bowl',
#   'description': 'Use the crack from the ledge and exit the left side of the roof.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016140/party-bowl',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches',
#   'difficulty': 23,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016151,
#   'name': 'Perhaps Another Bowl?',
#   'description': 'Use the crack off the ledge and exit the right side of the roof.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119016230_medium_1591805791.jpg',
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016151/perhaps-another-bowl',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches',
#   'difficulty': 24,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011476,
#   'name': 'Pit Stop',
#   'description': 'Face climb past three bolts.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011476/pit-stop',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 15,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011449,
#   'name': 'Quick Stop',
#   'description': 'Nice hand crack in a corner. \xa0Crux is near the top.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011449/quick-stop',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches.',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119011462,
#   'name': 'Two For the Price of One',
#   'description': 'Face climb up a black streak past two bolts.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011462/two-for-the-price-of-one',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119016306,
#   'name': 'Wages of Sin',
#   'description': 'Old school sport climb to an anchor.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016306/wages-of-sin',
#   'climb_type': "['Sport', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 16,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119020674,
#   'name': "Becky's Corner",
#   'description': 'Nice crack in a corner.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020674/beckys-corner',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119020816,
#   'name': 'Blue Moon',
#   'description': 'Short sport climb with a few bolts to a two bolt anchor.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020816/blue-moon',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 21,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119020736,
#   'name': 'Grand Slam',
#   'description': 'Hard face moves down low and a crack up above.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020736/grand-slam',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches and quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'climb_id': 119020657,
#   'name': 'Pop Fly',
#   'description': 'Several bolts with a runout crux.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020657/pop-fly',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  ...]

# %%
client = MongoClient('mongodb+srv://DSC102:coliniscool@cluster0.4gstr.mongodb.net/MountainProject?retryWrites=true&w=majority&ssl=true&ssl_cert_reqs=CERT_NONE')
climbs = client.MountainProject.climbs

# %%
climbs.remove()
# Out:
# <ipython-input-31-29495965a937>:1: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   climbs.remove()
# {'n': 2118,
#  'opTime': {'ts': Timestamp(1613970691, 2118), 't': 30},
#  'electionId': ObjectId('7fffffff000000000000001e'),
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1613970691, 2118),
#   'signature': {'hash': b"\xdcJ\xe2\xd3\xea\xb9\x81ML\xc8\xe2\x88\xe1\x9e\xf02'\xd4`x",
#    'keyId': 6868680148380549122}},
#  'operationTime': Timestamp(1613970691, 2118)}

# %%
for entry in data:
    climbs.replace_one(entry, entry, upsert=True)

# %%
climbs.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7e3a384de99a> in <module>
# ----> 1 climbs.update_many(data, {"$setOnInsert": {}}, upsert=True)
#
# ~/Desktop/Rock-Climbing-Recommender/env/lib/python3.9/site-packages/pymongo/collection.py in update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, hint, session)
#    1087         .. versionadded:: 3.0
#    1088         """
# -> 1089         common.validate_is_mapping("filter", filter)
#    1090         common.validate_ok_for_update(update)
#    1091         common.validate_list_or_none('array_filters', array_filters)
#
# ~/Desktop/Rock-Climbing-Recommender/env/lib/python3.9/site-packages/pymongo/common.py in validate_is_mapping(option, value)
#     492     """Validate the type of method arguments that expect a document."""
#     493     if not isinstance(value, abc.Mapping):
# --> 494         raise TypeError("%s must be an instance of dict, bson.son.SON, or "
#     495                         "any other type that inherits from "
#     496                         "collections.Mapping" % (option,))
#
# TypeError: filter must be an instance of dict, bson.son.SON, or any other type that inherits from collections.Mapping

# %%
list(climbs.find())
# Out:
# [{'_id': ObjectId('60333d0894953fda34a260f1'),
#   'climb_id': 111004304,
#   'name': 'The Jet',
#   'description': 'A cool small route with some big, dynamic moves.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/111004329_medium_1494337531.jpg',
#   'latitude': 37.98546707,
#   'longitude': -119.91680796,
#   'avg_rating': 3.0,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/111004304/the-jet',
#   'climb_type': "['Boulder']",
#   'height_ft': 9.0,
#   'height_m': 3.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Crash pad, as the ground next to the boulder is a bit steep',
#   'difficulty': 17,
#   'rock_climb': 0,
#   'boulder_climb': 1},
#  {'_id': ObjectId('60333d0894953fda34a260f2'),
#   'climb_id': 113689801,
#   'name': 'Cupcake',
#   'description': "The most obvious route up the small crag at Glacier Point.    Lowest third involves a bit of good footwork, then an easy scramble for the middle third, then the top bit is probably the crux and trickier than it looks.    The base is on the disabled trail to Glacier Point so be very careful not to obstruct it - however the trail is very wide at that point - easily wide enough for buggies with room left over for ropes and a belayer. It may be worth checking with the rangers in the gift shop that it's OK to do this, though a ranger was supportive of our efforts!    Suspect there are other routes up the same crag which could be done with a bit of tweaking of the same anchor.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/113689867_medium_1507613747.jpg',
#   'latitude': 37.72934089,
#   'longitude': -119.57366051,
#   'avg_rating': 1.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/113689801/cupcake',
#   'climb_type': "['TR']",
#   'height_ft': 30.0,
#   'height_m': 9.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Easy walk to the top of the crag. Bring a long static line to build an anchor from a tree (about 30 foot away) and a big obvious boulder.',
#   'difficulty': 7,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260f3'),
#   'climb_id': 107753089,
#   'name': 'Face, Ramp & Crack',
#   'description': "The route on the left at the H3 crag. Begin with a few face moves to a fun mantel. After that, gain the obvious ramp on climber's left that leads up and right. A steep crack (hands, fists and a short wider section) with some face holds on the side awaits you and leads to the top.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107753109_medium_1494209211.jpg',
#   'latitude': 37.92210005,
#   'longitude': -119.80445567,
#   'avg_rating': 2.5,
#   'num_ratings': 6,
#   'url': 'https://www.mountainproject.com/route/107753089/face-ramp-crack',
#   'climb_type': "['TR']",
#   'height_ft': 45.0,
#   'height_m': 14.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'This route can also be led. Few protection opportunities in the beginning section and ramp (R), good protection in the 5.8 crack to finish. 2-5" cams.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260f4'),
#   'climb_id': 110648065,
#   'name': 'Finger Crack',
#   'description': "Steep finger crack - start off the ground isnt too bad with some bigger pockets you can really sink your fingers into but quickly steepens and feet become more precarious. Crux comes about 20 feet off the ground as the crack narrows to be tips only with little to say about feet. mantle out of this, then finish with some 'thank god' hand jams to the two-bolt anchor.",
#   'image_url': nan,
#   'latitude': 37.92210005,
#   'longitude': -119.80445567,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/110648065/finger-crack',
#   'climb_type': "['Trad', ' TR']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'two bolt anchor - thin gear.',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260f5'),
#   'climb_id': 107753112,
#   'name': 'Wandering Albatross',
#   'description': 'A super-fun and quality route with varied climbing that makes the most of the short wall by wandering left and right! You will use face climbing, possibly a mantel, fingerlocks/ringlocks, awesome handjams and fists. Start on the large flake near the middle of the wall and work your way on it via a strenuous mantel or a long reach up and left. The lip on the flake is intermittent, so work out your sequence! Then follow the finger crack above to where it meets a horizontal crack. Another finger crack continues up, slightly further right - you gain that with a semi-blind reach. Follow the new finger crack till it meets a horizontal hand crack above. Now make a long traverse right with your hands in a sumptious hand crack (a little dirty, but good) and good feet. You will meet a short, vertical hand crack directly below the anchor, which widens near the top.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107753121_medium_1494209213.jpg',
#   'latitude': 37.92210005,
#   'longitude': -119.80445567,
#   'avg_rating': 2.7,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/107753112/wandering-albatross',
#   'climb_type': "['Trad', ' TR']",
#   'height_ft': 45.0,
#   'height_m': 14.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'On toprope, there is big pendulum potential on this route. The swing is "clean", but could be unnerving for some. If there are two of you, get your belayer to pay out a bunch of slack if you swing out to dampen the swing. If there are more than two, tie into the middle of the rope and set up a second belay with your rope end off to the left to stop the swing.    If leading, bring protection between 0.5"-3".',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260f6'),
#   'climb_id': 119513779,
#   'name': 'Resurrection',
#   'description': nan,
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119514527_medium_1599489330.jpg',
#   'latitude': 37.96476865,
#   'longitude': -119.75488663,
#   'avg_rating': 4.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/119513779/resurrection',
#   'climb_type': "['Trad']",
#   'height_ft': 1800.0,
#   'height_m': 545.0,
#   'pitches': 17.0,
#   'grade': nan,
#   'protection': nan,
#   'difficulty': 23,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260f7'),
#   'climb_id': 107751556,
#   'name': 'Camp Mather',
#   'description': 'Start on the step and follow the easiest route up. This is well to the right hand side of the broad arete, and a few feet right of where your toprope will be hanging. This warmup route features jugs, mantels and crimps.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107751575_medium_1494209091.jpg',
#   'latitude': 37.90397806,
#   'longitude': -119.83459415,
#   'avg_rating': 1.8,
#   'num_ratings': 6,
#   'url': 'https://www.mountainproject.com/route/107751556/camp-mather',
#   'climb_type': "['TR']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '2 bolts on top for anchoring. Walk-off.',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260f8'),
#   'climb_id': 107751576,
#   'name': 'Variation',
#   'description': 'A number of variations exist to the left of Camp Mather. Pick your route according to the desired difficulty. An obvious variation is a lieback start followed by the face to the left of the broad arete once you have joined Camp Mather about half way up at the ledge.',
#   'image_url': nan,
#   'latitude': 37.90397806,
#   'longitude': -119.83459415,
#   'avg_rating': 1.7,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/107751576/variation',
#   'climb_type': "['TR']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Two bolts on top for anchoring. Walk-off.',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260f9'),
#   'climb_id': 118812991,
#   'name': 'Spliter handcrack',
#   'description': 'Thin hands to full hands at the top, negotiate the arete on the left and top out. A great place to learn hand jams close to the ground.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/118813002_medium_1588271764.jpg',
#   'latitude': 37.88227825,
#   'longitude': -119.86102258,
#   'avg_rating': 3.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/118812991/spliter-handcrack',
#   'climb_type': "['Boulder']",
#   'height_ft': 14.0,
#   'height_m': 4.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pads',
#   'difficulty': 12,
#   'rock_climb': 0,
#   'boulder_climb': 1},
#  {'_id': ObjectId('60333d0894953fda34a260fa'),
#   'climb_id': 108167876,
#   'name': "Amy's 5.3",
#   'description': "If you find yourself in the Illilouette looking for a nice moderate line, without time for a multipitch push up Starr King, this is just the thing.     A slabby left-facing dihedral has a series of cracks  at its back. Hop on, it's better than it looks from the ground! We thought it might go at 5.7 if cleaned up, but did 5.8ish moves to avoid loose blocks and vegetation. It takes a repertoire of moderate climbing moves to top out, very fun.     If you know of a prior history of this line  let me know and I'l update the description. I would be surprised to find nobody had climbed it yet, but for its long approach, and the fact most climbs recorded here are much more advanced than this.    Also check out the 30 foot vertical splitter hand crack, just right of the start of this one.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/108167953_medium_1494266997.jpg',
#   'latitude': 37.69999197,
#   'longitude': -119.53228411,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/108167876/amys-53',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 150.0,
#   'height_m': 45.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Trad rack.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260fb'),
#   'climb_id': 108165000,
#   'name': 'Southeast Face',
#   'description': 'Follow the path of least resistance - or whichever variation catches your eye - up two pitches, to where the summit can be approached by a class 3 scramble.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/108168362_medium_1494267016.jpg',
#   'latitude': 37.70270705,
#   'longitude': -119.51765953,
#   'avg_rating': 2.8,
#   'num_ratings': 17,
#   'url': 'https://www.mountainproject.com/route/108165000/southeast-face',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 350.0,
#   'height_m': 106.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'Standard rack. Not a lot of pro, but adequate and pretty typical of an alpine climb in the easy 5. range.',
#   'difficulty': 5,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260fc'),
#   'climb_id': 108178106,
#   'name': 'West Face of Mount Starr King',
#   'description': '(old school beta)   At the base of the west face are three prominent Jeffery pines and a bent lodge-pole pine just left of them. Rope up at the lodge-pole and follow a trough up and right to a belay bolt. Traverse right (5.8), then climb up and right to a very brush ledge. Continue up and right for about 200 feet, then traverse right 30 feet and climb straight up past loose flakes to a ledge. Proceed upward over more flakes and a few small overhangs for 300 feet to ledge on lower angle rock. And easy pitch ends at the summit slabs.     (modern beta from mtnyoung on supertopo)   Pitch 1: (5.6) Look for three pine trees grouped close to the base of The West Face of Mt. Starr King. Begin at the north-most of these trees (this north-most tree\x92s trunk forks partway up.) Follow a shallow, left facing corner/trough about 100 feet to an 18 inch wide roof (which is heavily marked by yellow lichen.) Good protection under the roof is followed by 25 feet of unprotected 5.6 slab, up and slightly left, ending at a two bolt belay on a lower angle section of face. (This pitch might be as long as 150 feet, depending on where a party ropes up.)    Pitch 2: (5.8) Traverse straight right for 25 feet to a right facing corner/flake (5.8). Go up and right along, and then over this. Continue toward a large bush which is on top of a thin ledge. Pass below the bush, moving onto the ledge just to its right. Belay 20 feet further up and right. (About 160 feet)    Pitch 3: (5.6) Unprotected 5.6 leads up and right 25 feet to the base of a prominent left facing corner. This \x93spreads out\x94 to become multiple corners higher. Belay not far above where the corners spread out. (140 feet)    Pitch 4: (5.8) Traverse left 30 feet across the tops of flakes and ledges to a single bolt. Three more well spaced bolts protect climbing straight up on a beautiful, golden slab to a point directly under a wide flake/roof. From the fourth bolt, move left five feet to a right facing corner (at a point where that right facing corner meets the roof.) Fun moves lead over the roof, then up and left 15 feet, to an excellent belay ledge. (150 feet)    Pitch 5: (5.8) Follow right facing corners upward, being careful to trend to the right, even though, in some places, leftward movement appears easier. Look for the best, most solid, crack system in which to belay. (170 feet, plus or minus)    Pitch 6: (5.5) Climb right and up a little, staying below blank and dirty sections of rock and roofs. After moving right, around a corner/roof, an up-and-left crack continues 50 feet; it starts at hand size and narrows to finger size. Belay on top of flakes above and right of the end of this crack. (170 feet)    Pitch 7: (5.0) Eighty more feet of easy flakes and face leads to the end of the climbing. Two hundred fifty feet more of class 3 and class 2 lead to the summit.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/114456738_medium_1528404142.jpg',
#   'latitude': 37.70270705,
#   'longitude': -119.51765953,
#   'avg_rating': 3.3,
#   'num_ratings': 8,
#   'url': 'https://www.mountainproject.com/route/108178106/west-face-of-mount-starr-king',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': nan,
#   'height_m': nan,
#   'pitches': 5.0,
#   'grade': 3.0,
#   'protection': 'Gear up to 1 inch',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260fd'),
#   'climb_id': 111866548,
#   'name': 'Northwest Arete',
#   'description': "A beautiful, sweeping, and exposed arete on solid & featured rock. I can't say I've done many Cl.4 routes in the Sierra that have old pitons and rap stations on route...",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/114602094_medium_1531852151.jpg',
#   'latitude': 37.6963101,
#   'longitude': -119.42857361,
#   'avg_rating': 3.3,
#   'num_ratings': 4,
#   'url': 'https://www.mountainproject.com/route/111866548/northwest-arete',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 1500.0,
#   'height_m': 455.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': "Solo, or bring a light rack and rope if you aren't comfortable on 4th+/easy 5th class.",
#   'difficulty': 1,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260fe'),
#   'climb_id': 109191270,
#   'name': 'Fuel Rod',
#   'description': 'Game on, rated 10b in an older guide and now rated 10d in the new guides, the bouldery crux of this route still felt hard for the rating. Clipping the second bolt will keep your attention but not as much as clipping the poorly placed 3rd bolt. The climbing remains sustained to the anchor and calling it 10 easy is misleading. A hand size optional piece in the older guide and small optional pro suggested in the Supertopo guide is only recommended if you like carrying extra weight. You could place a hand size piece before the anchor that might hold body weight but would send rock down on your belayer as it ripped out in the event of a fall. You might also get a smaller piece to the left that could hold a fall but you would be blocking what I felt was a crucial undercling hold. While fairly well bolted by TM standards this sport route constantly felt sporty.',
#   'image_url': nan,
#   'latitude': 37.84527246,
#   'longitude': -119.44647703,
#   'avg_rating': 2.6,
#   'num_ratings': 7,
#   'url': 'https://www.mountainproject.com/route/109191270/fuel-rod',
#   'climb_type': "['Sport']",
#   'height_ft': 75.0,
#   'height_m': 23.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '5 bolts and 2 closed shuts for an anchor. Also you can get good gear off the ground for a belay anchor to prevent going off the ledge in case the leader falls before clipping the first bolt(recommended).',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a260ff'),
#   'climb_id': 106482674,
#   'name': 'High Heels',
#   'description': "Not your typical Tuolumne climb.  If you're tired of running it out on glassy slabs and sketchy knobs go get on this thing.  This 20ft roof is super fun and pros up well.  A nice change from de rigueur of Tuolumne.    Was on the cover of the old Tuolumne guide.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119426183_medium_1598124459.jpg',
#   'latitude': 37.84527246,
#   'longitude': -119.44647703,
#   'avg_rating': 3.3,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/106482674/high-heels',
#   'climb_type': "['Trad']",
#   'height_ft': 35.0,
#   'height_m': 11.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'A few finger and hand size.  Bolts at the belay maybe sketchy.',
#   'difficulty': 22,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26100'),
#   'climb_id': 119426294,
#   'name': 'Public Enemy',
#   'description': nan,
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119426306_medium_1598125567.jpg',
#   'latitude': 37.84527246,
#   'longitude': -119.44647703,
#   'avg_rating': 3.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/119426294/public-enemy',
#   'climb_type': "['Sport']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '5 quickdraws plus 2 for the anchor.  Lower/rap off rings.',
#   'difficulty': 20,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26101'),
#   'climb_id': 106208624,
#   'name': 'Biscuit and Gravy',
#   'description': 'Tough start. Spotter recommended.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106830807_medium_1494144021.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.0,
#   'num_ratings': 28,
#   'url': 'https://www.mountainproject.com/route/106208624/biscuit-and-gravy',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 155.0,
#   'height_m': 47.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Mixed (Bolts and Gear)',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26102'),
#   'climb_id': 106486577,
#   'name': 'Black Diamond',
#   'description': '  This run-out route has an \x93R\x94 rating that denotes the likelihood of serious injury in the event of a fall; so it\x92s perhaps best to top-rope this climb after leading Wild in the Streaks just to the left. ',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110885733_medium_1494357433.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.3,
#   'num_ratings': 16,
#   'url': 'https://www.mountainproject.com/route/106486577/black-diamond',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 165.0,
#   'height_m': 50.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Widely (and perhaps not ideally) spaced bolts.   Shares bolted anchor with Wild in the Streaks',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26103'),
#   'climb_id': 106852893,
#   'name': 'Black Uhuru',
#   'description': 'Fun two-pitch slab climb up a black streak on knobs.  Recently updated with modern bolts.  Trad bolting may feel runout to new leaders.    First pitch: 2 bolts and 2" piece, 100\' to gear belay    Second pitch: 4 bolts, 160\' to two-bolt anchor with rap rings    Descent: Rappel the route to the main Bunny Slopes ledge.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106852902_medium_1494145703.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.2,
#   'num_ratings': 10,
#   'url': 'https://www.mountainproject.com/route/106852893/black-uhuru',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 260.0,
#   'height_m': 79.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': '1-3" cams for first belay, 4 quickdraws',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26104'),
#   'climb_id': 106852912,
#   'name': 'Hit or Miss',
#   'description': "Fun slab climb with newly-updated bolts.  Trad bolting may feel runout to new leaders.    First pitch: 0.5 camalot and 4 bolts, 165', 5.7    Second pitch: 2 bolts and 0.5 camalot, 160', 5.6    Both belays are at bolted anchors with rap rings.    Descent: Rappel the route.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110885468_medium_1494357421.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 1.6,
#   'num_ratings': 5,
#   'url': 'https://www.mountainproject.com/route/106852912/hit-or-miss',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 325.0,
#   'height_m': 98.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'single 0.5 camalot needed on both pitches, 4 quickdraws',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26105'),
#   'climb_id': 106208618,
#   'name': 'Hot Crossed Buns',
#   'description': 'Some long run outs on easy ground.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/108130267_medium_1494264750.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.0,
#   'num_ratings': 40,
#   'url': 'https://www.mountainproject.com/route/106208618/hot-crossed-buns',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 155.0,
#   'height_m': 47.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Mixed (Bolts and Gear)',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26106'),
#   'climb_id': 106222436,
#   'name': 'Mere Image',
#   'description': 'Face climb near a dike;  first on the right side of the dike and up over a steep black face, then cross back to the left to clip a bolt.  Follow the dike (or just left of it) up to an anchor & rappel.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110776724_medium_1494353812.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.4,
#   'num_ratings': 20,
#   'url': 'https://www.mountainproject.com/route/106222436/mere-image',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 130.0,
#   'height_m': 39.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Bolts (far enough apart to make it scary, not so far as to make it truly dangerous)',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26107'),
#   'climb_id': 107746818,
#   'name': 'Raindance',
#   'description': 'Knobby, slab climb. Good TR after climbing Mere Image.',
#   'image_url': nan,
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 1.5,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/107746818/raindance',
#   'climb_type': "['Sport', ' Alpine']",
#   'height_ft': 135.0,
#   'height_m': 41.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Bolt',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26108'),
#   'climb_id': 106208614,
#   'name': 'Wild in the Streaks',
#   'description': 'Thin start. Eases as you gain altitude.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/118899691_medium_1589949980.jpg',
#   'latitude': 37.84423676,
#   'longitude': -119.44760891,
#   'avg_rating': 2.1,
#   'num_ratings': 28,
#   'url': 'https://www.mountainproject.com/route/106208614/wild-in-the-streaks',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 165.0,
#   'height_m': 50.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '5 bolts, bolted anchor',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26109'),
#   'climb_id': 106244996,
#   'name': 'Apex Predator',
#   'description': 'The crux is pulling the steep overhanging (ever so slightly) head wall while pulling on small vertical crimps.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/109336291_medium_1494347021.jpg',
#   'latitude': 37.84449214,
#   'longitude': -119.44701602,
#   'avg_rating': 2.7,
#   'num_ratings': 7,
#   'url': 'https://www.mountainproject.com/route/106244996/apex-predator',
#   'climb_type': "['Sport']",
#   'height_ft': 65.0,
#   'height_m': 20.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'The guide book says there are 6 bolts they are high quality Fixe anchors so no worries here in case you were to peel...',
#   'difficulty': 18,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2610a'),
#   'climb_id': 106244914,
#   'name': 'Joe Mamba',
#   'description': 'The crux comes at the top as you pull the short but steep headwall to gain the ledge. The Falcon guide book shows 4 bolts, however the first one has since been chopped leaving a spicy (yet easy) climb to the 1st bolt',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106244920_medium_1494091119.jpg',
#   'latitude': 37.84449214,
#   'longitude': -119.44701602,
#   'avg_rating': 3.0,
#   'num_ratings': 8,
#   'url': 'https://www.mountainproject.com/route/106244914/joe-mamba',
#   'climb_type': "['Sport']",
#   'height_ft': 65.0,
#   'height_m': 20.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '3 bolts, no bolted anchors easy to setup anchors at the top though.',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2610b'),
#   'climb_id': 106244986,
#   'name': 'Rodeo Revolution',
#   'description': 'The reason I gave this a bomb is that I would not want anyone to come here thinking they could do a nice 5.7 crack. It is filled with moss (at least from close inspection on the ground) and the pro looks sparse and questionable.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106245054_medium_1494091132.jpg',
#   'latitude': 37.84449214,
#   'longitude': -119.44701602,
#   'avg_rating': 1.3,
#   'num_ratings': 6,
#   'url': 'https://www.mountainproject.com/route/106244986/rodeo-revolution',
#   'climb_type': "['Trad']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Big (think #4 camalots and up) there might be some spots for smaller gear but it appeared to be full of moss',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2610c'),
#   'climb_id': 111207113,
#   'name': 'Angelic Upstart',
#   'description': 'Great face climbing on gold polish.   11A crux starts the third pitch, consistant 5.10 moves between every bolt.   Be aware the second pitch has a variation to the left called "Claim Jumper", it is 5.12.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/111207125_medium_1494342964.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/111207113/angelic-upstart',
#   'climb_type': "['Trad']",
#   'height_ft': 350.0,
#   'height_m': 106.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Mostly protected by bolts, bring some stoppers and small cams.  Some traversing too.   Tops out at the same spot as the top of Ursula.',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2610d'),
#   'climb_id': 113846498,
#   'name': 'Avocados and Tequila',
#   'description': 'To the left side of the Ripple boulder there is a small ledge.  Start there, put in a piece at the crack near the start of the dike and go up a bit to the first bolt (5.8R). Clip another bolt and continue straight up.  You can get another piece in the left facing feature before you get to bolt #3.  Continue up nice face climbing with another 5.8ish move at bolt #4.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 1.8,
#   'num_ratings': 4,
#   'url': 'https://www.mountainproject.com/route/113846498/avocados-and-tequila',
#   'climb_type': "['Trad']",
#   'height_ft': 150.0,
#   'height_m': 45.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '6 bolts to anchors, with a couple of pieces of gear in the 1-2" size.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2610e'),
#   'climb_id': 106042441,
#   'name': 'Bit by Bit',
#   'description': 'This route starts to the Right of "Errett Out".   Climb a pitch past seven bolts to a two bolt anchor.   The second pitch leads past nine bolts to a two bolt anchor.   Rappel (two 60-meter ropes).',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106570455_medium_1494121336.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.7,
#   'num_ratings': 23,
#   'url': 'https://www.mountainproject.com/route/106042441/bit-by-bit',
#   'climb_type': "['Sport']",
#   'height_ft': nan,
#   'height_m': nan,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'Draws.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2610f'),
#   'climb_id': 106510747,
#   'name': 'Bull Dozier',
#   'description': "Right leaning crack starts off ledge about 30' up   Climb 5.6 friction (no pro) straight up to slightly right-leaning crack [or it looks like a corner system just to the left is protectable - then traverse right].   First pitch - good pro & moves to sloping ledge - 195' 5.7   2nd & 3rd pitches As per J. Albers (from comments)   The first pitch belay is actually in a scoop about 30 feet below the bolts you mentioned, though using the bolts is fine as long as nobody is using them for the face climb they are there for.   The second pitch continues up the crack past a bulge (bring a 4 inch piece for the bulge) and up the nice hand crack to a another scoop to belay...maybe 120-130 feet from the bolts.   Third pitch continues until the crack ends and you are on 4th class, belay where you can. You can then climb out on 4th class from this belay, though many will want a belay for the last bit of 4th class to the top of the dome (it is exposed). Enjoyable climb.   Cheers.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106892243_medium_1494148939.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.8,
#   'num_ratings': 112,
#   'url': 'https://www.mountainproject.com/route/106510747/bull-dozier',
#   'climb_type': "['Trad']",
#   'height_ft': 400.0,
#   'height_m': 121.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Standard trad rack   Mostly finger to hand sizes',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26110'),
#   'climb_id': 106510756,
#   'name': 'Cheeseburgers  and Beer',
#   'description': "Left side of Dozier Dome @ black streak   Climb straight up through bolt-protected face (crux is about 50' up); pass some horizontals with supplemental pro.  make obvious trend to the right (join Scandalous Summer) at top to avoid chossy/lichen-covered rock   Belay/ 2-rope rapell from tree on ledge  ",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/110856313_medium_1494355929.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.1,
#   'num_ratings': 48,
#   'url': 'https://www.mountainproject.com/route/106510756/cheeseburgers-and-beer',
#   'climb_type': "['Trad']",
#   'height_ft': 190.0,
#   'height_m': 58.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Several bolts (6 or 7)   Supplement with small to 2" gear',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26111'),
#   'climb_id': 106849248,
#   'name': 'Cheetos and Everclear',
#   'description': 'Start at the large white dike. Follow dike (fun easy moves) for 4 bolts then step right and head up nice thin face for 5 more bolts. Fun, balancy moves. About 180 feet from the ground (belay in the shade) or around 130 feet from the terrace (belay with the view).',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107232485_medium_1494175062.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.8,
#   'num_ratings': 31,
#   'url': 'https://www.mountainproject.com/route/106849248/cheetos-and-everclear',
#   'climb_type': "['Sport']",
#   'height_ft': 180.0,
#   'height_m': 55.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '9 draws, optional hand size piece and long sling to protect easy 5th crack. 2 bolts with rappel rings at top of climb.',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26112'),
#   'climb_id': 107124704,
#   'name': 'Dozier Dihedral',
#   'description': 'Dozier Dihedral is the right facing corner on the right side of Dozier Dome.  Layback and smear to a small roof.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 1.0,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/107124704/dozier-dihedral',
#   'climb_type': "['Trad']",
#   'height_ft': nan,
#   'height_m': nan,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Standard Rack, mostly small gear.',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26113'),
#   'climb_id': 108256706,
#   'name': 'Dumpster Evangelist',
#   'description': 'Climb an easy, shallow right facing corner (gear needed) and then work left to bolts.  Climb up the nice knobby face.  This is a well bolted climb.  Crux is near the top.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.6,
#   'num_ratings': 13,
#   'url': 'https://www.mountainproject.com/route/108256706/dumpster-evangelist',
#   'climb_type': "['Trad']",
#   'height_ft': 115.0,
#   'height_m': 35.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': "Bolts.  Gear needed for the first 15 feet or so (yellow alien to #2 camalot sizes roughly).  A 70 meter rope works to lower the climber.  2 ropes are needed to get back to the ground from Blitzo's Balcony.",
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26114'),
#   'climb_id': 108304345,
#   'name': 'Errett By Bit',
#   'description': "This seems to be the combo favored by most, linking up the better parts of Errett Out and Bit By Bit.    P1 coincides mostly with P1 of Errett Out, passing its low two-bolt anchor at 70 ft and continuing up the bolted face to the second-to-last bolt.  At that point, instead of heading up to the last bolt of that pitch, veer up and right onto a right-slanting ramp to connect to the P1 bolted anchor of Bit By Bit.    P2 goes up the entire P2 of Bit By Bit to that pitch's bolted rap anchor.  Either rap here, or continue up the 5.8 P3 of Bit By Bit (which is indicated as P3 of Loud & Obnoxious here on MP) to another bolted rap anchor.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/111357958_medium_1494348996.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.2,
#   'num_ratings': 62,
#   'url': 'https://www.mountainproject.com/route/108304345/errett-by-bit',
#   'climb_type': "['Trad']",
#   'height_ft': 260.0,
#   'height_m': 79.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': 'Bolts mostly, single rack to 1.5", bolted rap anchors.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26115'),
#   'climb_id': 106042438,
#   'name': 'Errett Out',
#   'description': 'This climb starts down and left of "Holdless Horror" and just left of a group of trees.    Climb a low angle slab, past one bolt and past a horizontal crack and seven more bolts to a two bolt belay.    Climb a 5.7 pitch past seven bolts to a two bolt anchor.    A 5.6 pitch leads past three bolts.    Rappel or walk off.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119331354_medium_1596597943.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.7,
#   'num_ratings': 35,
#   'url': 'https://www.mountainproject.com/route/106042438/errett-out',
#   'climb_type': "['Sport']",
#   'height_ft': 500.0,
#   'height_m': 152.0,
#   'pitches': 3.0,
#   'grade': 2.0,
#   'protection': 'Draws, a few cams.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26116'),
#   'climb_id': 107764132,
#   'name': 'Felsic',
#   'description': 'Roughly follows a left leaning dike up the face. Shares the first 4 bolts with "Cheetos and Everclear". Sustained at the 5.8/5.9 level. Mostly small knobs, some friction, and a couple of hand crack moves.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107764166_medium_1494210007.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.0,
#   'num_ratings': 34,
#   'url': 'https://www.mountainproject.com/route/107764132/felsic',
#   'climb_type': "['Sport']",
#   'height_ft': 160.0,
#   'height_m': 48.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': '11 draws. Two bolts with chains. Optional small hand sized cam can be placed in the crack half way up where the bolts are a "little" wider spaced. 1-2" cams for the belay at the ledge.',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26117'),
#   'climb_id': 106014323,
#   'name': 'Holdless Horror',
#   'description': 'P1:  Start on the face just right of the bush growing out of the bottom of the crack.  Climb up to first horizontal ledge, or, further up to the next smaller one (80 or 100 feet?) and build a belay anchor.  5.6.   P2:  The "business" pitch.  Climb up and mitigate impending horror by using the "holdless" terrain rather than get engulfed in the people eatin\', imposing crack.  Busy, but, never hard and the pro is decent if you take the time to find the money spots.  5.7.   P3:  The fun 5.6 pitch.  Great climbing that gets steep and improbable looking, but, always a nice foot and/or hand hold to help you out.   P4:  Final easy fifth class romp to the top.  Can climb far enough up to set belay for a safe walk off following the pitch.  Low angle, one short roof near the end of the pitch.  Great gear, but, somewhat spread out between bomber placements.    Historically significant as the first technical rock climbing route on this Dome.  Great name, too.  Classic TMH.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/112011291_medium_1494316236.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 3.0,
#   'num_ratings': 193,
#   'url': 'https://www.mountainproject.com/route/106014323/holdless-horror',
#   'climb_type': "['Trad']",
#   'height_ft': 550.0,
#   'height_m': 167.0,
#   'pitches': 4.0,
#   'grade': nan,
#   'protection': 'Standard rack.  Nuts and single set of cams from small (1 TCU) to a #4 camalot.  No fixed gear.  No anchors.',
#   'difficulty': 9,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26118'),
#   'climb_id': 106556570,
#   'name': 'Isostacy',
#   'description': 'Beautiful rock with a great mix of face and crack climbing.  Second pitch requires some careful route finding for the easiest path. There is a bit of R-rated climbing, but the gear is there and the stances to place it from are comfortable.     50 feet of 4th class to a ledge. Gear anchor.    Climb a right trending ramp to an obvious downward pointing roof/flake, get gear, then pull onto the flake and face climb up and left to another right facing flake which takes gear.  Climb up and left to another, smaller right facing flake that takes a small cam and then go a ways up and left to a subtle right trending ramp in the area with the brightest white rock (a bit of small gear here). Follow the right trending ramp up and back right to the first bolt. Climb up past three more bolts to a double bolt anchor with chains.     The crux is well protected with bolts, but you do need to climb some 5.7R between gear placements before the bolts.  Excellent climbing. 160-170 feet.    Face climb up and right for 40 feet, aiming for a hand crack.  You can get some gear before the crack, but you need to use runners. This part is a bit run out, but very easy climbing, maybe 5.4.  Follow the pretty 5.6 hand crack to a two bolt anchor with chains. Full 200 feet.     Climb straight up from the belay over bulges past 3 bolts to a two bolt anchor with chains. 60 feet. ',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/106904875_medium_1494150037.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.9,
#   'num_ratings': 56,
#   'url': 'https://www.mountainproject.com/route/106556570/isostacy',
#   'climb_type': "['Trad']",
#   'height_ft': 470.0,
#   'height_m': 142.0,
#   'pitches': 4.0,
#   'grade': nan,
#   'protection': 'Standard trad rack including nuts and small cams to 2 inches. Long runners for the somewhat wandering 2nd pitch and the start of the 3rd pitch.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26119'),
#   'climb_id': 107709957,
#   'name': 'Loud and Obnoxious',
#   'description': "This is the next route right of Bit By Bit. The first pitch starts up a 4th class slab to some flakes. There's optional gear placements here. Then a steep section of very tightly bolted knob climbing. Above the angle lessens and you cruise over to a bolted anchor. The next pitch climbs up to another anchor below the right side of an arching roof. Pitch 3 turns the roof and then it's easy 5th class to the final anchor. Rapping the route is the quickest way down, or you can walk off to the right.    This modern sport climb was bolted over the top of an old R/X route.",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107709985_medium_1494206452.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.6,
#   'num_ratings': 20,
#   'url': 'https://www.mountainproject.com/route/107709957/loud-and-obnoxious',
#   'climb_type': "['Sport']",
#   'height_ft': 500.0,
#   'height_m': 152.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Bolts, optional 2" gear getting to the first bolt.',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2611a'),
#   'climb_id': 107709974,
#   'name': 'Plutonics',
#   'description': 'This takes a line of strength up the blank section of wall between Holdless Horror and Bull Dozier. The first pitch is long and has many bolts. The difficulties gradually lessen as you work your way up the face. There is a bolted anchor just before a large ledge, or you can take a seat on the big ledge (no anchor) to belay. The second pitch climbs past a few bolts on easy terrain to another anchor. One more pitch of 4th class leads to the top.    Rap the route or walk off right.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.7,
#   'num_ratings': 15,
#   'url': 'https://www.mountainproject.com/route/107709974/plutonics',
#   'climb_type': "['Sport']",
#   'height_ft': 500.0,
#   'height_m': 152.0,
#   'pitches': 3.0,
#   'grade': nan,
#   'protection': 'Bolts',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2611b'),
#   'climb_id': 108210693,
#   'name': 'Read Between the Lines',
#   'description': 'Fun toprope that shares the same anchor as "You, Me and the Dike". A slabby start leads to a good ledge, then climb knobby face to beautiful golden granite (crux). Thin incut edges can be found for you fingertips but it is mostly your feet that are doing the work. The route eases in difficulty if you go further to the right as there are more face features. Climb straight up to the anchor for the best value.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.0,
#   'num_ratings': 3,
#   'url': 'https://www.mountainproject.com/route/108210693/read-between-the-lines',
#   'climb_type': "['TR']",
#   'height_ft': 180.0,
#   'height_m': 55.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'None, toprope only',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2611c'),
#   'climb_id': 107261451,
#   'name': 'Ripple',
#   'description': "Pitch 1 (5.7, 140'): 4 bolts + gear to bolted belay.    Pitch 2 (5.7, 180'): 6 bolts + gear to bolted belay (bit of a runout on easy terrain without gear). ",
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/107261457_medium_1494177039.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.6,
#   'num_ratings': 23,
#   'url': 'https://www.mountainproject.com/route/107261451/ripple',
#   'climb_type': "['Trad']",
#   'height_ft': 320.0,
#   'height_m': 97.0,
#   'pitches': 2.0,
#   'grade': nan,
#   'protection': '6 draws, cams from 0.6 to 1.25".',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2611d'),
#   'climb_id': 105870872,
#   'name': 'Scandalous Summer',
#   'description': 'A fun, easy climb at the far left of the wall.    Climb low angle knobs past bolts to a ledge with trees.     Crux is after the last bolt.    Rappel.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.3,
#   'num_ratings': 41,
#   'url': 'https://www.mountainproject.com/route/105870872/scandalous-summer',
#   'climb_type': "['Trad']",
#   'height_ft': 190.0,
#   'height_m': 58.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Draws.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2611e'),
#   'climb_id': 114652887,
#   'name': 'Side Dish',
#   'description': 'OK climbing; never a line; as a result, mossy character relative to its neighbors.The crux is a little like the start to West Crack on DAFF, but the holds are a little larger and the runout a little longer. There is some gear on the way to the start of the crack; offset cams and green alien/smaller are handy. The Reid/Falkenstein book shows this route connecting back to Holdless Horror, but it goes to the top if you want to take it there. Expect a little runout in a runnel. The obvious corner exit is highly vegetated; we took the crack system to its left. Walk off as for Holdless etc.',
#   'image_url': nan,
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 1.8,
#   'num_ratings': 4,
#   'url': 'https://www.mountainproject.com/route/114652887/side-dish',
#   'climb_type': "['Trad']",
#   'height_ft': 450.0,
#   'height_m': 136.0,
#   'pitches': 3.0,
#   'grade': 2.0,
#   'protection': 'Modern rack; nuts, cams tiny to 4"; no bolts',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a2611f'),
#   'climb_id': 108256698,
#   'name': "Tourette's",
#   'description': 'Cool knob climb that is very well bolted.  Mantle up past the first bolt, climb through a small roof, and work left to the nice knobby face.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/114421335_medium_1527597848.jpg',
#   'latitude': 37.84942217,
#   'longitude': -119.43164584,
#   'avg_rating': 2.9,
#   'num_ratings': 19,
#   'url': 'https://www.mountainproject.com/route/108256698/tourettes',
#   'climb_type': "['Trad']",
#   'height_ft': 110.0,
#   'height_m': 33.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': "Bolts.  Bolted anchor at the top.  A 70 meter rope needed to lower.  2 ropes are necessary to get back to the ground from Blitzo's Balcony.",
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a26120'),
#   'climb_id': 106498804,
#   'name': 'Ursula',
# ...
#   'climb_id': 105902968,
#   'name': 'Deep Space',
#   'description': "1. Follow the lower, left water streak past 4 bolts (crux) to a ledge and follow the ledge right to its end at a shallow corner (small gear belay).   2. Follow the upper, right water steak to the summit past one bolt. Don't expect to find much pro but the climbing gets easier as you go.",
#   'image_url': nan,
#   'latitude': 37.91081774,
#   'longitude': -119.42044385,
#   'avg_rating': 3.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105902968/deep-space',
#   'climb_type': "['Trad']",
#   'height_ft': 300.0,
#   'height_m': 91.0,
#   'pitches': 2.0,
#   'grade': 2.0,
#   'protection': "Draws, small tcu's and stoppers.",
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c0'),
#   'climb_id': 105902973,
#   'name': 'Voyager',
#   'description': 'Incredible thin-edge face climbing on very hard gold-colored glacial-polished rock.    1. 5.10b/c. Climb up over a small roof (#2 cam) and to a small ledge above. Place a TCU and move left on face to a bolt, then follow a line of bolts straight up the water streak to a 3-bolt belay. Cruxes will be encountered under the final two protection bolts.    2. 5.8. Climb a long stretch straight up to a bolt, then another long stretch to another bolt somewhat to the left at a steeper and very gold-polished section. Then do the 5.8 crux, and with a little devious route finding, you can keep the grade at 5.8 to the top.',
#   'image_url': nan,
#   'latitude': 37.91081774,
#   'longitude': -119.42044385,
#   'avg_rating': 4.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105902973/voyager',
#   'climb_type': "['Trad']",
#   'height_ft': 300.0,
#   'height_m': 91.0,
#   'pitches': 2.0,
#   'grade': 2.0,
#   'protection': 'Small cams to 2 inch and draws. This is NOT a sport climb.',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c1'),
#   'climb_id': 105902961,
#   'name': 'Weeping Moon',
#   'description': '1. 5.10a, follow unprotected face for miles past a single bolt to a small ledge on a shallow left facing half-moon shaped feature that has a water streak running out of the bottom.   2. 5.8, follow more uprotected face for miles to the top.    Good Luck',
#   'image_url': nan,
#   'latitude': 37.91081774,
#   'longitude': -119.42044385,
#   'avg_rating': 4.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/105902961/weeping-moon',
#   'climb_type': "['Trad']",
#   'height_ft': 300.0,
#   'height_m': 91.0,
#   'pitches': 2.0,
#   'grade': 2.0,
#   'protection': 'No protection data',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c2'),
#   'climb_id': 119789986,
#   'name': 'Sheep Thrills',
#   'description': nan,
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119776166_medium_1603149990.jpg',
#   'latitude': 37.97787667,
#   'longitude': -119.33833784,
#   'avg_rating': 3.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119789986/sheep-thrills',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 700.0,
#   'height_m': 212.0,
#   'pitches': 5.0,
#   'grade': 3.0,
#   'protection': 'No protection data',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c3'),
#   'climb_id': 119016203,
#   'name': 'A Boy and His Dog',
#   'description': 'Face climb through multiple cruxes to a two bolt anchor.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016203/a-boy-and-his-dog',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c4'),
#   'climb_id': 119016038,
#   'name': 'Big Business',
#   'description': 'Wide crack in the corner..',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016038/big-business',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c5'),
#   'climb_id': 119011421,
#   'name': 'Big Gulp',
#   'description': 'The crux is down low, just above the first bolt.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011421/big-gulp',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 17,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c6'),
#   'climb_id': 119011588,
#   'name': 'Charge Card',
#   'description': 'Chimney with the crux about halfway up.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011588/charge-card',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches.',
#   'difficulty': 11,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c7'),
#   'climb_id': 119016118,
#   'name': 'Cole Burner',
#   'description': 'From the left side of the ledge, face climb past bolts, run it out to the crack and follow it up and right to the top.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016118/cole-burner',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches and long slings',
#   'difficulty': 21,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c8'),
#   'climb_id': 119016278,
#   'name': 'Discount Crack',
#   'description': 'Nice hand crack.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016278/discount-crack',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264c9'),
#   'climb_id': 119016093,
#   'name': 'Fat Boys',
#   'description': 'Nice traversing hand crack.\xa0 Start on the left side of the ledge and jam up and right to a belay on a ledge.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016093/fat-boys',
#   'climb_type': "['Trad', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches.',
#   'difficulty': 15,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264ca'),
#   'climb_id': 119011566,
#   'name': "Grant's Gulch",
#   'description': 'A wide crack in the back of a corner.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 0.5,
#   'num_ratings': 2,
#   'url': 'https://www.mountainproject.com/route/119011566/grants-gulch',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches.',
#   'difficulty': 10,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264cb'),
#   'climb_id': 119011576,
#   'name': 'Jiffy Pop',
#   'description': 'Beautiful rock!',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011576/jiffy-pop',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264cc'),
#   'climb_id': 119016071,
#   'name': 'Le Papillon',
#   'description': 'A sport route up outstanding rock.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016071/le-papillon',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264cd'),
#   'climb_id': 119016178,
#   'name': "Man's Best Friend",
#   'description': 'Follow bolts to a two bolt anchor.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016178/mans-best-friend',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 16,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264ce'),
#   'climb_id': 119011542,
#   'name': 'One Size Fits All',
#   'description': 'Nice hand crack. \xa0Crux protected by a bolt.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011542/one-size-fits-all',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 70.0,
#   'height_m': 21.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264cf'),
#   'climb_id': 119016140,
#   'name': 'Party Bowl',
#   'description': 'Use the crack from the ledge and exit the left side of the roof.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016140/party-bowl',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches',
#   'difficulty': 23,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d0'),
#   'climb_id': 119016151,
#   'name': 'Perhaps Another Bowl?',
#   'description': 'Use the crack off the ledge and exit the right side of the roof.',
#   'image_url': 'https://cdn2.apstatic.com/photos/climb/119016230_medium_1591805791.jpg',
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016151/perhaps-another-bowl',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches',
#   'difficulty': 24,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d1'),
#   'climb_id': 119011476,
#   'name': 'Pit Stop',
#   'description': 'Face climb past three bolts.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011476/pit-stop',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 15,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d2'),
#   'climb_id': 119011449,
#   'name': 'Quick Stop',
#   'description': 'Nice hand crack in a corner. \xa0Crux is near the top.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011449/quick-stop',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches.',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d3'),
#   'climb_id': 119011462,
#   'name': 'Two For the Price of One',
#   'description': 'Face climb up a black streak past two bolts.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119011462/two-for-the-price-of-one',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 60.0,
#   'height_m': 18.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 14,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d4'),
#   'climb_id': 119016306,
#   'name': 'Wages of Sin',
#   'description': 'Old school sport climb to an anchor.',
#   'image_url': nan,
#   'latitude': 37.90521847,
#   'longitude': -119.40754405,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119016306/wages-of-sin',
#   'climb_type': "['Sport', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 16,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d5'),
#   'climb_id': 119020674,
#   'name': "Becky's Corner",
#   'description': 'Nice crack in a corner.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020674/beckys-corner',
#   'climb_type': "['Trad', ' TR', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 2 inches',
#   'difficulty': 12,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d6'),
#   'climb_id': 119020816,
#   'name': 'Blue Moon',
#   'description': 'Short sport climb with a few bolts to a two bolt anchor.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 2.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020816/blue-moon',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 40.0,
#   'height_m': 12.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 21,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d7'),
#   'climb_id': 119020736,
#   'name': 'Grand Slam',
#   'description': 'Hard face moves down low and a crack up above.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020736/grand-slam',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Pro to 3 inches and quickdraws',
#   'difficulty': 19,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  {'_id': ObjectId('60333d0894953fda34a264d8'),
#   'climb_id': 119020657,
#   'name': 'Pop Fly',
#   'description': 'Several bolts with a runout crux.',
#   'image_url': nan,
#   'latitude': 37.90409147,
#   'longitude': -119.40542402,
#   'avg_rating': 1.0,
#   'num_ratings': 1,
#   'url': 'https://www.mountainproject.com/route/119020657/pop-fly',
#   'climb_type': "['Sport', ' TR', ' Alpine']",
#   'height_ft': 50.0,
#   'height_m': 15.0,
#   'pitches': nan,
#   'grade': nan,
#   'protection': 'Quickdraws',
#   'difficulty': 13,
#   'rock_climb': 1,
#   'boulder_climb': 0},
#  ...]

# %%
import pandas as pd
from pymongo import MongoClient

import math

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import requests
from bs4 import BeautifulSoup, Tag
import json

# %%
#temp latitude and longtitudes. will be user inputs in the end
web_params = {'user_url': 'https://www.mountainproject.com/user/111094313/offwidth-eric', 'location': [37.819460, -119.539186], 'max_distance': 50, 'recommender': 'debug', 'num_recs': 10, 'difficulty_range': {'boulder': [0, 3], 'route': [11, 16]}}

# %%
#read in data from MongoDB
client = MongoClient('mongodb+srv://DSC102:coliniscool@cluster0.4gstr.mongodb.net/MountainProject?retryWrites=true&w=majority&ssl=true&ssl_cert_reqs=CERT_NONE')
climbs = client.MountainProject.climbs
df = pd.DataFrame.from_records(list(climbs.find()))
df = df.fillna(-1)
df['climb_type'] = df['climb_type'].apply(lambda x: x.strip('][').split(', '))
df
# Out:
#                            _id   climb_id                       name  \
# 0     60359825ae2766120caadf67  111004304                    The Jet
# 1     60359825ae2766120caadf71  113689801                    Cupcake
# 2     60359825ae2766120caadf7b  107753089         Face, Ramp & Crack
# 3     60359825ae2766120caadf86  110648065               Finger Crack
# 4     60359825ae2766120caadf90  107753112        Wandering Albatross
# ...                        ...        ...                        ...
# 2113  60359861ae2766120cab3afe  105945535           Sacherer Cracker
# 2114  60359861ae2766120cab3b0a  106284793             Short But Thin
# 2115  60359861ae2766120cab3b14  106410313        The Slack ( center)
# 2116  60359861ae2766120cab3b1e  107032569            The Slack, Left
# 2117  60359861ae2766120cab3b29  107416757  West Buttress (pitch 1&2)
#
#                                             description  \
# 0      A cool small route with some big, dynamic moves.
# 1     The most obvious route up the small crag at Gl...
# 2     The route on the left at the H3 crag. Begin wi...
# 3     Steep finger crack - start off the ground isnt...
# 4     A super-fun and quality route with varied clim...
# ...                                                 ...
# 2113  One of the most classic pitches at its grade i...
# 2114  Sustained, technical, and thin. Creative footw...
# 2115  First or one of the first Yosemite free 5.11. ...
# 2116  This is a classic Chuck Pratt testpiece - a mu...
# 2117  So the West Buttress obviously isn't a "base r...
#
#                                               image_url   latitude  \
# 0     https://cdn2.apstatic.com/photos/climb/1110043...  37.985467
# 1     https://cdn2.apstatic.com/photos/climb/1136898...  37.729341
# 2     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# 3                                                    -1  37.922100
# 4     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# ...                                                 ...        ...
# 2113  https://cdn2.apstatic.com/photos/climb/1076312...  37.730087
# 2114  https://cdn2.apstatic.com/photos/climb/1067710...  37.730087
# 2115  https://cdn2.apstatic.com/photos/climb/1189273...  37.730087
# 2116  https://cdn2.apstatic.com/photos/climb/1070326...  37.730087
# 2117                                                 -1  37.730087
#
#        longitude  avg_rating  num_ratings  \
# 0    -119.916808         3.0            3
# 1    -119.573661         1.0            2
# 2    -119.804456         2.5            6
# 3    -119.804456         2.0            1
# 4    -119.804456         2.7            3
# ...          ...         ...          ...
# 2113 -119.637863         3.9          248
# 2114 -119.637863         2.6           45
# 2115 -119.637863         2.7            9
# 2116 -119.637863         3.3            4
# 2117 -119.637863         3.5            8
#
#                                                     url       climb_type  \
# 0     https://www.mountainproject.com/route/11100430...      ['Boulder']
# 1     https://www.mountainproject.com/route/11368980...           ['TR']
# 2     https://www.mountainproject.com/route/10775308...           ['TR']
# 3     https://www.mountainproject.com/route/11064806...  ['Trad', ' TR']
# 4     https://www.mountainproject.com/route/10775311...  ['Trad', ' TR']
# ...                                                 ...              ...
# 2113  https://www.mountainproject.com/route/10594553...         ['Trad']
# 2114  https://www.mountainproject.com/route/10628479...         ['Trad']
# 2115  https://www.mountainproject.com/route/10641031...         ['Trad']
# 2116  https://www.mountainproject.com/route/10703256...         ['Trad']
# 2117  https://www.mountainproject.com/route/10741675...         ['Trad']
#
#       height_ft  height_m  pitches  grade  \
# 0           9.0       3.0     -1.0   -1.0
# 1          30.0       9.0     -1.0   -1.0
# 2          45.0      14.0     -1.0   -1.0
# 3          40.0      12.0     -1.0   -1.0
# 4          45.0      14.0     -1.0   -1.0
# ...         ...       ...      ...    ...
# 2113      150.0      45.0     -1.0   -1.0
# 2114       40.0      12.0     -1.0   -1.0
# 2115      400.0     121.0      4.0   -1.0
# 2116      350.0     106.0      3.0   -1.0
# 2117      300.0      91.0      2.0   -1.0
#
#                                              protection  difficulty  \
# 0     Crash pad, as the ground next to the boulder i...           2
# 1     Easy walk to the top of the crag. Bring a long...           7
# 2     This route can also be led. Few protection opp...          11
# 3                          two bolt anchor - thin gear.          17
# 4     On toprope, there is big pendulum potential on...          13
# ...                                                 ...         ...
# 2113  Doubles to 3".  Most forego anything big for t...          13
# 2114  Fingers to micro-cams/nuts. Not often led as y...          18
# 2115  double from green Alien to #3. One each #4, #5...          16
# 2116           Pro to 6+ inches. Doubles from 2" to 5".          14
# 2117  Doubles from fingers to 2". A 6" piece protect...          13
#
#       rock_climb  boulder_climb
# 0              0              1
# 1              1              0
# 2              1              0
# 3              1              0
# 4              1              0
# ...          ...            ...
# 2113           1              0
# 2114           1              0
# 2115           1              0
# 2116           1              0
# 2117           1              0
#
# [2118 rows x 19 columns]

# %%
# filter by location
def calc_distance(x):
    # approximate radius of earth in km
    R = 6373.0
    lat1 = radians(web_params['location'][0])
    lon1 = radians(web_params['location'][1])
    lat2 = radians(x['latitude'])
    lon2 = radians(x['longitude'])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c * 0.621371 #convert to miles by multiplying by 0.621371
    return distance
df_filtered = df[df.apply(calc_distance, axis=1) <= web_params['max_distance']]
df_filtered
# Out:
#                            _id   climb_id                       name  \
# 0     60359825ae2766120caadf67  111004304                    The Jet
# 1     60359825ae2766120caadf71  113689801                    Cupcake
# 2     60359825ae2766120caadf7b  107753089         Face, Ramp & Crack
# 3     60359825ae2766120caadf86  110648065               Finger Crack
# 4     60359825ae2766120caadf90  107753112        Wandering Albatross
# ...                        ...        ...                        ...
# 2113  60359861ae2766120cab3afe  105945535           Sacherer Cracker
# 2114  60359861ae2766120cab3b0a  106284793             Short But Thin
# 2115  60359861ae2766120cab3b14  106410313        The Slack ( center)
# 2116  60359861ae2766120cab3b1e  107032569            The Slack, Left
# 2117  60359861ae2766120cab3b29  107416757  West Buttress (pitch 1&2)
#
#                                             description  \
# 0      A cool small route with some big, dynamic moves.
# 1     The most obvious route up the small crag at Gl...
# 2     The route on the left at the H3 crag. Begin wi...
# 3     Steep finger crack - start off the ground isnt...
# 4     A super-fun and quality route with varied clim...
# ...                                                 ...
# 2113  One of the most classic pitches at its grade i...
# 2114  Sustained, technical, and thin. Creative footw...
# 2115  First or one of the first Yosemite free 5.11. ...
# 2116  This is a classic Chuck Pratt testpiece - a mu...
# 2117  So the West Buttress obviously isn't a "base r...
#
#                                               image_url   latitude  \
# 0     https://cdn2.apstatic.com/photos/climb/1110043...  37.985467
# 1     https://cdn2.apstatic.com/photos/climb/1136898...  37.729341
# 2     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# 3                                                    -1  37.922100
# 4     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# ...                                                 ...        ...
# 2113  https://cdn2.apstatic.com/photos/climb/1076312...  37.730087
# 2114  https://cdn2.apstatic.com/photos/climb/1067710...  37.730087
# 2115  https://cdn2.apstatic.com/photos/climb/1189273...  37.730087
# 2116  https://cdn2.apstatic.com/photos/climb/1070326...  37.730087
# 2117                                                 -1  37.730087
#
#        longitude  avg_rating  num_ratings  \
# 0    -119.916808         3.0            3
# 1    -119.573661         1.0            2
# 2    -119.804456         2.5            6
# 3    -119.804456         2.0            1
# 4    -119.804456         2.7            3
# ...          ...         ...          ...
# 2113 -119.637863         3.9          248
# 2114 -119.637863         2.6           45
# 2115 -119.637863         2.7            9
# 2116 -119.637863         3.3            4
# 2117 -119.637863         3.5            8
#
#                                                     url       climb_type  \
# 0     https://www.mountainproject.com/route/11100430...      ['Boulder']
# 1     https://www.mountainproject.com/route/11368980...           ['TR']
# 2     https://www.mountainproject.com/route/10775308...           ['TR']
# 3     https://www.mountainproject.com/route/11064806...  ['Trad', ' TR']
# 4     https://www.mountainproject.com/route/10775311...  ['Trad', ' TR']
# ...                                                 ...              ...
# 2113  https://www.mountainproject.com/route/10594553...         ['Trad']
# 2114  https://www.mountainproject.com/route/10628479...         ['Trad']
# 2115  https://www.mountainproject.com/route/10641031...         ['Trad']
# 2116  https://www.mountainproject.com/route/10703256...         ['Trad']
# 2117  https://www.mountainproject.com/route/10741675...         ['Trad']
#
#       height_ft  height_m  pitches  grade  \
# 0           9.0       3.0     -1.0   -1.0
# 1          30.0       9.0     -1.0   -1.0
# 2          45.0      14.0     -1.0   -1.0
# 3          40.0      12.0     -1.0   -1.0
# 4          45.0      14.0     -1.0   -1.0
# ...         ...       ...      ...    ...
# 2113      150.0      45.0     -1.0   -1.0
# 2114       40.0      12.0     -1.0   -1.0
# 2115      400.0     121.0      4.0   -1.0
# 2116      350.0     106.0      3.0   -1.0
# 2117      300.0      91.0      2.0   -1.0
#
#                                              protection  difficulty  \
# 0     Crash pad, as the ground next to the boulder i...           2
# 1     Easy walk to the top of the crag. Bring a long...           7
# 2     This route can also be led. Few protection opp...          11
# 3                          two bolt anchor - thin gear.          17
# 4     On toprope, there is big pendulum potential on...          13
# ...                                                 ...         ...
# 2113  Doubles to 3".  Most forego anything big for t...          13
# 2114  Fingers to micro-cams/nuts. Not often led as y...          18
# 2115  double from green Alien to #3. One each #4, #5...          16
# 2116           Pro to 6+ inches. Doubles from 2" to 5".          14
# 2117  Doubles from fingers to 2". A 6" piece protect...          13
#
#       rock_climb  boulder_climb
# 0              0              1
# 1              1              0
# 2              1              0
# 3              1              0
# 4              1              0
# ...          ...            ...
# 2113           1              0
# 2114           1              0
# 2115           1              0
# 2116           1              0
# 2117           1              0
#
# [2114 rows x 19 columns]

# %%
# filter by type of climb and difficulty
def type_and_difficulty_check(x):
    if x['boulder_climb'] == 1 and x['difficulty'] >= web_params['difficulty_range']['boulder'][0] and x['difficulty'] <= web_params['difficulty_range']['boulder'][1]:
        return True
    if x['rock_climb'] == 1 and x['difficulty'] >= web_params['difficulty_range']['route'][0] and x['difficulty'] <= web_params['difficulty_range']['route'][1]:
        return True
    return False
df_filtered = df_filtered[df_filtered.apply(type_and_difficulty_check, axis=1)]
df_filtered
# Out:
#                            _id   climb_id                       name  \
# 0     60359825ae2766120caadf67  111004304                    The Jet
# 2     60359825ae2766120caadf7b  107753089         Face, Ramp & Crack
# 4     60359825ae2766120caadf90  107753112        Wandering Albatross
# 7     60359825ae2766120caadfb0  107751576                  Variation
# 8     60359825ae2766120caadfbe  118812991          Spliter handcrack
# ...                        ...        ...                        ...
# 2112  60359861ae2766120cab3af4  107414798                  Peter Pan
# 2113  60359861ae2766120cab3afe  105945535           Sacherer Cracker
# 2115  60359861ae2766120cab3b14  106410313        The Slack ( center)
# 2116  60359861ae2766120cab3b1e  107032569            The Slack, Left
# 2117  60359861ae2766120cab3b29  107416757  West Buttress (pitch 1&2)
#
#                                             description  \
# 0      A cool small route with some big, dynamic moves.
# 2     The route on the left at the H3 crag. Begin wi...
# 4     A super-fun and quality route with varied clim...
# 7     A number of variations exist to the left of Ca...
# 8     Thin hands to full hands at the top, negotiate...
# ...                                                 ...
# 2112  Peter Pan is a great offwidth climb in a spect...
# 2113  One of the most classic pitches at its grade i...
# 2115  First or one of the first Yosemite free 5.11. ...
# 2116  This is a classic Chuck Pratt testpiece - a mu...
# 2117  So the West Buttress obviously isn't a "base r...
#
#                                               image_url   latitude  \
# 0     https://cdn2.apstatic.com/photos/climb/1110043...  37.985467
# 2     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# 4     https://cdn2.apstatic.com/photos/climb/1077531...  37.922100
# 7                                                    -1  37.903978
# 8     https://cdn2.apstatic.com/photos/climb/1188130...  37.882278
# ...                                                 ...        ...
# 2112                                                 -1  37.730087
# 2113  https://cdn2.apstatic.com/photos/climb/1076312...  37.730087
# 2115  https://cdn2.apstatic.com/photos/climb/1189273...  37.730087
# 2116  https://cdn2.apstatic.com/photos/climb/1070326...  37.730087
# 2117                                                 -1  37.730087
#
#        longitude  avg_rating  num_ratings  \
# 0    -119.916808         3.0            3
# 2    -119.804456         2.5            6
# 4    -119.804456         2.7            3
# 7    -119.834594         1.7            3
# 8    -119.861023         3.0            1
# ...          ...         ...          ...
# 2112 -119.637863         3.4            5
# 2113 -119.637863         3.9          248
# 2115 -119.637863         2.7            9
# 2116 -119.637863         3.3            4
# 2117 -119.637863         3.5            8
#
#                                                     url       climb_type  \
# 0     https://www.mountainproject.com/route/11100430...      ['Boulder']
# 2     https://www.mountainproject.com/route/10775308...           ['TR']
# 4     https://www.mountainproject.com/route/10775311...  ['Trad', ' TR']
# 7     https://www.mountainproject.com/route/10775157...           ['TR']
# 8     https://www.mountainproject.com/route/11881299...      ['Boulder']
# ...                                                 ...              ...
# 2112  https://www.mountainproject.com/route/10741479...         ['Trad']
# 2113  https://www.mountainproject.com/route/10594553...         ['Trad']
# 2115  https://www.mountainproject.com/route/10641031...         ['Trad']
# 2116  https://www.mountainproject.com/route/10703256...         ['Trad']
# 2117  https://www.mountainproject.com/route/10741675...         ['Trad']
#
#       height_ft  height_m  pitches  grade  \
# 0           9.0       3.0     -1.0   -1.0
# 2          45.0      14.0     -1.0   -1.0
# 4          45.0      14.0     -1.0   -1.0
# 7          60.0      18.0     -1.0   -1.0
# 8          14.0       4.0     -1.0   -1.0
# ...         ...       ...      ...    ...
# 2112      300.0      91.0      3.0   -1.0
# 2113      150.0      45.0     -1.0   -1.0
# 2115      400.0     121.0      4.0   -1.0
# 2116      350.0     106.0      3.0   -1.0
# 2117      300.0      91.0      2.0   -1.0
#
#                                              protection  difficulty  \
# 0     Crash pad, as the ground next to the boulder i...           2
# 2     This route can also be led. Few protection opp...          11
# 4     On toprope, there is big pendulum potential on...          13
# 7             Two bolts on top for anchoring. Walk-off.          13
# 8                                                  Pads           0
# ...                                                 ...         ...
# 2112  A single set of cams from 1" to a #6 Camalot. ...          12
# 2113  Doubles to 3".  Most forego anything big for t...          13
# 2115  double from green Alien to #3. One each #4, #5...          16
# 2116           Pro to 6+ inches. Doubles from 2" to 5".          14
# 2117  Doubles from fingers to 2". A 6" piece protect...          13
#
#       rock_climb  boulder_climb
# 0              0              1
# 2              1              0
# 4              1              0
# 7              1              0
# 8              0              1
# ...          ...            ...
# 2112           1              0
# 2113           1              0
# 2115           1              0
# 2116           1              0
# 2117           1              0
#
# [1138 rows x 19 columns]

# %%
def get_user_history(user_url):
    output = pd.DataFrame(columns=['name', 'url', 'user_rating'])
    text = requests.get(user_url + '/ticks').text
    soup = BeautifulSoup(text, 'html.parser')
    num_pages = int(soup.find_all('a', {"class":"no-click"})[2].contents[0].strip()[-1])
    for i in range(num_pages):
        text = requests.get(user_url + '/ticks?page=' + str(i + 1)).text
        soup = BeautifulSoup(text, 'html.parser')
        all_links = soup.find_all('a')
        all_ratings = [] #this is the list of all star ratings on the current page
        for link in all_links:
            #this part is finding out the star ratings
            ratings_list = link.find_all('span', {"class":"scoreStars"})
            if len(ratings_list) > 0:
                rating = 0
                for element in ratings_list[0].contents:
                    if isinstance(element, Tag):
                        image = element['src']
                        if image == '/img/stars/starBlue.svg':
                            rating += 1
                        if image == '/img/stars/starBlueHalf.svg':
                            rating += 0.5
                all_ratings.append(rating)
            #this part is adding the data to the final output list
            if len(link.find_all('strong')) > 0 and len(link) < 2:
                #key is the name of the route, value is (route url, user's star rating for this route)
                output.loc[len(output.index)] = [link.find('strong').contents[0], link.get('href'), all_ratings.pop(0)]
    return output.to_dict()

# %%
#cosine similarity function
def find_similarity(x, current_row):
    output = pd.DataFrame(columns=['row', 'similarity_score', 'similar_to'])
    for index, row in df_selected_attributes.iterrows():
        similarity_score = round(cosine_similarity(np.array(x), [row.tolist()])[0][0], 6) #need to round because output is weird
        if similarity_score < 1: #so that you don't recommend yourself
            output.loc[len(output.index)] = [index, similarity_score, current_row]
    return output

# %%
#get user's past rating data
user = web_params['user_url']
history = get_user_history(user)
history
# Out:
# {'name': {0: 'Destructomatic',
#   1: 'Ticks Dig Me',
#   2: 'Hunger Pains',
#   3: 'Quirky',
#   4: 'Community Chest',
#   5: 'Uncomfortably Dumb',
#   6: 'Creepshow',
#   7: 'Vacavillain',
#   8: 'Comfortably Dumb',
#   9: 'Diagon Alley',
#   10: 'West Face',
#   11: 'The Mountains are Calling',
#   12: 'Driller Instinct',
#   13: 'Stoned Wheat Thin',
#   14: 'Conduct Unbecoming',
#   15: 'Stem Christy',
#   16: "Lil' Squirt",
#   17: 'More Trad Than Rad',
#   18: 'Scorpio',
#   19: 'Bread Line',
#   20: 'Ali',
#   21: 'The Juggernut',
#   22: 'Cream Puff',
#   23: 'Caifura',
#   24: 'Insidious Crack',
#   25: 'The Yawn',
#   26: 'Jailbreak Finish',
#   27: 'On the Lamb',
#   28: 'Tectonomagmatic',
#   29: 'East Wall',
#   30: 'Haystack',
#   31: 'Southeast Buttress',
#   32: 'Southeast Buttress',
#   33: 'Tenaya, Matthes, Cathedral…',
#   34: 'Northwest Buttress',
#   35: 'Holdless Horror'},
#  'url': {0: 'https://www.mountainproject.com/route/107754121/destructomatic',
#   1: 'https://www.mountainproject.com/route/105735239/ticks-dig-me',
#   2: 'https://www.mountainproject.com/route/105735230/hunger-pains',
#   3: 'https://www.mountainproject.com/route/105735107/quirky',
#   4: 'https://www.mountainproject.com/route/105735212/community-chest',
#   5: 'https://www.mountainproject.com/route/105735125/uncomfortably-dumb',
#   6: 'https://www.mountainproject.com/route/107754198/creepshow',
#   7: 'https://www.mountainproject.com/route/107754203/vacavillain',
#   8: 'https://www.mountainproject.com/route/105735134/comfortably-dumb',
#   9: 'https://www.mountainproject.com/route/107840173/diagon-alley',
#   10: 'https://www.mountainproject.com/route/106065890/west-face',
#   11: 'https://www.mountainproject.com/route/119835151/the-mountains-are-calling',
#   12: 'https://www.mountainproject.com/route/106212643/driller-instinct',
#   13: 'https://www.mountainproject.com/route/107289784/stoned-wheat-thin',
#   14: 'https://www.mountainproject.com/route/106482195/conduct-unbecoming',
#   15: 'https://www.mountainproject.com/route/106482182/stem-christy',
#   16: 'https://www.mountainproject.com/route/105877651/lil-squirt',
#   17: 'https://www.mountainproject.com/route/105889665/more-trad-than-rad',
#   18: 'https://www.mountainproject.com/route/105882066/scorpio',
#   19: 'https://www.mountainproject.com/route/105882058/bread-line',
#   20: 'https://www.mountainproject.com/route/113362304/ali',
#   21: 'https://www.mountainproject.com/route/114972595/the-juggernut',
#   22: 'https://www.mountainproject.com/route/107657708/cream-puff',
#   23: 'https://www.mountainproject.com/route/107657703/caifura',
#   24: 'https://www.mountainproject.com/route/105735155/insidious-crack',
#   25: 'https://www.mountainproject.com/route/105903295/the-yawn',
#   26: 'https://www.mountainproject.com/route/105862994/jailbreak-finish',
#   27: 'https://www.mountainproject.com/route/105862991/on-the-lamb',
#   28: 'https://www.mountainproject.com/route/110672799/tectonomagmatic',
#   29: 'https://www.mountainproject.com/route/105987507/east-wall',
#   30: 'https://www.mountainproject.com/route/105810596/haystack',
#   31: 'https://www.mountainproject.com/route/105835705/southeast-buttress',
#   32: 'https://www.mountainproject.com/route/105835705/southeast-buttress',
#   33: 'https://www.mountainproject.com/route/107677399/tenaya-matthes-cathedral-traverse',
#   34: 'https://www.mountainproject.com/route/105900951/northwest-buttress',
#   35: 'https://www.mountainproject.com/route/106014323/holdless-horror'},
#  'user_rating': {0: 3,
#   1: 2.5,
#   2: 2.5,
#   3: 1.5,
#   4: 1.5,
#   5: 3,
#   6: 2,
#   7: 2.5,
#   8: 2.5,
#   9: 1.5,
#   10: 3.5,
#   11: 3,
#   12: 3.5,
#   13: 2,
#   14: 2,
#   15: 2.5,
#   16: 1.5,
#   17: 2.5,
#   18: 2.5,
#   19: 2.5,
#   20: 2.5,
#   21: 2,
#   22: 2.5,
#   23: 2.5,
#   24: 2.5,
#   25: 3.5,
#   26: 2.5,
#   27: 4,
#   28: 2.5,
#   29: 2.5,
#   30: 3,
#   31: 4,
#   32: 4,
#   33: 4,
#   34: 3.5,
#   35: 3}}

# %%
#routes the user has completed that are also in our DB
user_df = pd.DataFrame(history)
merged_df = user_df.merge(df_filtered, how='inner', on=['name', 'url'])
merged_df
# Out:
#                name                                                url  \
# 0          The Yawn  https://www.mountainproject.com/route/10590329...
# 1  Jailbreak Finish  https://www.mountainproject.com/route/10586299...
# 2       On the Lamb  https://www.mountainproject.com/route/10586299...
# 3   Tectonomagmatic  https://www.mountainproject.com/route/11067279...
#
#    user_rating                       _id   climb_id  \
# 0          3.5  60359830ae2766120caaf0d7  105903295
# 1          2.5  6035982dae2766120caaecd7  105862994
# 2          4.0  6035982eae2766120caaed12  105862991
# 3          2.5  6035982eae2766120caaed30  110672799
#
#                                          description  \
# 0  Start the route below a prominent 10' horizont...
# 1  The exact location of this great finish to On ...
# 2  On the Lamb is a very unique and classic trave...
# 3  Tectonomagmatic is a good approach pitch to Fi...
#
#                                            image_url   latitude   longitude  \
# 0  https://cdn2.apstatic.com/photos/climb/1173416...  37.860168 -119.428556
# 1                                                 -1  37.869323 -119.425879
# 2  https://cdn2.apstatic.com/photos/climb/1108387...  37.869323 -119.425879
# 3                                                 -1  37.869323 -119.425879
#
#    avg_rating  num_ratings climb_type  height_ft  height_m  pitches  grade  \
# 0         3.6           52   ['Trad']      600.0     182.0      4.0   -1.0
# 1         2.7           14   ['Trad']       -1.0      -1.0     -1.0   -1.0
# 2         3.8          276   ['Trad']       -1.0      -1.0      4.0   -1.0
# 3         2.3           12   ['Trad']      140.0      42.0     -1.0   -1.0
#
#                                           protection  difficulty  rock_climb  \
# 0  Single rack 0.4" to 1", double 1.5-2", double ...          12           1
# 1  Mostly draws & some gear from On the Lamb for ...          12           1
# 2       Standard rack; include wires and small cams.          12           1
# 3  9 draws, small to medium size cams and maybe s...          14           1
#
#    boulder_climb
# 0              0
# 1              0
# 2              0
# 3              0

# %%
#defining favorite as highest rated
fav_routes = merged_df[merged_df['user_rating'] == merged_df['user_rating'].max()]
fav_routes
# Out:
#           name                                                url  \
# 2  On the Lamb  https://www.mountainproject.com/route/10586299...
#
#    user_rating                       _id   climb_id  \
# 2          4.0  6035982eae2766120caaed12  105862991
#
#                                          description  \
# 2  On the Lamb is a very unique and classic trave...
#
#                                            image_url   latitude   longitude  \
# 2  https://cdn2.apstatic.com/photos/climb/1108387...  37.869323 -119.425879
#
#    avg_rating  num_ratings climb_type  height_ft  height_m  pitches  grade  \
# 2         3.8          276   ['Trad']       -1.0      -1.0      4.0   -1.0
#
#                                      protection  difficulty  rock_climb  \
# 2  Standard rack; include wires and small cams.          12           1
#
#    boulder_climb
# 2              0

# %%
#only look at the numerical attributes so far (will create more later)
fav_routes_selected_attributes = fav_routes[['latitude', 'longitude', 'avg_rating', 'num_ratings', 'height_ft', 'height_m', 'pitches', 'grade', 'difficulty']]
df_selected_attributes = df_filtered[['latitude', 'longitude', 'avg_rating', 'num_ratings', 'height_ft', 'height_m', 'pitches', 'grade', 'difficulty']]

# %%
#find row indicies in the database where the similarity scores are highest
output = pd.DataFrame(columns=['row', 'similarity_score', 'similar_to'])
for index, row in fav_routes_selected_attributes.iterrows():
    output = output.append(find_similarity([row.tolist()], index), ignore_index=True)
#only output the top N recommendations
output = output.sort_values(by='similarity_score', ascending=False)[:web_params['num_recs']]
output
# Out:
#          row  similarity_score  similar_to
# 486    943.0          0.999290         2.0
# 941   1769.0          0.998446         2.0
# 740   1446.0          0.998395         2.0
# 1120  2088.0          0.996277         2.0
# 789   1519.0          0.991446         2.0
# 167    327.0          0.989428         2.0
# 406    768.0          0.988040         2.0
# 919   1722.0          0.981446         2.0
# 355    645.0          0.981102         2.0
# 1060  1976.0          0.970997         2.0

# %%
df.iloc[output['row']]
# Out:
#                            _id   climb_id                          name  \
# 943   6035983fae2766120cab07d9  105860641                 Crescent Arch
# 1769  60359857ae2766120cab2c11  105862896            Northeast Buttress
# 1446  6035984dae2766120cab1cf5  105874598                        Nurdle
# 2088  60359860ae2766120cab39f6  105877768              La Cosita, Right
# 1519  6035984fae2766120cab205d  105865301  Reed's Pinnacle-Direct Route
# 327   6035982eae2766120caaed97  105923367             Crying Time Again
# 768   6035983aae2766120cab0001  105862873                 Steck-Salathe
# 1722  60359855ae2766120cab2a10  105841126                 Grant's Crack
# 645   60359837ae2766120caafaee  105915141              Church Bowl Tree
# 1976  6035985dae2766120cab34da  105867013                    Commitment
#
#                                             description  \
# 943   This route follows the obvious right-curving c...
# 1769  The Northeast Buttress of Higher Cathedral Roc...
# 1446  Climb the crack left of "Knob Job".     Rappel...
# 2088  This corner is just a little uphill from Littl...
# 1519  A Yosemite classic!   The first pitch goes up ...
# 327   Awesome moderate knob pulling. Even though thi...
# 768   The Steck-Salathe truly deserves its status as...
# 1722  Fun, technical 5.9 fingercrack. Can be toprope...
# 645   The technnical crux is down low (getting of th...
# 1976  This climb is in the next book right of "Mungi...
#
#                                               image_url   latitude  \
# 943   https://cdn2.apstatic.com/photos/climb/1065832...  37.879499
# 1769  https://cdn2.apstatic.com/photos/climb/1121538...  37.714398
# 1446  https://cdn2.apstatic.com/photos/climb/1182673...  37.724062
# 2088  https://cdn2.apstatic.com/photos/climb/1189273...  37.729533
# 1519  https://cdn2.apstatic.com/photos/climb/1058653...  37.724389
# 327   https://cdn2.apstatic.com/photos/climb/1062185...  37.881030
# 768   https://cdn2.apstatic.com/photos/climb/1068451...  37.729597
# 1722  https://cdn2.apstatic.com/photos/climb/1074737...  37.744998
# 645   https://cdn2.apstatic.com/photos/climb/1151741...  37.748806
# 1976  https://cdn2.apstatic.com/photos/climb/1063146...  37.747669
#
#        longitude  avg_rating  num_ratings  \
# 943  -119.413446         3.5          251
# 1769 -119.634701         3.6          244
# 1446 -119.713950         2.6          241
# 2088 -119.637522         3.1          224
# 1519 -119.700628         3.7          412
# 327  -119.351058         3.5          195
# 768  -119.593810         3.8          195
# 1722 -119.599900         2.7          381
# 645  -119.580021         2.7          393
# 1976 -119.598795         3.4          667
#
#                                                     url       climb_type  \
# 943   https://www.mountainproject.com/route/10586064...         ['Trad']
# 1769  https://www.mountainproject.com/route/10586289...         ['Trad']
# 1446  https://www.mountainproject.com/route/10587459...         ['Trad']
# 2088  https://www.mountainproject.com/route/10587776...         ['Trad']
# 1519  https://www.mountainproject.com/route/10586530...         ['Trad']
# 327   https://www.mountainproject.com/route/10592336...         ['Trad']
# 768   https://www.mountainproject.com/route/10586287...         ['Trad']
# 1722  https://www.mountainproject.com/route/10584112...  ['Trad', ' TR']
# 645   https://www.mountainproject.com/route/10591514...         ['Trad']
# 1976  https://www.mountainproject.com/route/10586701...         ['Trad']
#
#       height_ft  height_m  pitches  grade  \
# 943        -1.0      -1.0      5.0   -1.0
# 1769       -1.0      -1.0     11.0   -1.0
# 1446       -1.0      -1.0     -1.0   -1.0
# 2088       -1.0      -1.0     -1.0   -1.0
# 1519       -1.0      -1.0      3.0   -1.0
# 327        -1.0      -1.0      4.0   -1.0
# 768        -1.0      -1.0     15.0   -1.0
# 1722       60.0      18.0     -1.0   -1.0
# 645        60.0      18.0     -1.0   -1.0
# 1976       -1.0      -1.0      3.0   -1.0
#
#                                              protection  difficulty  \
# 943                   A selection of cams and stoppers.          13
# 1769                 Standard rack plus a 4 inch piece.          12
# 1446                                         Pro to 3".          11
# 2088                                       Pro to 1.5".          12
# 1519                                         Pro to 3".          13
# 327                Light rack, quick draws, and runners          13
# 768   Two each from TCU's to hands.  One each 4 and ...          13
# 1722                                 No protection data          12
# 645                    small nuts and cams, bolt anchor          13
# 1976                                         Pro to 3".          12
#
#       rock_climb  boulder_climb
# 943            1              0
# 1769           1              0
# 1446           1              0
# 2088           1              0
# 1519           1              0
# 327            1              0
# 768            1              0
# 1722           1              0
# 645            1              0
# 1976           1              0
