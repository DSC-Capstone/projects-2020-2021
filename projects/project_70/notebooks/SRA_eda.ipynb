# %% [markdown]
# # EDA on SRA Run Table

# %%
import pandas as pd

# %%
sra = pd.read_csv("/teams/DSC180A_FA20_A00/b04genetics/group_4/opioids-od-genome-analysis/data/external/SRA_case_table.csv")
sra = sra.drop('Case', axis=1)
sra.tail()
# Out:
#     SRR Number Cause of Death  Age Race Sex  Brain pH   RIN Opioids  Cocaine  \
# 45  SRR7949805     Drug abuse   57    B   M      6.47  7.23      Mo        1
# 46  SRR7949802     Drug abuse   59    W   M      6.43  6.70  Co, Mo        0
# 47  SRR7949803     Drug abuse   59    B   M      6.35  6.90  Co, Mo        0
# 48  SRR7949812     Drug abuse   60    B   M      6.64  6.90  Co, Mo        1
# 49  SRR7949813     Drug abuse   61    B   M      6.26  7.00  Fe, Mo        1
#
#            Group
# 45  Experimental
# 46  Experimental
# 47  Experimental
# 48  Experimental
# 49  Experimental

# %% [markdown]
# ## See differences of quantitative values between two groups

# %%
group_means = sra.groupby('Group').mean()
group_means
# Out:
#                     Age  Brain pH     RIN  Cocaine
# Group
# Control       50.400000    6.6015  7.3875      0.0
# Experimental  51.466667    6.5330  7.2490      0.6

# %%
diff_group_means = group_means.diff()
diff_group_means
# Out:
#                    Age  Brain pH     RIN  Cocaine
# Group
# Control            NaN       NaN     NaN      NaN
# Experimental  1.066667   -0.0685 -0.1385      0.6

# %%
diff_group_means.plot(kind='bar')

# %% [markdown]
# ## Analyze difference in experimental group of those who used cocaine and those who didn't

# %%
exper = sra[sra.Group == 'Experimental']
cocaine_use_means = exper.groupby('Cocaine').mean()
cocaine_use_means
# Out:
#                Age  Brain pH     RIN
# Cocaine
# 0        51.750000  6.494167  7.2175
# 1        51.277778  6.558889  7.2700

# %%
cocaine_use_diff = cocaine_use_means.diff()
cocaine_use_diff
# Out:
#               Age  Brain pH     RIN
# Cocaine
# 0             NaN       NaN     NaN
# 1       -0.472222  0.064722  0.0525

# %%
cocaine_use_diff.plot(kind='bar')

# %% [markdown]
# ## One-Hot-Encode Opioids Column

# %%
sra.Opioids.unique()
# Out:
# array(['Neg', 'Fe', 'Mo', 'Fe, He', 'Co, He, Mo', 'Fe, Hy', 'Me',
#        'Co, Fe, He, Mo', 'He, Mo', 'Ox', 'Hy', 'Co, Mo', 'Fe, Mo'],
#       dtype=object)

# %%
opioids_split = sra['Opioids'].str.split(',')
opioids_split = opioids_split.apply(lambda x: [y.strip() for y in x])
sra['Opioids'] = opioids_split
sra['Opioids'] = sra.Opioids.apply(lambda x: [] if x == ['Neg'] else x)

# %%
sra.head(3)
# Out:
#    SRR Number           Cause of Death  Age Race Sex  Brain pH   RIN Opioids  \
# 0  SRR7949817  MGSW, aortic dissection   41    B   M      6.64  8.04      []
# 1  SRR7949816                    HTCVD   42    B   M      6.78  7.03      []
# 2  SRR7949815                    ASCVD   46    B   M      6.71  7.20      []
#
#    Cocaine    Group
# 0        0  Control
# 1        0  Control
# 2        0  Control

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
sra_ohe = sra.join(pd.DataFrame(mlb.fit_transform(sra.pop('Opioids')),
                          columns=mlb.classes_,
                          index=sra.index))

# %%
sra_ohe = sra_ohe.set_index('SRR Number')
sra_ohe.tail()
# Out:
#            Cause of Death  Age Race Sex  Brain pH   RIN  Cocaine  \
# SRR Number
# SRR7949805     Drug abuse   57    B   M      6.47  7.23        1
# SRR7949802     Drug abuse   59    W   M      6.43  6.70        0
# SRR7949803     Drug abuse   59    B   M      6.35  6.90        0
# SRR7949812     Drug abuse   60    B   M      6.64  6.90        1
# SRR7949813     Drug abuse   61    B   M      6.26  7.00        1
#
#                    Group  Co  Fe  He  Hy  Me  Mo  Ox
# SRR Number
# SRR7949805  Experimental   0   0   0   0   0   1   0
# SRR7949802  Experimental   1   0   0   0   0   1   0
# SRR7949803  Experimental   1   0   0   0   0   1   0
# SRR7949812  Experimental   1   0   0   0   0   1   0
# SRR7949813  Experimental   0   1   0   0   0   1   0

# %% [markdown]
# ## Pie Chart of Drug Popularity

# %%
from matplotlib.pyplot import pie, axis, show
drugs = sra_ohe[['Co', 'Fe', 'He', 'Hy', 'Me', 'Mo', 'Ox']]
pie(drugs.sum(), labels = drugs.columns, autopct='%1.0f%%', labeldistance=1.1, pctdistance=.8, radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6b43f6ed50>,
#   <matplotlib.patches.Wedge at 0x7f6b43efc510>,
#   <matplotlib.patches.Wedge at 0x7f6b43efcd90>,
#   <matplotlib.patches.Wedge at 0x7f6b43f056d0>,
#   <matplotlib.patches.Wedge at 0x7f6b43f11250>,
#   <matplotlib.patches.Wedge at 0x7f6b43f11b90>,
#   <matplotlib.patches.Wedge at 0x7f6b43f1b190>],
#  [Text(1.5945441662377633, 1.5157271858474788, 'Co'),
#   Text(-0.658598753255849, 2.099106400878679, 'Fe'),
#   Text(-2.1549658319672864, 0.44285693294058387, 'He'),
#   Text(-1.7397067737801388, -1.3466329645688546, 'Hy'),
#   Text(-1.4330196611302148, -1.6692676989668989, 'Me'),
#   Text(0.8675826675394218, -2.021707277274626, 'Mo'),
#   Text(2.1971763055119173, -0.11142837384168598, 'Ox')],
#  [Text(1.159668484536555, 1.1023470442527117, '24%'),
#   Text(-0.4789809114587993, 1.5266228370026758, '11%'),
#   Text(-1.5672478777943901, 0.3220777694113337, '23%'),
#   Text(-1.265241290021919, -0.9793694287773488, '5%'),
#   Text(-1.042196117185611, -1.2140128719759264, '2%'),
#   Text(0.6309692127559431, -1.4703325652906372, '34%'),
#   Text(1.597946404008667, -0.08103881733940799, '2%')])

# %% [markdown]
# ## Distribution of Race

# %%
race = sra.Race.value_counts()
pie(race, labels = race.index, autopct='%1.0f%%', labeldistance=1.1, pctdistance=.8, radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f69eb045350>,
#   <matplotlib.patches.Wedge at 0x7f69eb045ad0>],
#  [Text(-1.4023329298081773, 1.6951290080626946, 'B'),
#   Text(1.4023330885176026, -1.6951288767668027, 'W')],
#  [Text(-1.0198784944059471, 1.2328210967728688, '72%'),
#   Text(1.0198786098309838, -1.2328210012849474, '28%')])

# %% [markdown]
# ## Distribution of Age

# %%
sra.Age.plot(kind='hist')

# %% [markdown]
# ## Scatterplot matrix to see relationships between features

# %%
pd.plotting.scatter_matrix(sra_ohe, alpha=0.3, figsize=(15,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed421190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed3ac510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed36d4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed380a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed394f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed32e550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed35ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed307b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed31e090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed2d2710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed24b150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed1ff6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed1b4c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed177210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed12e790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed164d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed1262d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed0db850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed090dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed052390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ed008910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecfc0e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecf81450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecf369d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eceedf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eceb0510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecee4a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ece9afd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ece5d5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ece14b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecdd5110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecd8a690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecd40c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecd031d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eccb7750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecc6ccd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecc2e290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecbe7810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecc19d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecbde350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecb948d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecb49e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecb0c410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ecac1990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69eca77f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eca3a4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec9eea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eca1ab10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec968590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec99cb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec95f0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec915650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec8c8bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec88d190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec842710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec7f8c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec7bd250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec7717d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec727d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec6e8310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec71e890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec6d2e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec6953d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec64c950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec602ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec5c4490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec578a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec52ff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec4f2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec4a7ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec4d4b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec4a1610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec456b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec418150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec3cc6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec382c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec344210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec2fb790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec2b1d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec2732d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec229850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec25ddd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec21f390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec1d6910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec18de90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec151450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec1049d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec0bbf50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec07d510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ec031a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebfe8fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebfaa5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebfdfb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebfa2110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebf58690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebf0ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebed01d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebe85750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebe3dcd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebdff290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebdb3810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebd68d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebd2c350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebd608d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebd16e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebcda410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebc8f990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebc45f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebc064d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebbbca50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebb68b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebb35590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebaeab10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebaac0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ebae1650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eba98bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eba5a190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eba10710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eb9c6c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eb989250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eb93f7d0>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(sra_ohe[sra_ohe.Group=='Experimental'], alpha=0.3, figsize=(15,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f69f3079e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef6f6410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef68a210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef69e750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef632cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef64b290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69f3fc5b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69f310ebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69f19ef090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef795790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef7bf1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef564cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef4a7390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef4dea10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef4a00d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef456750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef40bdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef3ce490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef385b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef3461d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef2fc850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef2b2ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef275590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef22bc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef1ee2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef225950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef1d0b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef19b690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef153d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef1163d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef0caa50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef08f110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ef043790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69eeffae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eefbb4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eef72b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eef2dbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eeeee190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eef23710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eeedbc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eee9c250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eee527d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eee08d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eedcb310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69eed7f890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eed36e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eecf83d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eecae950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eece3ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eec28490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eec5ea10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eec13f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eebd3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eeb87ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eeb34b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69eeb01610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eeab7b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eea7a150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eea306d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eea64c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee9a8210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee9dc790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee993d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee9562d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee90b850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee8c1dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee882390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee836910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee7ede90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee7b0450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee7e49d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee79cf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee75e510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee714a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee6cafd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee68b5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee642b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee606110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee5b8690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee570c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee5321d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee4e7750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee51bcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee4df290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee495810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee44ad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee40c350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee3c38d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee379e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee33b410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee2f1990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee2a7f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee2694d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee29ea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee249b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee216590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee1ccb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee18e0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee144650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee0fabd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee0bd190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee070710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee0a6c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edfeb250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ee0217d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edfd4d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edf98310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edf4e890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edf03e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edec53d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ede79950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ede31ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69eddf4490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edda9a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edddff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edda0550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edd56ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edd02b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edccc610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edc86b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69edc47150>]],
#       dtype=object)
