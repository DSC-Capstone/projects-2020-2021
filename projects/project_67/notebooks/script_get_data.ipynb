# %%
import os
import pandas as pd

# %%
# starts: SRR837437
# ends: SRR837506
os.system("mkdir fastq_files")
for i in range(437,506,1):
    os.system("wget -N ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/SRR837"+str(i)+'/SRR837'+str(i)+'.fastq.gz -P fastq_files')

# %%
df = pd.read_csv('SraRunTable.txt')
df
# Out:
#           Run  Age Assay Type  AvgSpotLen       Bases   BioProject  \
# 0   SRR837437   77    RNA-Seq          50   891533900  PRJNA201039
# 1   SRR837438   74    RNA-Seq          50   869717450  PRJNA201039
# 2   SRR837439   68    RNA-Seq          50   758073050  PRJNA201039
# 3   SRR837440   75    RNA-Seq          50   835484250  PRJNA201039
# 4   SRR837441   74    RNA-Seq          50   853289150  PRJNA201039
# ..        ...  ...        ...         ...         ...          ...
# 65  SRR837502   72    RNA-Seq          50   417504700  PRJNA201039
# 66  SRR837503   63    RNA-Seq          50   478856650  PRJNA201039
# 67  SRR837504   78    RNA-Seq          50  1226908800  PRJNA201039
# 68  SRR837505   78    RNA-Seq          50   955937550  PRJNA201039
# 69  SRR837506   79    RNA-Seq          50  1220548450  PRJNA201039
#
#        BioSample      Bytes Center Name Consent  ...           Instrument  \
# 0   SAMN02116274  521467001         GEO  public  ...  Illumina HiSeq 2000
# ...

# %%
runs = list(df['Run'].unique())

# %%
for i in runs:
    os.system(f"wget -N ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR837/{i}/{i}.fastq.gz -P raw_data")

# %%
os.chdir('..')
os.listdir()
# Out:
# ['test',
#  'src',
#  'run.py',
#  'data',
#  'config',
#  'README.md',
#  '.gitignore',
#  'references',
#  'notebooks',
#  '.git']

# %%
os.chdir('/teams/DSC180A_FA20_A00/b04genetics/group_1')

# %%
os.listdir()
# Out:
# ['raw_data']

# %%
os.system('mkdir raw_data')
os.listdir()
# Out:
# ['raw_data']
