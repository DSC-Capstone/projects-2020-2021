# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ABSSeq = [20, 21, 18, 19, 19, 19, 16, 18, 18, 19, 19]
DESeq = [307, 283, 307, 239, 394, 65, 58, 248, 218, 218, 209]
NOISeq = [87, 102, 101, 91, 86, 65, 81, 97, 97, 87, 87]
PoissonSeq = [7, 7, 8, 7, 7, 6, 7, 7, 7, 7, 8]
edgeR = [7, 8, 7, 7, 8, 11, 11, 8, 8, 7, 8]
ttest = [9, 10, 9, 8, 9, 10, 10, 11, 9, 9, 9]
voom = [7, 7, 8, 7, 7, 10, 10, 7, 7, 8, 7]
index = ['baseline0_0', 'baseline1250_0', 'baseline625_625', 'baseline4000_0', 'baseline2000_2000', 'poisson0_0', 
        'poisson625_625', 'single0_0', 'single625_625', 'random0_0', 'random625_625']
df = pd.DataFrame({'ABSSeq': ABSSeq,
                  'DESeq2': DESeq,
                  'NOISeq': NOISeq,
                  'PoissonSeq': PoissonSeq,
                  'edgeR': edgeR,
                  'ttest': ttest,
                  'voom.limma': voom}, index = index)
df
# Out:
#                    ABSSeq  DESeq2  NOISeq  PoissonSeq  edgeR  ttest  \
# baseline0_0            20     307      87           7      7      9
# baseline1250_0         21     283     102           7      8     10
# baseline625_625        18     307     101           8      7      9
# baseline4000_0         19     239      91           7      7      8
# baseline2000_2000      19     394      86           7      8      9
# poisson0_0             19      65      65           6     11     10
# poisson625_625         16      58      81           7     11     10
# single0_0              18     248      97           7      8     11
# single625_625          18     218      97           7      8      9
# random0_0              19     218      87           7      7      9
# random625_625          19     209      87           8      8      9
#
#                    voom.limma
# baseline0_0                 7
# baseline1250_0              7
# baseline625_625             8
# ...

# %%
ax = df.plot.bar(rot=45, figsize = (14, 10), ylabel = 'Duration (in seconds)', xlabel = 'Synthetic Dataset', title = 'Comparing Duration of Running Tools on Synthetic Datasets')
