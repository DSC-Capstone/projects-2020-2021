# %%
import sys
sys.path.append("../")
from src import graph_construct, visual
import h5py
import networkx as nx
import json

# %%
import torch
import tqdm

# %%
torch.__version__
# Out:
# '1.2.0'

# %%
f = h5py.File('../data/test.h5', 'r')
test = f['points'][:]
f.close()

# %%
visual.visual(test)

# %%
test.shape
# Out:
# (6691, 3)

# %%
test = graph_construct.pts_norm(test)
visual.visual(test)

# %%
test_1000 = graph_construct.pts_sample(test, 1000)
visual.visual(test)

# %%
A = graph_construct.graph_construct_radius(test_1000, 0.1)
G = visual.graph(A)
visual.draw_graph(G, test_1000)

# %%
A = graph_construct.graph_construct_radius(test_1000, 0.3)
G = visual.graph(A)
visual.draw_graph(G, test_1000)

# %%
A = graph_construct.graph_construct_radius(test_1000, 0.2)
G = visual.graph(A)
visual.draw_graph(G, test_1000)
