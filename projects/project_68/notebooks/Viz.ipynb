# %% [markdown]
# # Viz

# %%
sns.countplot(x='GROUP', data=patients)

# %%
sns.countplot(x='gender', data=patients)

# %%
sns.countplot(x='Age', data=patients)

# %%
sns.distplot(patients['Bases'])

# %%
sns.distplot(patients['Bytes'])

# %%
df = patients[patients['GROUP'] == 'control']
sns.distplot(df['Age'],  kde=False, label='Control')

df = patients[patients['GROUP'] == 'alzheimer patient']
sns.distplot(df['Age'],  kde=False, label='Alzheimers')

plt.legend(prop={'size': 10})
plt.title('Age of Patients')
plt.xlabel('Age (Years)')
plt.ylabel('# of Patients')
# Out:
# Text(0, 0.5, '# of Patients')

# %%
gender = patients.groupby(['gender', 'GROUP'])['GROUP'].agg(['count'])
gender = gender.reset_index()

ax = sns.barplot(x="GROUP", y="count", hue="gender", data=gender)
plt.legend(prop={'size': 10})
plt.title('Counts of Patients')
plt.xlabel('Group')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(x=patients['GROUP'], y=patients['Age'])

# %%
sns.boxplot(x=patients['gender'], y=patients['Age'])

# %%
sns.pairplot(patients[['Age','Bases','Bytes']+['GROUP']], hue = 'GROUP')

# %%
filtered_counts.sample(5,axis=1).boxplot()

# %%
sns.distplot(fc_var_imputed)
plt.axis([0, 25, 0, 0.01])
# Out:
# [0, 25, 0, 0.01]

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(patients[['Age','Bases','Bytes']].corr(),cmap=cmap,linewidths=.5)

# %%
#ENST00000621981.1
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000621981.1'].iloc[0])

# %%
#ENST00000362251.4
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000362251.4'].iloc[0])

# %%
#ENST00000385255.3
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000385255.3'].iloc[0])

# %%
#ENST00000362116.3
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000362116.3'].iloc[0])

# %%
#ENST00000362202.3
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000362202.3'].iloc[0])

# %%
#ENST00000384835.3
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000384835.3'].iloc[0])

# %%
#ENST00000385140.1
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000385140.1'].iloc[0])

# %%
#ENST00000636285.1
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000636285.1'].iloc[0])

# %%
#ENST00000362134.1
sns.distplot(filtered_counts[filtered_counts.index == 'ENST00000362134.1'].iloc[0])

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(significants[['log2FoldChange','pvalue','baseMean','lfcSE']].corr(),cmap=cmap,linewidths=.5)

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(wilcox_heatmap_values[['p.value','log2fold']].corr(),cmap=cmap,linewidths=.5)

# %%
sns.scatterplot(data = wilcox_heatmap_values, x='log2fold',y='p.value')

# %%
mirnas = mirnas.set_index(['target_id'])
mirnas = mirnas[(mirnas.T != 0).any()]
var = pd.DataFrame(mirnas.var(axis = 0))
var.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fab6a9cdfd0>]],
#       dtype=object)

# %%
df = pd.read_csv("mirna_counts.csv", index_col = 0)
#Wilcox
#ENST00000619233.1 (Most Upregulated)
#ENST00000362251.4 (Most Downregulated)
wilcox_bp = df[(df['target_id'] == 'ENST00000619233.1') | (df['target_id'] == 'ENST00000362251.4')]
wilcox_bp = wilcox_bp.set_index(['target_id']).T

#DESeq
#ENST00000390223.3 (Most Upregulated)
#ENST00000629190.1 (Most Downregulated)
deseq_bp = df[(df['target_id'] == 'ENST00000390223.3') | (df['target_id'] == 'ENST00000629190.1')]
deseq_bp = deseq_bp.set_index(['target_id']).T

deseq_bp.boxplot()

# %%
wilcox_bp.boxplot()

# %%
row = alz_df[alz_df['target_id'] == 'ENST00000390223.3']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#alz
fig.set_title("Most Upregulated of DESeq2 (Alzheimer's)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %%
row = control_df[control_df['target_id'] == 'ENST00000390223.3']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#control
fig.set_title("Most Upregulated of DESeq2 (Control)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %% [markdown]
# # ENST00000629190.1

# %%
row = alz_df[alz_df['target_id'] == 'ENST00000629190.1']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#alz
fig.set_title("Most Downregulated of DESeq2 (Alzheimer's)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %%
row = control_df[control_df['target_id'] == 'ENST00000629190.1']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#control
fig.set_title("Most Downregulated of DESeq2 (Control)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %% [markdown]
# # ENST00000619233.1

# %%
#ENST00000619233.1
row = alz_df[alz_df['target_id'] == 'ENST00000619233.1']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#alz
fig.set_title("Most Upregulated of Wilcox (Alzheimer's)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %%
row = control_df[control_df['target_id'] == 'ENST00000619233.1']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#control
fig.set_title("Most Upregulated of Wilcox (Control)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %% [markdown]
# # ENST00000362251.4

# %%
#ENST00000362251.4
row = alz_df[alz_df['target_id'] == 'ENST00000362251.4']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#alz
fig.set_title("Most Downregulated of Wilcox (Alzheimer's)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %%
row = control_df[control_df['target_id'] == 'ENST00000362251.4']
row = row.set_index(['target_id']).T
# sns.boxplot(row)
fig = row.boxplot()
#control
fig.set_title("Most Downregulated of Wilcox (Control)")
fig.set_ylabel('counts')
fig.set_xlabel("miRNA")
# Out:
# Text(0.5, 0, 'miRNA')

# %%
Image('../references/methods_flowchart.png',width=500)

# %% [markdown]
# ![147548659_210952814047277_8176225233658920783_n.png](attachment:147548659_210952814047277_8176225233658920783_n.png)
# <center>Quality scores across all bases from a pre-cutadapt fastq file</center>
#
# ![147542257_458198995217918_614456838404144421_n.png](attachment:147542257_458198995217918_614456838404144421_n.png)
# <center> Percentage of Adapter reads. This is expected since we didn't run Cutadapt to remove the adapter sequences</center>

# %%
Image('../references/ENST_conversions.png')

# %%
Image('../references/figure_3.png')

# %% [markdown]
# Figure 4. DESeq2 Volcano plot of pvalues

# %%
Image('../references/figure_4.png')

# %%
Image('../references/figure_7.png')

# %% [markdown]
# Figure 8. hsa-miR-766 Side by Side of DESeq Most Upregulated Alzheimer’s versus Control

# %%
Image('../references/figure_8.png')

# %% [markdown]
# Figure 9. hsa-miR-1248 Side by Side of DESeq Most Downregulated Alzheimer’s versus Control

# %%
Image('../references/figure_9.png')

# %% [markdown]
# Figure 10. hsa-miR-6882 Side by Side of Wilcox Most Upregulated Alzheimer’s versus Control

# %%
Image('../references/figure_10.png')

# %%
from IPython.core.display import display, HTML, Image

# %%
Image('../references/figure_13.png')

# %%
Image('../references/figure_14.png')

# %%
Image('../references/figure_15.png')

# %%
Image('../references/enst_highlighted.png')
