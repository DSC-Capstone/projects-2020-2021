# %%
import pandas as pd

# %% [markdown]
# # Merge Phantom Buster .csvs
# These .csvs contain broad data about each of the accounts that the 100 Senators of the 116th Congress follow.

# %%
out = pd.DataFrame()
for i in range(10):
    out = out.append(pd.read_csv("../../data/raw/raw{0}.csv".format("_" + str(i) if i != 0 else ""))[["screenName", "query"]])

# %% [markdown]
# # Filter the CSVs to only contain followed-following relationships between Senators

# %%
handles = pd.read_csv("../../data/handles.csv")

out = out[out["screenName"].isin(handles["Handle"])]
out["query"] = out["query"].apply(lambda x : x.split("/")[-1])
out = out.reset_index(drop = True)
out.columns = ["followed", "following"]

# %%
hand_to_name = dict(zip(handles["Handle"], handles["Name"]))

# %%
out.assign(followed = out.followed.apply(lambda x: hand_to_name[x]),
           following = out.following.apply(lambda x: hand_to_name[x])).to_csv("../../data/edges.csv", index = False)

# %%
pd.read_csv("../../data/edges.csv").sort_values(by = "following")
# Out:
#                        followed         following
# 82                IN Todd Young   AK Dan Sullivan
# 104          OK James M. Inhofe   AK Dan Sullivan
# 103              SD Mike Rounds   AK Dan Sullivan
# 102             GA David Perdue   AK Dan Sullivan
# 101           OK James Lankford   AK Dan Sullivan
# 100        ME Angus S. King Jr.   AK Dan Sullivan
# 99           KY Mitch McConnell   AK Dan Sullivan
# 98            MI Gary C. Peters   AK Dan Sullivan
# 97              MT Steve Daines   AK Dan Sullivan
# 96                 RI Jack Reed   AK Dan Sullivan
# 95        RI Sheldon Whitehouse   AK Dan Sullivan
# 94          VT Patrick J. Leahy   AK Dan Sullivan
# 93          CA Dianne Feinstein   AK Dan Sullivan
# 92                MT Jon Tester   AK Dan Sullivan
# 106               IA Joni Ernst   AK Dan Sullivan
# 91              HI Brian Schatz   AK Dan Sullivan
# 89         IL Richard J. Durbin   AK Dan Sullivan
# 88            VA Mark R. Warner   AK Dan Sullivan
# 87       PA Robert P. Casey Jr.   AK Dan Sullivan
# 86            SC Lindsey Graham   AK Dan Sullivan
# 85             WI Tammy Baldwin   AK Dan Sullivan
# 84              LA John Kennedy   AK Dan Sullivan
# 83          DE Thomas R. Carper   AK Dan Sullivan
# 81          MA Elizabeth Warren   AK Dan Sullivan
# 80             MN Amy Klobuchar   AK Dan Sullivan
# 79                IN Mike Braun   AK Dan Sullivan
# 78              ND Kevin Cramer   AK Dan Sullivan
# 77            AZ Kyrsten Sinema   AK Dan Sullivan
# 76              LA Bill Cassidy   AK Dan Sullivan
# 90           HI Mazie K. Hirono   AK Dan Sullivan
# ...                         ...               ...
# 3785         MS Roger F. Wicker   WA Patty Murray
# 3757           MN Amy Klobuchar   WA Patty Murray
# 3755    NH Margaret Wood Hassan   WA Patty Murray
# 3754          MI Gary C. Peters   WA Patty Murray
# 3753        MA Edward J. Markey   WA Patty Murray
# 3752  NV Catherine Cortez Masto   WA Patty Murray
# 3751          AZ Kyrsten Sinema   WA Patty Murray
# 3821         WY Michael B. Enzi   WA Patty Murray
# 3756   NY Kirsten E. Gillibrand   WA Patty Murray
# 3766              ID Mike Crapo   WA Patty Murray
# 3765             NE Deb Fischer   WA Patty Murray
# 3768            AR John Boozman   WA Patty Murray
# 3783         TN Lamar Alexander   WA Patty Murray
# 3782        MD Chris Van Hollen   WA Patty Murray
# 3781        CA Dianne Feinstein   WA Patty Murray
# 3780    DE Christopher A. Coons   WA Patty Murray
# 3779               RI Jack Reed   WA Patty Murray
# 3767             WI Ron Johnson   WA Patty Murray
# 3777         IL Tammy Duckworth   WA Patty Murray
# 3778         HI Mazie K. Hirono   WA Patty Murray
# 3774               VA Tim Kaine   WA Patty Murray
# 3773             ND John Hoeven   WA Patty Murray
# 3772          ID James E. Risch   WA Patty Murray
# 3771        MA Elizabeth Warren   WA Patty Murray
# 3770         NM Martin Heinrich   WA Patty Murray
# 3769           WY John Barrasso   WA Patty Murray
# 3776           WI Tammy Baldwin   WA Patty Murray
# 3763        CA Kamala D. Harris   WA Patty Murray
# 3820      CT Christopher Murphy    WI Ron Johnson
# 3819      NY Charles E. Schumer  WI Tammy Baldwin
#
# [3823 rows x 2 columns]
