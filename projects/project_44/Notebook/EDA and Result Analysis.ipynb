# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image
import re
import collections
from tqdm.notebook import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Below are the figures that we use for the AutoPhrase Web.
# The sample dataset is DBLP.5K.txt
# “DBLP.5k”, which is the first 5000 lines on the “DBLP” file and it contains the topical keyphrases from the scientific paper domain.

# %% [markdown]
# ### Input Analysis (EDA)
#
# What are the length distributions of documents and sentences? Any outliers?
#
# This image shows the each line number of word directly to the users.

# %%
Image("../data/eda/word_distribution.png")

# %% [markdown]
# Boxplot Visual would give a better view of the length of documents.

# %%
Image("../data/eda/box_plot_word_length.png")

# %% [markdown]
# After removing the outliers..
#
# It shows the distribution of word length.

# %%
Image("../data/eda/cleaned_set.png")

# %% [markdown]
# It shows the token frequency in desending order. We can see there is more than 7000 tokens in the file and the most fequence words is greater than 1000 times.

# %%
Image("../data/eda/tokens_freq.png")

# %% [markdown]
# It shows the top 20 frequent words in tokenization step. The most freqnent word is of with 1700+ times in the input text.

# %%
Image("../data/eda/tokens_top20_words.png")

# %% [markdown]
# This is the basic number of sentense and the statistic of the text info.

# %%
f = open("../data/eda/description.txt", "r")
print(f.read())
# Out:
# There are 4007 sentences in this input text file. The mean of the input text word length is around 9 for each sentence with the standard deviation 13. Number of Rare tokens is 6768 (which defined as the the number of tokens is less than 5).

# %% [markdown]
# ### Output Analysis
#
# Run AutoPhrase, and then plot the quality score distribution of single-word and multi-word phrases separately.  As we can see, the whole performance of multi-words performs worse than a single word, because there are different combinations that can form from unigram and the single word is only itself without any adds-on. There might be some special cases when there are some combinations of high-quality phrases that are higher than a single word, which is much more meaningful than the single phrase. It can be explained by the meaning of a multi-word phrase that is much more meaningful than a single word and the multi-word phrase fulfills the concordance criteria than a single word, because a single word does not have any context related word connecting with it.

# %%
Image("../data/outputs/multi_value_distribution.png")

# %%
Image("../data/outputs/single_value_distribution.png")

# %%
Image("../data/outputs/comparison_quality_score.png")

# %% [markdown]
# This is the word frequent with the corresponding autophrase score.

# %%
Image("../data/outputs/freq_score_plot.png")

# %% [markdown]
# ### TF-IDF & AutoPhrase results
#
# AutoPhrase results include sets of sorted quality phrases but sometimes they are not “high quality” enough even with high quality scores. We use TF-IDF Score* AutoPhrase quality score to measure the “quality” of a phrase.
# In information retrieval, tf–idf/TF*IDF/TFIDF (short for term frequency–inverse document frequency), is a numerical statistic that is intended to reflect how important a word is to a document in a collection or corpus. It is often used as a weighting factor in searches of information retrieval, text mining, and user modeling.
# We use the TfidfVectorizer class from the sklearn.feature_extraction.text library to perform TF-IDF analysis and combine it with the AutoPhrase result.
#
# We use the input text analyzing with TF-IDF and generate the word with corresponding quality values. After normalizing, we multiply the value with the Autophrase result and select the top 20 high quality phrases, which make the word cloud much more meaningful than only using the Autophrase itself only.

# %%
#tf-idf top 20 for single word
res = pd.read_csv('../data/outputs/tfidfsingle.csv')
res.head(20)
# Out:
#               Word     Score
# 0          systems  1.000000
# 1             data  0.986594
# 2         database  0.945130
# 3               3d  0.713369
# 4        databases  0.609674
# 5      information  0.554792
# 6      programming  0.546746
# 7            using  0.494745
# 8         modeling  0.490921
# 9            model  0.428595
# 10  objectoriented  0.425043
# 11        language  0.422819
# 12          mining  0.419279
# 13      management  0.417808
# 14             web  0.388956
# 15      algorithms  0.373921
# 16       knowledge  0.370413
# 17          models  0.369761
# 18           paper  0.362441
# 19          design  0.357222

# %%
#autophrase top 20 single
ds = pd.read_csv('../data/outputs/qualitysingle.csv')
ds.head(20)
# Out:
#        Score            Word
# 0   0.717242           range
# 1   0.709456        language
# 2   0.707983     information
# 3   0.706008          design
# 4   0.705491           logic
# 5   0.704934        database
# 6   0.702155      management
# 7   0.700830      processing
# 8   0.700649          object
# 9   0.700148           model
# 10  0.698704           human
# 11  0.698285           based
# 12  0.697617  objectoriented
# 13  0.696743      relational
# 14  0.696731             web
# 15  0.695662        approach
# 16  0.694926         digital
# 17  0.694528       knowledge
# 18  0.693406        analysis
# 19  0.692342        internet

# %%
#multiplication top 20 single
mul = pd.read_csv('../data/outputs/multiplicationsingle.csv')
mul.head(20)
# Out:
#               Word     Score
# 0          systems  0.680173
# 1             data  0.678809
# 2         database  0.666254
# 3        databases  0.402040
# 4               3d  0.396027
# 5      information  0.392783
# 6         modeling  0.328645
# 7            model  0.300080
# 8         language  0.299972
# 9   objectoriented  0.296517
# 10      management  0.293366
# 11          mining  0.287376
# 12             web  0.270998
# 13       knowledge  0.257262
# 14          design  0.252202
# 15          models  0.246027
# 16           paper  0.245922
# 17      algorithms  0.244394
# 18           logic  0.239938
# 19        analysis  0.239132

# %%
#tf-idf top 20 multi
res = pd.read_csv('../data/outputs/tfidfmulti.csv')
res.head(20)
# Out:
#                         Word     Score
# 0           database systems  1.000000
# 1                data mining  0.937370
# 2        information systems  0.523989
# 3       programming language  0.483070
# 4          logic programming  0.470176
# 5    objectoriented database  0.415367
# 6           query processing  0.412304
# 7        knowledge discovery  0.364865
# 8               range images  0.364566
# 9      information retrieval  0.326568
# 10            database desig  0.320534
# 11           data structures  0.297329
# 12     programming languages  0.261428
# 13       relational database  0.257814
# 14          machine learning  0.235670
# 15      knowledge management  0.235513
# 16        management systems  0.222783
# 17  objectoriented databases  0.217245
# 18       concurrency control  0.212647
# 19           eine einführung  0.211326

# %%
#autophrase top 20 multi
ds = pd.read_csv('../data/outputs/qualitymulti.csv')
ds.head(20)
# Out:
#        Score                         Word
# 0   0.939180         knowledge management
# 1   0.930222        information retrieval
# 2   0.921603        programming languages
# 3   0.916816               query language
# 4   0.909308          relational database
# 5   0.906608       transaction processing
# 6   0.903549          concurrency control
# 7   0.901075         relational databases
# 8   0.897878  database management systems
# 9   0.894858             machine learning
# 10  0.888096             database systems
# 11  0.887508                  data mining
# 12  0.882880              database design
# 13  0.882317              data structures
# 14  0.870314            logic programming
# 15  0.861052             natural language
# 16  0.853968      artificial intelligence
# 17  0.849867       information technology
# 18  0.831146          information systems
# 19  0.823361              data management

# %%
#multiplication top 20 multi
mul = pd.read_csv('../data/outputs/multiplicationmulti.csv')
mul.head(20)
# Out:
#                         Word     Score
# 0           database systems  0.888096
# 1                data mining  0.831924
# 2        information systems  0.435511
# 3          logic programming  0.409201
# 4           query processing  0.320402
# 5      information retrieval  0.303781
# 6    objectoriented database  0.287197
# 7        knowledge discovery  0.283968
# 8               range images  0.278639
# 9            data structures  0.262339
# 10            database desig  0.244616
# 11     programming languages  0.240933
# 12       relational database  0.234432
# 13      knowledge management  0.221189
# 14          machine learning  0.210891
# 15       concurrency control  0.192137
# 16  objectoriented databases  0.174470
# 17           database design  0.173785
# 18   artificial intelligence  0.170365
# 19       database management  0.158127

# %% [markdown]
# Instead of using AutoPhrase result only,  we use (AutoPhrase score * TF-IDF score) as the metric to evaluate the quality of a phrase. Then, we used a word cloud to visualize the phrases with top quality scores, since it is a better representative of the input text corpus.

# %%
#multiplication top 20 combined
final = pd.read_csv('../data/outputs/multiplicationall.csv')
final.head(40)
# Out:
#                        Word  Score
# 0          database systems   0.89
# 1               data mining   0.83
# 2                   systems   0.68
# 3                      data   0.68
# 4                  database   0.67
# 5       information systems   0.44
# 6         logic programming   0.41
# 7                 databases   0.40
# 8                        3d   0.40
# 9               information   0.39
# 10                 modeling   0.33
# 11         query processing   0.32
# 12    information retrieval   0.30
# 13                    model   0.30
# 14                 language   0.30
# 15           objectoriented   0.30
# 16               management   0.29
# 17                   mining   0.29
# 18  objectoriented database   0.29
# 19      knowledge discovery   0.28
# 20             range images   0.28
# 21                      web   0.27
# 22          data structures   0.26
# 23                knowledge   0.26
# 24                   design   0.25
# 25                   models   0.25
# 26                    paper   0.25
# 27           database desig   0.24
# 28               algorithms   0.24
# 29    programming languages   0.24
# 30                    logic   0.24
# 31                 analysis   0.24
# 32      relational database   0.23
# 33             introduction   0.23
# 34                    range   0.22
# 35                 approach   0.22
# 36                   object   0.22
# 37             applications   0.22
# 38     knowledge management   0.22
# 39         machine learning   0.21

# %% [markdown]
# ### Sentiment Analysis

# %% [markdown]
# Sentiment analysis (or opinion mining) is a natural language processing technique used to determine whether data is positive, negative or neutral.
# We use textblob to give both a polarity and subjectivity score on each sentence of the text corpus. Then plot a distribution based on that. This would give user an insight on whether the corpus is positive or negative overall and if it’s more rational or emotional.

# %% [markdown]
# Figures shown below are the sentiment analysis result for DBLP.5K.txt. Since this a scientific journal, not surprisingly the polarity and subjectivity is zero for most sentences, meaning most of them of quite neutral and objective. This meets our expectation.

# %%
Image("../data/outputs/sentiment_polarity_distribution.png")

# %%
Image("../data/outputs/sentiment_subjectivity_distribution.png")
