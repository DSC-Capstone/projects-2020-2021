# %% [markdown]
# # DSC180A Checkpoint #2

# %% [markdown]
# ## Setup

# %%
import re
import pandas as pd
import os
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## ETL & feature extraction

# %%
# Transform smali file to call-anlysis table
def process_smali(sml):
    methods = pd.DataFrame(re.findall(r'method.* (\w+)[(].+[)].+;([\d\D]*?)\.end method', sml))
    if len(methods) == 0:
        return -1
    
    def process_method(x):
        res = pd.DataFrame(re.findall(r'invoke-(\w{5,9})\s.+}, (.*);->(.+)[(]', x[1]))
        if len(res) == 0:
            return
        res.columns = ['invoke_type', 'package_long', 'call']
        res['method'] = x[0]
        res['package'] = res.package_long.apply(lambda x:x[1:x.find('/')])
        res['type'] = res.package.apply(lambda x:x if x in ['android', 'androidx', 'google', 'java', 'javax', 'kotlin'] else 'self')
        return res
    
    dfs = methods.apply(process_method, axis=1)
    try:
        return pd.concat(dfs.tolist())
    except:
        return -1

# %%
# Generate Markov Chain
def generate_chain(df):
    return df.type.value_counts() / len(df)

# %%
# Apply smali file analysis to all smali files in an apk
def process_apk(path, apk_name):
    print(path)
    i = 0
    df = pd.DataFrame()
    num_apicalls = 0
    for root, dirs, files in os.walk(path, topdown=False):  
        for name in files:
            if name.endswith('.smali'):
                if i >= 85000:
                    break
                f = open(os.path.join(root, name))
                sml_df = process_smali(f.read())
                if type(sml_df) == int:
                    pass
                else:
                    df = pd.concat([df, sml_df], ignore_index=True)
                f.close()
                i += 1
    df['name'] = apk_name        
    return df

# %%
# Parse all training data in directory which contains all malware or benign-ware
def parse_all(path, is_mal):
    fin = pd.DataFrame()
    wares = [i for i in os.listdir(path)]
    if is_mal:
        for d in wares:
            d_path = path + '/' + d
            varieties = [i for i in os.listdir(d_path)]
            for v in varieties:
                v_path = d_path + '/' + v
                try:
                    df = process_apk(v_path, d + ' ' + v)
                    fin = pd.concat([fin, df], ignore_index=True)
                    fin.to_csv('fin.csv')
                    print('finish {}'.format(d + ' ' + v))
                except:
                    pass
    else:
        for d in wares:
            d_path = path + '/' + d
            try:
                df = process_apk(d_path, d)
                fin = pd.concat([fin, df], ignore_index=True)
                fin.to_csv('benigns.csv')
                print('finish {}'.format(d))
            except:
                pass
    return dfs

# %%
def parse_pp(wares, is_mal):
    fin = pd.DataFrame()
    path = '/teams/DSC180A_FA20_A00/a04malware/malware'
    if is_mal:
        for d in wares:
            d_path = path + '/' + d
            varieties = [i for i in os.listdir(d_path)]
            for v in varieties:
                v_path = d_path + '/' + v
                try:
                    df = process_apk(v_path, d + ' ' + v)
                    fin = pd.concat([fin, df], ignore_index=True)
                    fin.to_csv('ff4.csv')
                    print('finish {}'.format(d + ' ' + v))
                except:
                    pass

# %% [markdown]
# ## Data Parsing

# %%
os.listdir('/teams/DSC180A_FA20_A00/a04malware/popular-apps')[:200]
# Out:
# ['net.updategames.granny',
#  'com.gameloft.android.ANMP.GloftA8HM',
#  'com.devsisters.gb',
#  'com.huobi.cn',
#  'com.gretech.gomplayerko',
#  'com.buffstudio.sevendays_free',
#  'com.Fren2y.FlyBattle',
#  'tasty.buzzfeed.japan.recipes.cooking',
#  'com.celiniumapps.gotseven',
#  'com.cyberbots.roulette',
#  'com.sega.comixzone',
#  'com.MIPL.ShreeAnnapurnaTiffin',
#  'kr.ac.mokwon',
#  'com.facebook.katana',
#  'com.gasterus.polsampaifinish',
#  'com.OsamahAsad.TastiestChineseCuisine',
#  'com.aircrunch.shopalerts',
#  'com.han.dominoes',
#  'ru.omdevelopment.ref.qurangerman.free',
#  'com.microsoft.todos',
#  'com.tabkeey.taapseewallpaper',
#  'com.framingitup.app',
#  'com.roboxy.muruganclocklivewallpaper',
#  'com.nimblebit.bitcity',
#  'com.iedutainments.free.no',
#  'com.appbuilder.u1180923p1557621',
#  'jp.co.cheep.markun.settings',
#  'com.baseballguideandtips',
#  'com.solosalon.servicer',
#  'net.minhawebradio.joelcecilio',
#  'com.luc.tetvn',
#  'com.AtPlayMusic.NoteRacerTrombone',
#  'com.sega.kidcham',
#  'com.HarauStudio.EXOSong',
#  'com.wow.sticker',
#  'com.mysteryshopping.mysteryshoppingsolutions',
#  'com.wb.goog.squadmoji',
#  'com.hulu.plus',
#  'com.pink.neon.rose.theme',
#  'com.kisah4khalifahrasyidin.agastudio',
#  'air.com.hypah.io.slither',
#  'com.melink.android',
#  'com.kabouzeid.gramophone',
#  'com.kitkatandroid.keyboard',
#  'com.oristats.habitbull',
#  'com.thebestonepp.watchmoviesonline',
#  'com.srkphotography.smsjokesstatusfactory',
#  'com.zombieracing.duaxebansung',
#  'com.walmart.android',
#  'com.romale.vr.mountainshills.pack',
#  'com.Christmas.Salon.Dress.Designer',
#  'phi.tv',
#  'com.mydtc',
#  'com.alien.music.youme',
#  'com.msi.logogame',
#  'com.madhumadhiapps.loveimageshd4koffline',
#  'org.videolan.vlc',
#  'com.zplayworld.popstar',
#  'com.ubisoft.dance.justdance2015companion',
#  'com.kollywoodapps.luckystonefinder_tamil',
#  'ovh.sauzanaprod.listecadeau',
#  'com.facebook.orca',
#  'com.banglaappsmela.bdsarangso',
#  'com.app_lubbockct.layout',
#  'ua.com.citysites.belorechensk',
#  'com.mutationsonline',
#  'com.statussaver.videos.download.savestory.saveallstatus',
#  'com.bnha.boniface',
#  'aplove.pitha_recipe',
#  'com.chisanu.waifuhologram',
#  'com.vishalbymi.PM_Yojna',
#  'com.neilredfern.pubgolfscorecardv2',
#  'my.com.tshirtking',
#  'air.com.pixelfederation.diggy',
#  'com.altatawwar.shaheen',
#  'mobile.expert.app',
#  'com.miniclip.plagueinc',
#  'com.inos.quiz.futbol',
#  'net.newvibrations.baskavoda2017',
#  'org.edx.mobile',
#  'com.istoetaxi.motorista',
#  'com.Tobit.android.Slitte7180107812',
#  'mobi.andromedia.games.lightsoff',
#  'com.newappmatrix.mathematicsgame',
#  'com.optimumdroid.howmanybaby.willihave.prank',
#  'com.Girls.Beauty.Spa.Makeup.Artist',
#  'com.pointsoft.dm',
#  'com.deepforestmedia.sdktest.inandroidtest.today',
#  'com.musicshopstudios.narutoshippuuden.music.shop',
#  'com.shedunoo.booster.cleaner',
#  'ru.serjik.christmaslive',
#  'me.doubledutch.xktjx.partnersretreat2017',
#  'com.illuminationgames.aa3',
#  'com.bhss.d4expert',
#  'com.merakiapp.zifmzimbabwefreestreamingmusicradiostation',
#  'com.korean.hangugmal.hangugeo.chosonmal.keyboard.hebrewkeyboard.type.free.infra',
#  'com.peacockcrackers.app',
#  'titiknoltilesinc.ozunapiano',
#  'com.advaitgps.vts',
#  'com.imaginstudio.imagetools.pixellab',
#  'com.digisol.dlive',
#  'com.SilsenseTechnologies.Engram',
#  'com.disney.starwarshub_goo',
#  'com.colossalfactory.quicktext',
#  'com.varnitechnologies.swaminarayan',
#  'radio.ecuastereo',
#  'com.egaming.pharaohriches',
#  'com.transferwise.android',
#  'com.app_uniquegadgets.layout',
#  'com.google.android.apps.tasks',
#  'com.naver.linewebtoon',
#  'com.go.RingStone.c1',
#  'com.jogemapps.ceramahustadzmaulanamp3offline',
#  'com.froogloid.kring.google.zxing.client.android',
#  'com.simplehabit.simplehabitapp',
#  'com.Chupa.superwariors',
#  'com.cnn.mobile.android.tv',
#  'org.brilliant.android',
#  'com.mochibits.hexario.google',
#  'com.candy.kathah',
#  'com.geishatokyo.snowballio',
#  'popular-apps',
#  'br.com.app.gpuuu1552436.gpuuu5142c9bb55f4cab7c0d5ec1caa19bc91',
#  'com.quantum.whatsappstatus',
#  'com.joy.note1',
#  'com.fungames.flightpilot',
#  'com.relaxmeditation.sangdroid',
#  'com.CL.GuideForCraigslist',
#  'com.fs.sha29',
#  'br.com.eem.cem',
#  'media.apps.games.andro.geneballjumpjumpjump',
#  'com.app.p8519IG',
#  'com.cake.expert.developer',
#  'canadakoreanmall.ckmall',
#  'com.businessoft.taxidriver',
#  'it.Fitnessitaly.MobilePublic',
#  'com.tppm.christmas.countdown.wallpaper',
#  'com.radioworld.chanquetefmapp',
#  'com.besthd.shengdan',
#  'another.music.player',
#  'com.rc.earthonline.livestreetview.liveworldwebcams',
#  'com.viralstudio.masuk.pak.eko',
#  'com.maksimedia.diljit.dosanjh',
#  'com.ladybugg.kitsh',
#  'br.com.app.gpuu1433592.gpuu7d442804e3f91686c53b433a3b63443d',
#  'com.NlightenedTouch.ExtremeWBFPro',
#  'kz.sirius.siriuschat',
#  'mobi.infolife.ezweather',
#  'com.dena.a12026418',
#  'jp.or.jwa.sora_annai.android',
#  'com.wCSpinTheBottle_3738141',
#  'com.fgsoft.blockpuzzle2',
#  'com.dalil.moslimfiaiidaladha',
#  'com.picstudio.s.photo.editor.hd',
#  'com.openratio.karolinska.reprolab',
#  'com.masrio.sudoku',
#  'com.ChristmasSongsXmasRingtones.BestMelodiesFree',
#  'games.wfs.anothereden',
#  'jpark.AOS5',
#  'com.khaanistudio.super_hot_super_quick',
#  'com.newzinefinal.news',
#  'com.amazon.mShop.android.shopping',
#  'com.coinbase.android',
#  'com.ubisoft.dance.JustDance',
#  'com.PicInsta.Girl.Collage.Editor.Dr',
#  'com.santos.erik.middoff',
#  'com.ken.soul_divine',
#  'com.CoCoC.SmartTools.PlayByTab.RovioPCMehanik.Gemstonesdetector',
#  'com.PixelPerfectDude.SkiJump',
#  'com.jrll.musicasalsagratis',
#  'com.lifesofts.photo.christmasframes',
#  'com.adminapps.android5958fc2770cfe',
#  'io.silph.npc',
#  'com.appybuilder.jamestt676.KennyG',
#  'com.universotec.clipadasff',
#  'com.wTheAudiopedia_8069473',
#  'com.ChristmasNightLiveWallpaperApp',
#  'it.seipiu.seiinmovimento',
#  'com.myblosom.LauraPausiniAllSongLyrics',
#  'com.musica.palco.CardiBSongs2020',
#  'com.lulu.lulubox',
#  'com.websprix.ethiovstrippedversion',
#  'com.ubisoft.mightyquest',
#  'com.fezi.demilovato',
#  'com.sigescolar',
#  'com.damonicsapp.earring',
#  'com.applicationreves.mesreves',
#  'com.wb.goog.dc.legends',
#  'com.empire.grow.rome',
#  'com.knbmedia.findthemallpetlite',
#  'com.kokoc.mixit',
#  'com.desainpembatasruangan.nyelonongdroid',
#  'com.vaibhavlakhera.materialcolorpicker',
#  'com.rgastudio.hdmobiltv',
#  'com.jisco.cilmi',
#  'com.blwp.newyear',
#  'com.andromo.dev24540.app152191',
#  'com.ted.android',
#  'com.umamkhoir.laguenak',
#  'com.ram.newyearphotoframes']

# %%
features_benign = pd.read_csv('benigns.csv')
features_benign = features_benign.drop('Unnamed: 0',axis=1)

# %%
len(features_benign.name.unique())
# Out:
# 143

# %%
features_mal = features_mal.drop('Unnamed: 0',axis=1)

# %%
features_mal = pd.read_csv('malware_ma.csv')

# %%
chains_mal
# Out:
#                        android  androidx      java   javax  kotlin      self
# name
# Andup variety1         49420.0       0.0  119366.0  1028.0     0.0   69666.0
# BankBot variety1        2636.0       0.0    1588.0     0.0     0.0      36.0
# BankBot variety2       69411.0       0.0   48170.0     0.0     0.0    2267.0
# BankBot variety3      125295.0       0.0   57518.0   729.0     0.0   21401.0
# BankBot variety4        4083.0       0.0    6694.0     0.0     0.0    4882.0
# ...                        ...       ...       ...     ...     ...       ...
# Univert variety1        8850.0       0.0    4880.0     0.0     0.0     250.0
# Vidro variety1          3486.0       0.0   13587.0    65.0     0.0    7408.0
# VikingHorde variety1   21344.0       0.0   27995.0    62.0     0.0   42099.0
# Vmvol variety1           493.0       0.0    8759.0     0.0     0.0   10704.0
# Youmi variety1        149910.0       0.0  446652.0  5194.0     0.0  467492.0
#
# [77 rows x 6 columns]

# %%
# Malware
path_mal = '/teams/DSC180A_FA20_A00/a04malware/malware' # Path
dfs = parse_all(path_mal, 1)87 prank

# %%
# Safeware
path_saf = '/teams/DSC180A_FA20_A00/a04malware/popular-apps' # Path
features_saf = parse_all(path_saf, 0)
# Out:
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/net.updategames.granny
# finish net.updategames.granny
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.gameloft.android.ANMP.GloftA8HM
# finish com.gameloft.android.ANMP.GloftA8HM
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.devsisters.gb
# finish com.devsisters.gb
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.huobi.cn
# finish com.huobi.cn
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.gretech.gomplayerko
# finish com.gretech.gomplayerko
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.buffstudio.sevendays_free
# finish com.buffstudio.sevendays_free
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.Fren2y.FlyBattle
# finish com.Fren2y.FlyBattle
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/tasty.buzzfeed.japan.recipes.cooking
# finish tasty.buzzfeed.japan.recipes.cooking
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.celiniumapps.gotseven
# finish com.celiniumapps.gotseven
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.cyberbots.roulette
# finish com.cyberbots.roulette
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.sega.comixzone
# finish com.sega.comixzone
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.MIPL.ShreeAnnapurnaTiffin
# finish com.MIPL.ShreeAnnapurnaTiffin
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/kr.ac.mokwon
# finish kr.ac.mokwon
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.facebook.katana
# finish com.facebook.katana
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.gasterus.polsampaifinish
# finish com.gasterus.polsampaifinish
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.OsamahAsad.TastiestChineseCuisine
# finish com.OsamahAsad.TastiestChineseCuisine
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.aircrunch.shopalerts
# finish com.aircrunch.shopalerts
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.han.dominoes
# finish com.han.dominoes
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/ru.omdevelopment.ref.qurangerman.free
# finish ru.omdevelopment.ref.qurangerman.free
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.microsoft.todos
# finish com.microsoft.todos
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.tabkeey.taapseewallpaper
# finish com.tabkeey.taapseewallpaper
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.framingitup.app
# finish com.framingitup.app
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.roboxy.muruganclocklivewallpaper
# finish com.roboxy.muruganclocklivewallpaper
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.nimblebit.bitcity
# finish com.nimblebit.bitcity
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.iedutainments.free.no
# finish com.iedutainments.free.no
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.appbuilder.u1180923p1557621
# finish com.appbuilder.u1180923p1557621
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/jp.co.cheep.markun.settings
# finish jp.co.cheep.markun.settings
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.baseballguideandtips
# finish com.baseballguideandtips
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.solosalon.servicer
# finish com.solosalon.servicer
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/net.minhawebradio.joelcecilio
# finish net.minhawebradio.joelcecilio
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.luc.tetvn
# finish com.luc.tetvn
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.AtPlayMusic.NoteRacerTrombone
# finish com.AtPlayMusic.NoteRacerTrombone
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.sega.kidcham
# finish com.sega.kidcham
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.HarauStudio.EXOSong
# finish com.HarauStudio.EXOSong
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.wow.sticker
# finish com.wow.sticker
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.mysteryshopping.mysteryshoppingsolutions
# finish com.mysteryshopping.mysteryshoppingsolutions
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.wb.goog.squadmoji
# finish com.wb.goog.squadmoji
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.hulu.plus
# finish com.hulu.plus
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.pink.neon.rose.theme
# finish com.pink.neon.rose.theme
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.kisah4khalifahrasyidin.agastudio
# finish com.kisah4khalifahrasyidin.agastudio
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/air.com.hypah.io.slither
# finish air.com.hypah.io.slither
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.melink.android
# finish com.melink.android
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.kabouzeid.gramophone
# finish com.kabouzeid.gramophone
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.kitkatandroid.keyboard
# finish com.kitkatandroid.keyboard
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.oristats.habitbull
# finish com.oristats.habitbull
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.thebestonepp.watchmoviesonline
# finish com.thebestonepp.watchmoviesonline
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.srkphotography.smsjokesstatusfactory
# finish com.srkphotography.smsjokesstatusfactory
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.zombieracing.duaxebansung
# finish com.zombieracing.duaxebansung
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.walmart.android
# finish com.walmart.android
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.romale.vr.mountainshills.pack
# finish com.romale.vr.mountainshills.pack
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.Christmas.Salon.Dress.Designer
# finish com.Christmas.Salon.Dress.Designer
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/phi.tv
# finish phi.tv
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.mydtc
# finish com.mydtc
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.alien.music.youme
# finish com.alien.music.youme
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.msi.logogame
# finish com.msi.logogame
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.madhumadhiapps.loveimageshd4koffline
# finish com.madhumadhiapps.loveimageshd4koffline
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/org.videolan.vlc
# finish org.videolan.vlc
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.zplayworld.popstar
# finish com.zplayworld.popstar
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.ubisoft.dance.justdance2015companion
# finish com.ubisoft.dance.justdance2015companion
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.kollywoodapps.luckystonefinder_tamil
# finish com.kollywoodapps.luckystonefinder_tamil
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/ovh.sauzanaprod.listecadeau
# finish ovh.sauzanaprod.listecadeau
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.facebook.orca
# finish com.facebook.orca
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.banglaappsmela.bdsarangso
# finish com.banglaappsmela.bdsarangso
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.app_lubbockct.layout
# finish com.app_lubbockct.layout
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/ua.com.citysites.belorechensk
# finish ua.com.citysites.belorechensk
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.mutationsonline
# finish com.mutationsonline
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.statussaver.videos.download.savestory.saveallstatus
# finish com.statussaver.videos.download.savestory.saveallstatus
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.bnha.boniface
# finish com.bnha.boniface
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/aplove.pitha_recipe
# finish aplove.pitha_recipe
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.chisanu.waifuhologram
# finish com.chisanu.waifuhologram
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.vishalbymi.PM_Yojna
# finish com.vishalbymi.PM_Yojna
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.neilredfern.pubgolfscorecardv2
# finish com.neilredfern.pubgolfscorecardv2
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/my.com.tshirtking
# finish my.com.tshirtking
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/air.com.pixelfederation.diggy
# finish air.com.pixelfederation.diggy
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.altatawwar.shaheen
# finish com.altatawwar.shaheen
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/mobile.expert.app
# finish mobile.expert.app
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.miniclip.plagueinc
# finish com.miniclip.plagueinc
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.inos.quiz.futbol
# finish com.inos.quiz.futbol
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/net.newvibrations.baskavoda2017
# finish net.newvibrations.baskavoda2017
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/org.edx.mobile
# finish org.edx.mobile
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.istoetaxi.motorista
# finish com.istoetaxi.motorista
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.Tobit.android.Slitte7180107812
# finish com.Tobit.android.Slitte7180107812
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/mobi.andromedia.games.lightsoff
# finish mobi.andromedia.games.lightsoff
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.newappmatrix.mathematicsgame
# finish com.newappmatrix.mathematicsgame
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.optimumdroid.howmanybaby.willihave.prank
# finish com.optimumdroid.howmanybaby.willihave.prank
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.Girls.Beauty.Spa.Makeup.Artist
# finish com.Girls.Beauty.Spa.Makeup.Artist
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.pointsoft.dm
# finish com.pointsoft.dm
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.deepforestmedia.sdktest.inandroidtest.today
# finish com.deepforestmedia.sdktest.inandroidtest.today
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.musicshopstudios.narutoshippuuden.music.shop
# finish com.musicshopstudios.narutoshippuuden.music.shop
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.shedunoo.booster.cleaner
# finish com.shedunoo.booster.cleaner
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/ru.serjik.christmaslive
# finish ru.serjik.christmaslive
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/me.doubledutch.xktjx.partnersretreat2017
# finish me.doubledutch.xktjx.partnersretreat2017
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.illuminationgames.aa3
# finish com.illuminationgames.aa3
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.bhss.d4expert
# finish com.bhss.d4expert
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.merakiapp.zifmzimbabwefreestreamingmusicradiostation
# finish com.merakiapp.zifmzimbabwefreestreamingmusicradiostation
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.korean.hangugmal.hangugeo.chosonmal.keyboard.hebrewkeyboard.type.free.infra
# finish com.korean.hangugmal.hangugeo.chosonmal.keyboard.hebrewkeyboard.type.free.infra
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.peacockcrackers.app
# finish com.peacockcrackers.app
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/titiknoltilesinc.ozunapiano
# finish titiknoltilesinc.ozunapiano
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.advaitgps.vts
# finish com.advaitgps.vts
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.imaginstudio.imagetools.pixellab
# finish com.imaginstudio.imagetools.pixellab
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.digisol.dlive
# finish com.digisol.dlive
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.SilsenseTechnologies.Engram
# finish com.SilsenseTechnologies.Engram
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.disney.starwarshub_goo
# finish com.disney.starwarshub_goo
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.colossalfactory.quicktext
# finish com.colossalfactory.quicktext
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.varnitechnologies.swaminarayan
# finish com.varnitechnologies.swaminarayan
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/radio.ecuastereo
# finish radio.ecuastereo
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.egaming.pharaohriches
# finish com.egaming.pharaohriches
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.transferwise.android
# finish com.transferwise.android
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.app_uniquegadgets.layout
# finish com.app_uniquegadgets.layout
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.google.android.apps.tasks
# finish com.google.android.apps.tasks
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.naver.linewebtoon
# finish com.naver.linewebtoon
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.go.RingStone.c1
# finish com.go.RingStone.c1
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.jogemapps.ceramahustadzmaulanamp3offline
# finish com.jogemapps.ceramahustadzmaulanamp3offline
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.froogloid.kring.google.zxing.client.android
# finish com.froogloid.kring.google.zxing.client.android
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.simplehabit.simplehabitapp
# finish com.simplehabit.simplehabitapp
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.Chupa.superwariors
# finish com.Chupa.superwariors
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.cnn.mobile.android.tv
# finish com.cnn.mobile.android.tv
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/org.brilliant.android
# finish org.brilliant.android
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.mochibits.hexario.google
# finish com.mochibits.hexario.google
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.candy.kathah
# finish com.candy.kathah
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.geishatokyo.snowballio
# finish com.geishatokyo.snowballio
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/popular-apps
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/br.com.app.gpuuu1552436.gpuuu5142c9bb55f4cab7c0d5ec1caa19bc91
# finish br.com.app.gpuuu1552436.gpuuu5142c9bb55f4cab7c0d5ec1caa19bc91
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.quantum.whatsappstatus
# finish com.quantum.whatsappstatus
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.joy.note1
# finish com.joy.note1
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.fungames.flightpilot
# finish com.fungames.flightpilot
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.relaxmeditation.sangdroid
# finish com.relaxmeditation.sangdroid
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.CL.GuideForCraigslist
# finish com.CL.GuideForCraigslist
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.fs.sha29
# finish com.fs.sha29
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/br.com.eem.cem
# finish br.com.eem.cem
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/media.apps.games.andro.geneballjumpjumpjump
# finish media.apps.games.andro.geneballjumpjumpjump
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.app.p8519IG
# finish com.app.p8519IG
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.cake.expert.developer
# finish com.cake.expert.developer
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/canadakoreanmall.ckmall
# finish canadakoreanmall.ckmall
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.businessoft.taxidriver
# finish com.businessoft.taxidriver
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/it.Fitnessitaly.MobilePublic
# finish it.Fitnessitaly.MobilePublic
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.tppm.christmas.countdown.wallpaper
# finish com.tppm.christmas.countdown.wallpaper
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.radioworld.chanquetefmapp
# finish com.radioworld.chanquetefmapp
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.besthd.shengdan
# finish com.besthd.shengdan
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/another.music.player
# finish another.music.player
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.rc.earthonline.livestreetview.liveworldwebcams
# finish com.rc.earthonline.livestreetview.liveworldwebcams
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.viralstudio.masuk.pak.eko
# finish com.viralstudio.masuk.pak.eko
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.maksimedia.diljit.dosanjh
# finish com.maksimedia.diljit.dosanjh
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.ladybugg.kitsh
# finish com.ladybugg.kitsh
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/br.com.app.gpuu1433592.gpuu7d442804e3f91686c53b433a3b63443d
# finish br.com.app.gpuu1433592.gpuu7d442804e3f91686c53b433a3b63443d
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/com.NlightenedTouch.ExtremeWBFPro
# finish com.NlightenedTouch.ExtremeWBFPro
# /teams/DSC180A_FA20_A00/a04malware/popular-apps/kz.sirius.siriuschat

# %%
format_ser = pd.Series([0] * 6,['self','java','android','kotlin','androidx','javax'])
def form(ser):
    return ser.combine(format_ser, max).fillna(0)
def proc(x):
    return form(x.type.value_counts())

# %%
chains_mal = features_mal.groupby('name').apply(proc)
chains_benign = features_benign.groupby('name').apply(proc)
chains_mal['is_mal'] = [1] * len(chains_mal)
chains_benign['is_mal'] = [0] * len(chains_benign)
chains = pd.concat([chains_mal, chains_benign], ignore_index=True)

# %% [markdown]
# ## Model

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

def ttsplit(X, y):
    return train_test_split(X, y, test_size=0.33, random_state=42)

def baseline_predict(X):
    return X.apply(lambda x:1 if x.num_smali >= 50000 else 0, axis=1)

def build_Log(X_train, y_train, C, max_it):
    return LogisticRegression(fit_intercept=True, C=C, max_iter=max_it).fit(X_train, y_train)

def build_Linear(X_train, y_train):
    return LinearRegression().fit(X_train, y_train)

def build_KN(X_train, y_train, n):
    return KNeighborsClassifier(n_neighbors=n).fit(X_train, y_train)

def accuracy(y_train, y_test, y_predict_train, y_predict_test):
    print('train Accuracy = {}, test Accuracy = {}'.format(accuracy_score(y_train, y_predict_train),
                                                 accuracy_score(y_test, y_predict_test)))

def mse(y_train, y_test, y_predict_train, y_predict_test):
    print('train MSE = {}, test MSE = {}'.format(mean_squared_error(y_train, y_predict_train),
                                                 mean_squared_error(y_test, y_predict_test)))
    return mean_squared_error(y_test, y_predict_test)

# %%
X = chains.drop('is_mal', axis=1)
y = chains.is_mal
X_train, X_test, y_train, y_test = ttsplit(X,y)
reg_log = build_Log(X_train, y_train, 0.1, 1000)
pred_train_log = reg_log.predict(X_train)
pred_test_log = reg_log.predict(X_test)
reg_lin = build_Linear(X_train, y_train, 0.1, 1000)
pred_train_lin = reg_lin.predict(X_train)
pred_test_lin = reg_lin.predict(X_test)
reg_knn = build_KN(X_train, y_train, 0.1, 1000)
pred_train_kn = reg_knn.predict(X_train)
pred_test_kn = reg_knn.predict(X_test)

# %%
accuracy(y_train, y_test, pred_train_log, pred_test_log)
accuracy(y_train, y_test, pred_train_lin, pred_test_lin)
accuracy(y_train, y_test, pred_train_kn, pred_test_kn)

# %%
tn, fp, fn, tp = confusion_matrix(y_test, pred_test).ravel()
(tn, fp, fn, tp)

# %%
pred_train = 
pred_test =

# %% [markdown]
# ## EDA

# %%
chains['pred'] = reg_##.predict(X)
def cate(x):
    r = ''
    if x.is_mal == x.pred:
        r += 'T'
    else:
        r += 'F'
    if x.res == 1:
        r += 'P'
    else:
        r += 'N'
    return r
chains['analysis'] = chains.apply(cate, axis=1)

# %%
fp_df = chains.loc[chains.analysis == 'FP']
fn_df = chains.loc[chains.analysis == 'FN']
tn_df = chains.loc[chains.analysis == 'TN']
tp_df = chains.loc[chains.analysis == 'TP']

# %%
fp_df.describe()

# %%
tn_df.describe()

# %%
fn_df.describe()

# %%
tp_df.describe()

# %%
def advanced_predict(reg, x):
    res = reg.predict(x)
    if res:
        if x.android > 0.4:
            return 1
        return 0
    else:
        return 0

# %%
reg = build_Log(X_train, y_train, 0.1, 1000)
pred_train_adv = [advanced_predict(reg, x) for x in X_train]
pred_test_adv = [advanced_predict(reg, x) for x in X_test]

# %%
accuracy(y_train, y_test, pred_train_adv, pred_test_adv)
tn, fp, fn, tp = confusion_matrix(y_test, pred_test_adv).ravel()
(tn, fp, fn, tp)
