# %%
import pandas as pd
import os
import glob
import ipaddress
import itertools
import numpy as np
import scipy.signal
import matplotlib.pyplot as plt
from scipy.signal import peak_prominences

# %%
fp = '/teams/DSC180A_FA20_A00/b05vpnxray/group2_data/data'
PACKET_TIMESTAMP_UNIT = 'ms'

# %%
filelist = os.listdir(fp)
netflix_files = [f for f in filelist if 'netflix' in f]
prime_files = [f for f in filelist if 'prime' in f]
youtube_files = [f for f in filelist if 'youtube' in f]

n1 = pd.read_csv(os.path.join(fp, netflix_files[1]))
p1 = pd.read_csv(os.path.join(fp, prime_files[0]))
y1 = pd.read_csv(os.path.join(fp, youtube_files[0]))

# %%
[f for f in filelist if 'csv' not in f]
# Out:
# ['.ipynb_checkpoints']

# %%
[f for f in filelist if 'live' in f][0].split('live')
# Out:
# ['tiq004-twitch-', '-011121-22.csv']

# %%
def loop_through_files():
    for filename in filelist:
        streaming_providers = {
            'youtube' : 0,
            'amazonprime': 1,
            'netflix': 2,
            'youtube-live': 3,
            'twitch-live': 4
        }

        if 'live' in filename:
            if 'twitch' in filename:
                provider_int = streaming_providers['twitch-live']
            if 'youtube' in filename:
                provider_int = streaming_providers['youtube-live']
        if 'live' not in filename:
            provider_int = -1
            if 'youtube' in filename:
                provider_int = streaming_providers['youtube']
            if 'amazonprime' in filename:
                provider_int = streaming_providers['amazonprime']
            if 'netflix' in filename:
                provider_int = streaming_providers['netflix']
                
        print(filename + ': ' + str(provider_int))
loop_through_files()
# Out:
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-8.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-16.csv: 2
# tiq004-twitch-live-011121-22.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-9.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-8.csv: -1
# maqader-twitch-live-1112021-5.csv: 4
# chang_amazonprime_3.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-27.csv: 2
# zishun-youtube-live-14.csv: 3
# chang_amazonprime_4.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-20.csv: 2
# zishun-youtube-live-13.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-20.csv: 2
# tiq004-twitch-live-011121-25.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-11.csv: 2
# maqader-twitch-live-1112021-2.csv: 4
# chang_amazonprime_24.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_15.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-1.csv: 2
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-2.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-0.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-1.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-6.csv: 2
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-5.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-18.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-6.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-7.csv: 2
# chang_amazonprime_23.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-29.csv: 2
# arv020_hulu_1080p_1x_vpn_mac_clean_12.csv: -1
# mhrowlan-youtube-1x-vpn-mac-clean-20210108zz.csv: 0
# tiq004-twitch-live-011121-19.csv: 4
# arv020_amazonprime_1080p_1x_vpn_mac_clean_1.csv: 1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_46.csv: 1
# chang_youtube_7.csv: 0
# chang_amazonprime_16.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-1.csv: 2
# arv020_hulu_1080p_1x_vpn_mac_clean_27.csv: -1
# chang_youtube_19.csv: 0
# chang_amazonprime_11.csv: 1
# mhrowlan-youtube-1x-vpn-mac-clean-20210108pp.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-6.csv: 2
# arv020_hulu_1080p_1x_vpn_mac_clean_20.csv: -1
# dagong-twitch-live-1122021-8.csv: 4
# arv020_amazonprime_1080p_1x_vpn_mac_clean_6.csv: 1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_41.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_3.csv: -1
# mhrowlan-disney-33.csv: -1
# chang_youtube_17.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-8.csv: 2
# maqader-youtube-live-1112021a-1.csv: 3
# arv020_amazonprime_1080p_1x_vpn_mac_clean_33.csv: 1
# zishun-youtube-live-26.csv: 3
# mhrowlan-youtube-1x-vpn-mac-clean-20210108nn.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-15.csv: 2
# dagong-twitch-live-1122021-6.csv: 4
# tiq004-twitch-live-011121-10.csv: 4
# arv020_amazonprime_1080p_1x_vpn_mac_clean_8.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-15.csv: 2
# zishun-youtube-live-5.csv: 3
# dagong-twitch-live-1122021-1.csv: 4
# tiq004-twitch-live-011121-17.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-12.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108dd.csv: 0
# arv020_amazonprime_1080p_1x_vpn_mac_clean_48.csv: 1
# zishun-youtube-live-2.csv: 3
# chang_youtube_9.csv: 0
# arv020_hulu_1080p_1x_vpn_mac_clean_4.csv: -1
# chang_youtube_10.csv: 0
# mhrowlan-disney-34.csv: -1
# chang_amazonprime_18.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-19.csv: -1
# mhrowlan-youtube-1x-vpn-mac-clean-20210108x.csv: 0
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-23.csv: 0
# dagong-twitch-live-1122021-16.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-14.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-2.csv: 2
# chang_youtube_15.csv: 0
# mhrowlan-disney-31.csv: -1
# arv020_hulu_1080p_1x_vpn_mac_clean_1.csv: -1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_31.csv: 1
# maqader-youtube-live-1112021a-3.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-17.csv: 2
# zishun-youtube-live-24.csv: 3
# tiq004-twitch-live-011121-12.csv: 4
# dagong-twitch-live-1122021-4.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-17.csv: 2
# zishun-youtube-live-7.csv: 3
# tiq004-twitch-live-011121-15.csv: 4
# dagong-twitch-live-1122021-3.csv: 4
# mhrowlan-youtube-1x-vpn-mac-clean-20210108ww.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-10.csv: 2
# zishun-youtube-live-0.csv: 3
# mhrowlan-netflix-1x-vpn-mac-clean-20210104a.csv: 2
# mhrowlan-disney-36.csv: -1
# chang_youtube_12.csv: 0
# arv020_hulu_1080p_1x_vpn_mac_clean_6.csv: -1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_36.csv: 1
# maqader-youtube-live-1112021a-4.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-10.csv: 2
# zishun-youtube-live-23.csv: 3
# arv020_amazonprime_1080p_1x_vpn_mac_clean_3.csv: 1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_44.csv: 1
# mhrowlan-youtube-1x-vpn-mac-clean-20210108ii.csv: 0
# chang_youtube_5.csv: 0
# apristin-youtube-live-20210119-0.csv: 3
# chang_amazonprime_14.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_8.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-3.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_38.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_25.csv: -1
# chang_amazonprime_13.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-4.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108cc.csv: 0
# arv020_hulu_1080p_1x_vpn_mac_clean_22.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-19.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-19.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_4.csv: 1
# zishun-youtube-live-9.csv: 3
# arv020_amazonprime_1080p_1x_vpn_mac_clean_43.csv: 1
# chang_youtube_2.csv: 0
# chang_amazonprime_26.csv: 1
# chang_amazonprime_8.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_17.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-3.csv: 2
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-0.csv: 0
# tiq004-twitch-live-011121-29.csv: 4
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-3.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-2.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-4.csv: 2
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-7.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-5.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-4.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-30.csv: 2
# chang_amazonprime_21.csv: 1
# zishun-youtube-live-18.csv: 3
# arv020_hulu_1080p_1x_vpn_mac_clean_10.csv: -1
# tiq004-twitch-live-011121-20.csv: 4
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-9.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-14.csv: 2
# maqader-twitch-live-1112021-7.csv: 4
# chang_amazonprime_1.csv: 1
# zishun-youtube-live-16.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-25.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210105.csv: 0
# chang_amazonprime_6.csv: 1
# chang_youtube_20.csv: 0
# chang_amazonprime_28.csv: 1
# zishun-youtube-live-11.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-22.csv: 2
# arv020_hulu_1080p_1x_vpn_mac_clean_19.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-22.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-13.csv: 2
# tiq004-twitch-live-011121-27.csv: 4
# maqader-twitch-live-1112021-0.csv: 4
# mhrowlan-disney-9.csv: -1
# maqader-youtube-live-1112021b-4.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210110-2.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_21.csv: 1
# dagong-youtube-live-1122021-3.csv: 3
# mhrowlan-disney-21.csv: -1
# tiq004-youtube-live-011321-11.csv: 3
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-18.csv: -1
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-22.csv: 0
# mhrowlan-youtube-1x-vpn-mac-clean-20210108y.csv: 0
# dagong-twitch-live-1122021-17.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-3.csv: 2
# tiq004-twitch-live-011121-7.csv: 4
# dagong-twitch-live-1122021-10.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-12.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-4.csv: 2
# maqader-youtube-live-1112021b-3.csv: 3
# maqader_youtube_live_1182021-3.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210110-5.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_26.csv: 1
# maqader-youtube-live-1112021-2.csv: 3
# dagong-youtube-live-1122021-4.csv: 3
# tiq004-youtube-live-011321-16.csv: 3
# mhrowlan-disney-26.csv: -1
# tiq004-twitch-live-011121-9.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-15.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-11.csv: -1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_54.csv: 1
# mhrowlan-youtube-1x-vpn-mac-clean-20210108p.csv: 0
# .ipynb_checkpoints: -1
# tiq004-youtube-live-011321-3.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210110-23.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_28.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_35.csv: -1
# dagong-youtube-live-1192021-2.csv: 3
# mhrowlan-disney-28.csv: -1
# tiq004-youtube-live-011321-18.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-4.csv: 2
# mhrowlan-disney-7.csv: -1
# tiq004-youtube-live-011321-4.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210110-24.csv: 2
# dagong-youtube-live-1192021-5.csv: 3
# arv020_hulu_1080p_1x_vpn_mac_clean_32.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-3.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-12.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-16.csv: -1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_53.csv: 1
# mhrowlan-youtube-1x-vpn-mac-clean-20210108w.csv: 0
# dagong-twitch-live-1122021-19.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210110-11.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108l.csv: 0
# dagong-youtube-live-1122021-13.csv: 3
# chang_amazonprime_36.csv: 1
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-19.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106-5.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108kk.csv: 0
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-23.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-27.csv: 2
# tiq004-twitch-live-011121-39.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106-2.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-24.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-20.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106-18.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108aa.csv: 0
# mhrowlan-youtube-1x-vpn-mac-clean-20210108k.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210110-16.csv: 2
# dagong-youtube-live-1122021-14.csv: 3
# chang_amazonprime_31.csv: 1
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-10.csv: 0
# tiq004-youtube-live-011821-1.csv: 3
# zishun_youtube_live_1182021_3.csv: 3
# tiq004-twitch-live-011121-30.csv: 4
# dagong-twitch-live-1122021-25.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106-16.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210105d.csv: 0
# arv020_amazonprime_1080p_1x_vpn_mac_clean_13.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210110-18.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108e.csv: 0
# mhrowlan-disney-13.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106-11.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_14.csv: 1
# mhrowlan-youtube-1x-vpn-mac-clean-20210105c.csv: 0
# mhrowlan-youtube-1x-vpn-mac-clean-20210108b.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-32.csv: 2
# chang_amazonprime_38.csv: 1
# mhrowlan-disney-14.csv: -1
# maqader-youtube-live-1122021-2.csv: 3
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-17.csv: 0
# zishun_youtube_live_1182021_4.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-29.csv: 2
# tiq004-twitch-live-011121-37.csv: 4
# mhrowlan-youtube-1x-vpn-mac-clean-20210108uu.csv: 0
# dagong-twitch-live-1122021-22.csv: 4
# chang_amazonprime_7.csv: 1
# chang_amazonprime_29.csv: 1
# zishun-youtube-live-10.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-23.csv: 2
# arv020_hulu_1080p_1x_vpn_mac_clean_18.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-23.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108tt.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-12.csv: 2
# tiq004-twitch-live-011121-26.csv: 4
# maqader-twitch-live-1112021-1.csv: 4
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-8.csv: 0
# tiq004-twitch-live-011121-21.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-15.csv: 2
# maqader-twitch-live-1112021-6.csv: 4
# zishun-youtube-live-17.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-24.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-5.csv: 2
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-6.csv: 0
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-4.csv: 2
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210108-31.csv: 2
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-5.csv: -1
# chang_amazonprime_20.csv: 1
# zishun-youtube-live-19.csv: 3
# arv020_hulu_1080p_1x_vpn_mac_clean_11.csv: -1
# chang_amazonprime_27.csv: 1
# chang_amazonprime_9.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_16.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-2.csv: 2
# tiq004-twitch-live-011121-28.csv: 4
# jeq004_youtube_1080p_1x_vpn_mac_clean_20210109-1.csv: 0
# jeq004_discovery_1080p_1x_vpn_mac_clean_20210125-2.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210105-3.csv: 2
# mhrowlan-youtube-1x-vpn-mac-clean-20210108jj.csv: 0
# chang_amazonprime_12.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-5.csv: 2
# arv020_hulu_1080p_1x_vpn_mac_clean_23.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-18.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_5.csv: 1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-18.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_42.csv: 1
# zishun-youtube-live-8.csv: 3
# chang_youtube_3.csv: 0
# arv020_amazonprime_1080p_1x_vpn_mac_clean_2.csv: 1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_45.csv: 1
# chang_youtube_4.csv: 0
# apristin-youtube-live-20210119-1.csv: 3
# chang_amazonprime_15.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_9.csv: -1
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-2.csv: 2
# arv020_amazonprime_1080p_1x_vpn_mac_clean_39.csv: 1
# arv020_hulu_1080p_1x_vpn_mac_clean_24.csv: -1
# tiq004-twitch-live-011121-14.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210107-20.csv: 2
# dagong-twitch-live-1122021-2.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-11.csv: 2
# zishun-youtube-live-1.csv: 3
# mhrowlan-disney-37.csv: -1
# chang_youtube_13.csv: 0
# arv020_hulu_1080p_1x_vpn_mac_clean_7.csv: -1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_37.csv: 1
# maqader-youtube-live-1112021a-5.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-11.csv: 2
# zishun-youtube-live-22.csv: 3
# chang_youtube_14.csv: 0
# mhrowlan-disney-30.csv: -1
# arv020_amazonprime_1080p_1x_vpn_mac_clean_30.csv: 1
# maqader-youtube-live-1112021a-2.csv: 3
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210104-16.csv: 2
# zishun-youtube-live-25.csv: 3
# tiq004-twitch-live-011121-13.csv: 4
# dagong-twitch-live-1122021-5.csv: 4
# jeq004_netflix_1080p_1x_vpn_mac_clean_20210106b-16.csv: 2
# zishun-youtube-live-6.csv: 3

# %%
def clean(df):
    """
    Attempts to filter out everything besides the traffic flow between the
    client and VPN service.

    The primary part of cleaning is merely getting rid of irrelevant flows.
    Since we are operating under the assumption that a VPN is in use, our
    clearning can *hopefully* isolate just the client<->VPN flow.

    At the moment, our approach is to remove any communications to link-local
    IPs, any multicast communications, and any communications between two
    private IPs.
    """

    ip1, ip2 = df.IP1.map(ipaddress.ip_address), df.IP2.map(ipaddress.ip_address)

    either_link_local = (
        (ip1.map(lambda x: x.is_link_local))
        | (ip2.map(lambda x: x.is_link_local))
    )

    either_multicast = (
        (ip1.map(lambda x: x.is_multicast))
        | (ip2.map(lambda x: x.is_multicast))
    )

    both_private = (
        (ip1.map(lambda x: x.is_private))
        & (ip2.map(lambda x: x.is_private))
    )

    return df[
        ~either_link_local
        & ~either_multicast
        & ~both_private
    ]

def unbin(df):
    """
    Takes in a DataFrame formatted as a network-stats output and 'unbins' the
    packet-level measurements so that each packet gets its own row.
    """
    
    packet_cols = ['packet_times', 'packet_sizes', 'packet_dirs']
    
    # Convert the strings `val1;val2;` into lists `[val1, val2]`
    df_listed = (
        df[packet_cols]
        .apply(lambda ser: ser.str.split(';').str[:-1])
    )
    
    # 'Explode' the lists so each element gets its own row.
    #
    # Exploding is considerably faster than summing lists and creating a new
    # frame.
    unbinned = (
        df_listed
        # Each list contains integer values, so we'll also cast them now.
        .apply(lambda ser: ser.explode(ignore_index=True).astype(int))
    )
    
    return unbinned

# %%
def process_file(df):
    """
    Filters out irrelevant traffic, then extracts packet-level data.
    """
    
    # print(f'Processing {filepath}')

    #df = pd.read_csv(filepath)
    
    # Filter out irrelevant traffic
    df = clean(df)

    # Extract packet-level data
    df = unbin(df)
    
    # Set the index to timedelta (should be monotonic increasing)
    df.columns = ['time', 'size', 'dir'] # NOTE: Renaming to match existing code
    df = df.sort_values('time')
    df['dt_time'] = pd.to_timedelta(df.time - df.time[0], PACKET_TIMESTAMP_UNIT)
    df = df.set_index('dt_time')

    # Finally, save the preprocessed file.
    #df.to_csv(pathlib.Path(out_dir, 'preprocessed-'+filepath.name))

    return df

# %%
n1_unpacked = process_file(n1)
p1_unpacked = process_file(p1)
y1_unpacked = process_file(y1)

# %%
plt.plot(n1['Time'], n1['2->1Bytes'])
plt.title('Netflix - Time Series of 2->1 Bytes');

# %%
plt.plot(p1['Time'], p1['2->1Bytes'])
plt.title('Amazon Prime - Time Series of 2->1 Bytes');

# %%
plt.plot(y1['Time'], y1['2->1Bytes'])
plt.title('Youtube - Time Series of 2->1 Bytes');

# %%
n1_rs = n1_unpacked.resample('500ms').sum()
f, Pxx_den = scipy.signal.welch(n1_rs['size'], fs=2)
plt.semilogy(f, np.sqrt(Pxx_den))
plt.title('Prevalence of frequencies in Packet Size over Time - Netflix');
plt.xlabel('Frequency (Hz)')
plt.ylabel('Bytes')
plt.yscale('linear')


peaks, _ = scipy.signal.find_peaks(np.sqrt(Pxx_den))

prominences = peak_prominences(np.sqrt(Pxx_den), peaks)[0]
netflix_max_prom = prominences.max()

# peaks, _ = scipy.signal.find_peaks(np.sqrt(Pxx_den), prominence = netflix_max_prom)
# plt.plot(np.sqrt(Pxx_den))
#plt.plot(peaks, np.sqrt(Pxx_den)[peaks], "x");
# plt.title('Netflix - Packet Size');

print("Netflix maximum prominence: ", netflix_max_prom)
# Out:
# Netflix maximum prominence:  503135.1866261307

# %%
y1_rs = y1_unpacked.resample('500ms').sum()
f, Pxx_den = scipy.signal.welch(y1_rs['size'], fs=2)
plt.semilogy(f, np.sqrt(Pxx_den)/1000000)
plt.title('Prevalence of frequencies in Packet Size over Time - Youtube');
plt.xlabel('Frequency (Hz)')
plt.ylabel('MB')
plt.yscale('linear')

peaks, _ = scipy.signal.find_peaks(np.sqrt(Pxx_den))

prominences = peak_prominences(np.sqrt(Pxx_den), peaks)[0]
youtube_max_prom = prominences.max()
print("Youtube maximum prominence: ", youtube_max_prom)
# Out:
# Youtube maximum prominence:  664966.8085190732

# %%
p1_rs = p1_unpacked.resample('500ms').sum()
f, Pxx_den = scipy.signal.welch(p1_rs['size'], fs=2)
plt.semilogy(f, np.sqrt(Pxx_den))
plt.title('Prevalence of frequencies in Packet Size over Time - Amazon Prime');
plt.xlabel('Frequency (Hz)')
plt.ylabel('Bytes')
plt.yscale('linear')

peaks, _ = scipy.signal.find_peaks(np.sqrt(Pxx_den))

prominences = peak_prominences(np.sqrt(Pxx_den), peaks)[0]
prime_max_prom = prominences.max()
print("Amazon Prime maximum prominence: ", prime_max_prom)
# Out:
# Amazon Prime maximum prominence:  774583.7861012355
