# %%
import requests
from bs4 import BeautifulSoup, Tag
import json
import pandas as pd

# %% [markdown]
# # scraping a route page

# %%
def get_route_data(route_url):
    text = requests.get(route_url).text
    soup = BeautifulSoup(text, 'html.parser')
    climb_type = soup.find('td', string='Type:').next_sibling.next_sibling.contents[0].strip()
    if 'Aid' in climb_type or 'Ice' in climb_type or 'Mixed' in climb_type:
        return None
    difficulty_section = soup.find('h2', {'class': 'inline-block mr-2'})
    if difficulty_section is None:
        difficulty_rating = 'NA'
        difficulty_rating_system = 'NA'
    else:
        if isinstance(difficulty_section.contents[0], str):
            difficulty_rating = difficulty_section.contents[0]
            difficulty_rating_system = 'NA'
        else:
            difficulty_rating = difficulty_section.contents[0].contents[0]
            difficulty_rating_system = difficulty_section.contents[0].contents[1].contents[0].contents[0]
    if difficulty_rating_system != 'YDS':
        return None
    
    data = json.loads("".join(soup.find("script", {"type":"application/ld+json"}).contents))
    
    description_section = soup.find_all('div', {'class': 'fr-view'})
    description = description_section[0].contents
    if len(description_section) == 3:
        protection = description_section[2].contents
    elif len(description_section) == 2:
        protection = description_section[1].contents
    else:
        protection = 'No protection data'
    
    data['climb_type'] = climb_type
    data['description'] = ''.join([x for x in description if isinstance(x, str)])
    data['protection'] = ''.join([x for x in protection if isinstance(x, str)])
    data['difficulty_rating'] = difficulty_rating
    data['difficulty_rating_system'] = difficulty_rating_system
    data['route_url'] = route_url
    return data

# %%
route = "https://www.mountainproject.com/route/109933221"
data = get_route_data(route)
data
# Out:
# {'@context': 'http://schema.org/',
#  '@type': 'LocalBusiness',
#  'name': 'Yosemite Slab',
#  'description': 'Huge, grand, stunning. Walk your way up the perfect slab.',
#  'image': 'https://cdn2.apstatic.com/photos/climb/113579015_medium_1505241287.jpg',
#  'geo': {'@type': 'GeoCoordinates',
#   'latitude': '37.50631842',
#   'longitude': '-88.68419115'},
#  'aggregateRating': {'@type': 'AggregateRating',
#   'ratingValue': '3.7',
#   'reviewCount': '95'},
#  'climb_type': 'Boulder, 40 ft (12 m)',
#  'protection': 'No. Kind of a do not fall situation.',
#  'difficulty_rating': 'V0 ',
#  'difficulty_rating_system': 'YDS',
#  'route_url': 'https://www.mountainproject.com/route/109933221'}

# %%
route = "https://www.mountainproject.com/route/105933562/"
print(route)
route = route.split("/")
print(route)
route.insert(4, "stats")
print(route)
route = "/".join(route)
print(route)
# Out:
# https://www.mountainproject.com/route/105933562/
# ['https:', '', 'www.mountainproject.com', 'route', '105933562', '']
# ['https:', '', 'www.mountainproject.com', 'route', 'stats', '105933562', '']
# https://www.mountainproject.com/route/stats/105933562/

# %%
route_stats_url = "https://www.mountainproject.com/route/stats/105933562/"

# %%
def get_route_ratings_data(route_url):
    text = requests.get(route_url).text
    soup = BeautifulSoup(text, 'html.parser')
    ratings_table = soup.find("table", attrs={"class": "table"})
    rows = ratings_table.find_all("tr")
    
    user_ratings = {}
    for row in rows:
        cols = row.find_all("td")
        user_url = cols[0].find("a").get("href")
        user_id = user_url.split("/")[4]
        stars = len(cols[1].find_all("img"))
        
        if(user_id in user_ratings.keys()):
            print(user_id, "appears multiple times")
        else:
            user_ratings[user_id] = stars
            
    return user_ratings

# %%
get_route_ratings_data(route_stats_url)
# Out:
# {'107518795': 4,
#  '107535054': 4,
#  '107537378': 4,
#  '106622079': 4,
#  '106329936': 4,
#  '106726952': 4,
#  '105865750': 4,
#  '107405626': 4,
#  '106381795': 4,
#  '107568281': 4,
#  '105789553': 4,
#  '10146': 4,
#  '10141': 4,
#  '14213': 4,
#  '107598776': 4,
#  '12988': 4,
#  '107468926': 4,
#  '105812440': 4,
#  '105857129': 4,
#  '11048': 4,
#  '106588555': 4,
#  '107659993': 4,
#  '107383190': 4,
#  '105818656': 4,
#  '107583733': 4,
#  '106958810': 4,
#  '106945872': 4,
#  '106209198': 4,
#  '106907209': 4,
#  '105805486': 4,
#  '105083583': 4,
#  '105802830': 4,
#  '11877': 4,
#  '105940930': 4,
#  '106262777': 4,
#  '105930639': 4,
#  '105904878': 4,
#  '106005105': 4,
#  '7002067': 4,
#  '105999112': 4,
#  '106020445': 4,
#  '107025542': 4,
#  '107075506': 4,
#  '106292269': 4,
#  '107738284': 4,
#  '12985': 4,
#  '10351': 4,
#  '106983776': 4,
#  '107588101': 4,
#  '106049619': 4,
#  '11181': 4,
#  '107352048': 4,
#  '106039240': 4,
#  '106055976': 4,
#  '105870586': 4,
#  '106088551': 4,
#  '105832216': 4,
#  '105846944': 4,
#  '106006184': 4,
#  '106365141': 4,
#  '10996': 4,
#  '106226653': 4,
#  '106088454': 4,
#  '106473856': 4,
#  '106017173': 4,
#  '11327': 4,
#  '107591659': 4,
#  '106420683': 4,
#  '106426167': 4,
#  '106398812': 4,
#  '106305548': 4,
#  '106455989': 4,
#  '105939248': 4,
#  '105973336': 4,
#  '13965': 4,
#  '106028022': 4,
#  '106000188': 4,
#  '105846604': 4,
#  '106544899': 4,
#  '106068243': 4,
#  '14568': 4,
#  '106073856': 4,
#  '106538248': 4,
#  '106831925': 4,
#  '14595': 4,
#  '106043058': 4,
#  '12690': 4,
#  '106552091': 4,
#  '106309395': 4,
#  '12527': 4,
#  '106415606': 4,
#  '106831774': 4,
#  '106887229': 4,
#  '106324178': 4,
#  '106933299': 4,
#  '106560803': 4,
#  '106789838': 4,
#  '106877680': 4,
#  '14152': 4,
#  '11167': 4,
#  '106732485': 4,
#  '106356571': 4,
#  '106420511': 4,
#  '106827872': 4,
#  '106068274': 4,
#  '106268558': 4,
#  '106487856': 4,
#  '106322173': 4,
#  '106548202': 4,
#  '107132993': 4,
#  '106730967': 4,
#  '106922742': 4,
#  '106846921': 4,
#  '107246852': 4,
#  '106491538': 4,
#  '106808417': 4,
#  '107298476': 4,
#  '107387693': 4,
#  '105947198': 4,
#  '106118724': 4,
#  '107456876': 4,
#  '107650191': 4,
#  '108195645': 4,
#  '107531774': 4,
#  '106168456': 4,
#  '106901183': 4,
#  '109591535': 3,
#  '107613776': 3,
#  '200070835': 3,
#  '110414401': 3,
#  '108323817': 3,
#  '200195003': 3,
#  '108977704': 3,
#  '106708022': 3,
#  '109495618': 3,
#  '106510314': 3,
#  '106210225': 3,
#  '105833503': 3,
#  '110839245': 3,
#  '13364': 3,
#  '108233563': 3,
#  '108401438': 3,
#  '111777299': 3,
#  '107643526': 3,
#  '200164909': 3,
#  '108171791': 3,
#  '106820629': 3,
#  '105084340': 3,
#  '108943993': 3,
#  '108094755': 3,
#  '112357776': 3,
#  '200039487': 3,
#  '200296165': 3,
#  '200141500': 3,
#  '200156094': 3,
#  '107166204': 3,
#  '200050086': 3,
#  '200234516': 3,
#  '109406011': 3,
#  '106662131': 3,
#  '106220386': 3,
#  '112003012': 3,
#  '200022637': 3,
#  '110944243': 3,
#  '111380201': 3,
#  '111901710': 3,
#  '108014034': 3,
#  '200338416': 3,
#  '200218071': 3,
#  '108270652': 3,
#  '111087341': 3,
#  '108093743': 3,
#  '109541388': 3,
#  '112507024': 3,
#  '112128100': 3,
#  '200431394': 3,
#  '112284281': 3,
#  '105934900': 3,
#  '106707988': 3,
#  '200017177': 3,
#  '110728916': 3,
#  '200253285': 3,
#  '111941074': 3,
#  '200694500': 3,
#  '200309935': 3,
#  '200222568': 3,
#  '200161344': 3,
#  '200876326': 3,
#  '112177374': 3,
#  '200526561': 3,
#  '108916902': 3,
#  '200378298': 3,
#  '106959007': 3,
#  '108348917': 3,
#  '109977730': 3,
#  '200491939': 3,
#  '111072569': 3,
#  '107159381': 3,
#  '15093': 2,
#  '106805249': 2,
#  '105855362': 2,
#  '105823132': 2,
#  '105878859': 2,
#  '106881716': 2,
#  '107065373': 2,
#  '106531595': 2,
#  '106714648': 2,
#  '106029651': 2,
#  '107525760': 2,
#  '106794436': 2,
#  '107205380': 2,
#  '108104464': 2,
#  '107302724': 2,
#  '106909519': 2,
#  '106712274': 2,
#  '107272204': 2,
#  '11331': 2,
#  '108220502': 2,
#  '107098879': 2,
#  '106420562': 2,
#  '110904912': 2,
#  '111214144': 2,
#  '109065359': 2,
#  '106158624': 2,
#  '105801073': 2,
#  '111540406': 2,
#  '107737637': 2,
#  '105974560': 2,
#  '109385742': 2,
#  '200088395': 2,
#  '14015': 2,
#  '107769068': 2,
#  '107092978': 2,
#  '112082839': 2,
#  '105826344': 2,
#  '200455940': 2,
#  '200366416': 2,
#  '200830855': 2,
#  '106052225': 1,
#  '110452706': 1,
#  '106949968': 1}

# %% [markdown]
# # scraping a user page

# %%
def get_user_history(user_url):
    output = pd.DataFrame(columns=['name', 'url', 'user_rating'])
    text = requests.get(user_url + '/ticks').text
    soup = BeautifulSoup(text, 'html.parser')
    num_pages = int(soup.find_all('a', {"class":"no-click"})[2].contents[0].strip()[-1])
    for i in range(num_pages):
        text = requests.get(user + '/ticks?page=' + str(i + 1)).text
        soup = BeautifulSoup(text, 'html.parser')
        all_links = soup.find_all('a')
        all_ratings = [] #this is the list of all star ratings on the current page
        for link in all_links:
            #this part is finding out the star ratings
            ratings_list = link.find_all('span', {"class":"scoreStars"})
            if len(ratings_list) > 0:
                rating = 0
                for element in ratings_list[0].contents:
                    if isinstance(element, Tag):
                        image = element['src']
                        if image == '/img/stars/starBlue.svg':
                            rating += 1
                        if image == '/img/stars/starBlueHalf.svg':
                            rating += 0.5
                all_ratings.append(rating)
            #this part is adding the data to the final output list
            if len(link.find_all('strong')) > 0 and len(link) < 2:
                #key is the name of the route, value is (route url, user's star rating for this route)
                output.loc[len(output.index)] = [link.find('strong').contents[0], link.get('href'), all_ratings.pop(0)]
    return output.to_dict()

# %%
user = 'https://www.mountainproject.com/user/10959/frances-fierst'
history = get_user_history(user)
history
# Out:
# {'name': {0: 'Sleepy Hallow',
#   1: 'Girls with Chim(n)ay',
#   2: 'Bushwhacker',
#   3: 'Route 66',
#   4: 'Good Dobby',
#   5: 'You Break It You Buy It',
#   6: "Kibbles 'n Bits",
#   7: 'Wherever I May Roam',
#   8: 'Unknown crack',
#   9: 'Fingers to hands',
#   10: 'Ringlock crack',
#   11: 'The Dihedral',
#   12: 'No name',
#   13: 'Round There',
#   14: 'Buffalo Power',
#   15: 'Thin Air',
#   16: 'Mossy Tits',
#   17: "Yoder's Bounce test",
#   18: 'The Safe Zone',
#   19: 'Purple Moon',
#   20: 'Phone Call From Satan',
#   21: 'Phone Call From Satan',
#   22: 'Moons of Pluto',
#   23: 'Screaming Yellow Zonkers',
#   24: 'Cosmos',
#   25: 'Orgasmophoria',
#   26: 'Phantasmagoria',
#   27: 'Dances with Clams',
#   28: 'Pop Art',
#   29: 'Dirty Pinkos',
#   30: 'Lets Face It',
#   31: 'Honey Pot',
#   32: "Chouinard's Crack (1st Half…",
#   33: 'Tuff It Out',
#   34: 'No Golf Shoes',
#   35: 'Snuffy Smith',
#   36: 'Leper Messiah',
#   37: 'Orion',
#   38: 'Bookworm',
#   39: 'Ancylostoma',
#   40: "Nightingale's on Vacation",
#   41: 'Irreverence',
#   42: 'Revelations',
#   43: 'Right on Joe',
#   44: 'Splitter Fingers',
#   45: 'Splitter Fingers',
#   46: 'Fingers through Bulges',
#   47: 'Dew, Chalk, and Blood',
#   48: "JT's Route",
#   49: "Drill 'Em and Fill 'Em",
#   50: 'Phoenix',
#   51: 'Hissing Llamas',
#   52: 'Cat Scan',
#   53: 'Light on the Path',
#   54: 'The Outsiders',
#   55: '5 Gallon Buckets',
#   56: 'Sunset Boulevard',
#   57: 'Kunza Korner',
#   58: 'Winter Sunset',
#   59: 'Sunset Slab',
#   60: 'Mantra',
#   61: 'Cruel Sister',
#   62: 'Delicatessen',
#   63: 'Dire Wolf',
#   64: 'Birds in a Rut',
#   65: 'Moonshine Dihedral',
#   66: 'Corner Shop',
#   67: 'Leap of Faith',
#   68: 'Vina Kulafu',
#   69: 'Long Live the Herm',
#   70: 'Selee',
#   71: 'King Cobra',
#   72: 'Cash Flow',
#   73: 'Route 9',
#   74: 'Route  14',
#   75: 'Route 8',
#   76: 'Soler',
#   77: 'Black Crack',
#   78: 'Le Gourmet Direct',
#   79: "Conn's West",
#   80: 'Stolen Chimney',
#   81: 'Direct Second Buttress',
#   82: "Reservoir Doggin'",
#   83: 'Lead Man',
#   84: 'Double Cross',
#   85: 'Casual Route',
#   86: 'Exum Ridge',
#   87: 'Loose Lady',
#   88: 'Levitation 29',
#   89: 'Spaceshot'},
#  'url': {0: 'https://www.mountainproject.com/route/106599007/sleepy-hallow',
#   1: 'https://www.mountainproject.com/route/111170331/girls-with-chimnay',
#   2: 'https://www.mountainproject.com/route/106599016/bushwhacker',
#   3: 'https://www.mountainproject.com/route/106517711/route-66',
#   4: 'https://www.mountainproject.com/route/108416293/good-dobby',
#   5: 'https://www.mountainproject.com/route/109619465/you-break-it-you-buy-it',
#   6: 'https://www.mountainproject.com/route/118229581/kibbles-n-bits',
#   7: 'https://www.mountainproject.com/route/105821077/wherever-i-may-roam',
#   8: 'https://www.mountainproject.com/route/119654556/unknown-crack',
#   9: 'https://www.mountainproject.com/route/114460429/fingers-to-hands',
#   10: 'https://www.mountainproject.com/route/114459436/ringlock-crack',
#   11: 'https://www.mountainproject.com/route/118989740/the-dihedral',
#   12: 'https://www.mountainproject.com/route/117068405/no-name',
#   13: 'https://www.mountainproject.com/route/106194074/round-there',
#   14: 'https://www.mountainproject.com/route/105802275/buffalo-power',
#   15: 'https://www.mountainproject.com/route/105802279/thin-air',
#   16: 'https://www.mountainproject.com/route/109576345/mossy-tits',
#   17: 'https://www.mountainproject.com/route/109575773/yoders-bounce-test',
#   18: 'https://www.mountainproject.com/route/109990368/the-safe-zone',
#   19: 'https://www.mountainproject.com/route/119200695/purple-moon',
#   20: 'https://www.mountainproject.com/route/105803921/phone-call-from-satan',
#   21: 'https://www.mountainproject.com/route/105803921/phone-call-from-satan',
#   22: 'https://www.mountainproject.com/route/105803003/moons-of-pluto',
#   23: 'https://www.mountainproject.com/route/105803440/screaming-yellow-zonkers',
#   24: 'https://www.mountainproject.com/route/105803446/cosmos',
#   25: 'https://www.mountainproject.com/route/105812149/orgasmophoria',
#   26: 'https://www.mountainproject.com/route/106807953/phantasmagoria',
#   27: 'https://www.mountainproject.com/route/105821110/dances-with-clams',
#   28: 'https://www.mountainproject.com/route/105821106/pop-art',
#   29: 'https://www.mountainproject.com/route/108347741/dirty-pinkos',
#   30: 'https://www.mountainproject.com/route/105821090/lets-face-it',
#   31: 'https://www.mountainproject.com/route/105814633/honey-pot',
#   32: 'https://www.mountainproject.com/route/106633246/chouinards-crack-1st-half-pitch-of-peking',
#   33: 'https://www.mountainproject.com/route/106070889/tuff-it-out',
#   34: 'https://www.mountainproject.com/route/106295092/no-golf-shoes',
#   35: 'https://www.mountainproject.com/route/105820358/snuffy-smith',
#   36: 'https://www.mountainproject.com/route/111244912/leper-messiah',
#   37: 'https://www.mountainproject.com/route/110643424/orion',
#   38: 'https://www.mountainproject.com/route/106154355/bookworm',
#   39: 'https://www.mountainproject.com/route/106193143/ancylostoma',
#   40: 'https://www.mountainproject.com/route/105820354/nightingales-on-vacation',
#   41: 'https://www.mountainproject.com/route/105820350/irreverence',
#   42: 'https://www.mountainproject.com/route/105804040/revelations',
#   43: 'https://www.mountainproject.com/route/111649827/right-on-joe',
#   44: 'https://www.mountainproject.com/route/111649809/splitter-fingers',
#   45: 'https://www.mountainproject.com/route/111649809/splitter-fingers',
#   46: 'https://www.mountainproject.com/route/111649772/fingers-through-bulges',
#   47: 'https://www.mountainproject.com/route/111649755/dew-chalk-and-blood',
#   48: 'https://www.mountainproject.com/route/105812559/jts-route',
#   49: 'https://www.mountainproject.com/route/105812551/drill-em-and-fill-em',
#   50: 'https://www.mountainproject.com/route/105790327/phoenix',
#   51: 'https://www.mountainproject.com/route/105822353/hissing-llamas',
#   52: 'https://www.mountainproject.com/route/105937358/cat-scan',
#   53: 'https://www.mountainproject.com/route/105789064/light-on-the-path',
#   54: 'https://www.mountainproject.com/route/105820726/the-outsiders',
#   55: 'https://www.mountainproject.com/route/105789060/5-gallon-buckets',
#   56: 'https://www.mountainproject.com/route/111930553/sunset-boulevard',
#   57: 'https://www.mountainproject.com/route/105806885/kunza-korner',
#   58: 'https://www.mountainproject.com/route/116193127/winter-sunset',
#   59: 'https://www.mountainproject.com/route/105820884/sunset-slab',
#   60: 'https://www.mountainproject.com/route/105899231/mantra',
#   61: 'https://www.mountainproject.com/route/105791785/cruel-sister',
#   62: 'https://www.mountainproject.com/route/108750316/delicatessen',
#   63: 'https://www.mountainproject.com/route/108750306/dire-wolf',
#   64: 'https://www.mountainproject.com/route/107341167/birds-in-a-rut',
#   65: 'https://www.mountainproject.com/route/105790283/moonshine-dihedral',
#   66: 'https://www.mountainproject.com/route/111603897/corner-shop',
#   67: 'https://www.mountainproject.com/route/111629871/leap-of-faith',
#   68: 'https://www.mountainproject.com/route/107694546/vina-kulafu',
#   69: 'https://www.mountainproject.com/route/105897933/long-live-the-herm',
#   70: 'https://www.mountainproject.com/route/106257692/selee',
#   71: 'https://www.mountainproject.com/route/105899219/king-cobra',
#   72: 'https://www.mountainproject.com/route/105897928/cash-flow',
#   73: 'https://www.mountainproject.com/route/107172763/route-9',
#   74: 'https://www.mountainproject.com/route/107031555/route-14',
#   75: 'https://www.mountainproject.com/route/107172755/route-8',
#   76: 'https://www.mountainproject.com/route/106061731/soler',
#   77: 'https://www.mountainproject.com/route/106777915/black-crack',
#   78: 'https://www.mountainproject.com/route/105917520/le-gourmet-direct',
#   79: 'https://www.mountainproject.com/route/105977724/conns-west',
#   80: 'https://www.mountainproject.com/route/105717310/stolen-chimney',
#   81: 'https://www.mountainproject.com/route/105761817/direct-second-buttress',
#   82: 'https://www.mountainproject.com/route/107052748/reservoir-doggin',
#   83: 'https://www.mountainproject.com/route/107052753/lead-man',
#   84: 'https://www.mountainproject.com/route/105721615/double-cross',
#   85: 'https://www.mountainproject.com/route/105748496/casual-route',
#   86: 'https://www.mountainproject.com/route/105933562/exum-ridge',
#   87: 'https://www.mountainproject.com/route/105722050/loose-lady',
#   88: 'https://www.mountainproject.com/route/105732443/levitation-29',
#   89: 'https://www.mountainproject.com/route/105717829/spaceshot'},
#  'user_rating': {0: 2.5,
#   1: 3.5,
#   2: 3.0,
#   3: 2.5,
#   4: 2.5,
#   5: 2.5,
#   6: 2.0,
#   7: 3.5,
#   8: 2.0,
#   9: 2.5,
#   10: 3.0,
#   11: 2.0,
#   12: 3.0,
#   13: 2.5,
#   14: 3.0,
#   15: 3.5,
#   16: 2.5,
#   17: 2.5,
#   18: 1.5,
#   19: 1.5,
#   20: 3.0,
#   21: 3.0,
#   22: 4.0,
#   23: 3.5,
#   24: 2.5,
#   25: 3.5,
#   26: 3.5,
#   27: 2.5,
#   28: 2.0,
#   29: 3.5,
#   30: 3.0,
#   31: 2.5,
#   32: 3.5,
#   33: 2.5,
#   34: 2.5,
#   35: 2.5,
#   36: 3.0,
#   37: 2.5,
#   38: 2.5,
#   39: 2.0,
#   40: 2.5,
#   41: 2.5,
#   42: 2.5,
#   43: 3.0,
#   44: 2.5,
#   45: 2.5,
#   46: 3.0,
#   47: 3.0,
#   48: 3.0,
#   49: 2.0,
#   50: 3.0,
#   51: 2.5,
#   52: 3.5,
#   53: 3.0,
#   54: 3.0,
#   55: 3.0,
#   56: 2.0,
#   57: 3.5,
#   58: 2.5,
#   59: 3.0,
#   60: 3.0,
#   61: 3.5,
#   62: 2.0,
#   63: 2.0,
#   64: 3.0,
#   65: 3.5,
#   66: 4.0,
#   67: 2.0,
#   68: 4.0,
#   69: 2.0,
#   70: 1.5,
#   71: 2.0,
#   72: 2.0,
#   73: 3.0,
#   74: 3.0,
#   75: 3.0,
#   76: 3.5,
#   77: 3.5,
#   78: 2.0,
#   79: 3.0,
#   80: 3.5,
#   81: 3.0,
#   82: 2.0,
#   83: 2.0,
#   84: 3.5,
#   85: 4.0,
#   86: 3.5,
#   87: 3.0,
#   88: 3.5,
#   89: 3.5}}

# %% [markdown]
# # scraping data from an entire state

# %%
def find_all_routes_in_state(state_url):
    def add_links(soup):
        div = soup.find('div', {'class': 'max-height max-height-md-0 max-height-xs-400'})
        if div:
            a_hrefs = div.find_all('a')
            for link in a_hrefs:
                links.append(link.get('href'))
    text = requests.get(state_url).text
    soup = BeautifulSoup(text, 'html.parser')
    links = []
    route_links = []
    add_links(soup)
    while len(links) > 0:
        link = links[0]
        if '/area/' in link:
            text = requests.get(link).text
            new_soup = BeautifulSoup(text, 'html.parser')
            add_links(new_soup)
        else:
            if link != '#':
                route_links.append(link)
        links.remove(link)
    return route_links

# %%
state = 'https://www.mountainproject.com/area/105877031/mount-rainier'
all_routes = find_all_routes_in_state(state)
all_routes
# Out:
# ['https://www.mountainproject.com/route/119283293/bread-loaf',
#  'https://www.mountainproject.com/route/106703081/central-mowich-face',
#  'https://www.mountainproject.com/route/110037673/curtis-ridge',
#  'https://www.mountainproject.com/route/105982534/emmons-glacier',
#  'https://www.mountainproject.com/route/106636996/fuhrer-finger',
#  'https://www.mountainproject.com/route/107671307/fuhrer-thumb',
#  'https://www.mountainproject.com/route/107467946/gibraltar-ledges',
#  'https://www.mountainproject.com/route/106812783/ingraham-glacier-direct',
#  'https://www.mountainproject.com/route/105877100/ingraham-glacier-disappointment-cleaver-route',
#  'https://www.mountainproject.com/route/105906991/kautz-glacier',
#  'https://www.mountainproject.com/route/106459197/liberty-ridge',
#  'https://www.mountainproject.com/route/111999837/north-mowich-headwall',
#  'https://www.mountainproject.com/route/106846325/ptarmigan-ridge',
#  'https://www.mountainproject.com/route/112479245/sunset-ridge',
#  'https://www.mountainproject.com/route/113173040/upper-castle-toprope-wall',
#  'https://www.mountainproject.com/route/106475331/willis-wall',
#  'https://www.mountainproject.com/route/114097472/wilson-headwall']

# %%
len(all_routes)
# Out:
# 17

# %%
all_data = []
for route in all_routes:
    route_data = get_route_data(route)
    if route_data:
        all_data.append(get_route_data(route))

# %%
len(all_data)
# Out:
# 2

# %%
all_data
# Out:
# [{'@context': 'http://schema.org/',
#   '@type': 'LocalBusiness',
#   'name': 'Bread Loaf',
#   'description': '',
#   'image': 'https://cdn2.apstatic.com/photos/climb/119283325_medium_1595814614.jpg',
#   'geo': {'@type': 'GeoCoordinates',
#    'latitude': '46.85290262',
#    'longitude': '-121.76047432'},
#   'aggregateRating': {'@type': 'AggregateRating',
#    'ratingValue': '2.0',
#    'reviewCount': '1'},
#   'climb_type': 'Boulder, Alpine, 8 ft (2 m)',
#   'protection': 'Crash pads, Spotters',
#   'difficulty_rating': 'V0 ',
#   'difficulty_rating_system': 'YDS',
#   'route_url': 'https://www.mountainproject.com/route/119283293/bread-loaf'},
#  {'@context': 'http://schema.org/',
#   '@type': 'LocalBusiness',
#   'name': 'Upper Castle Toprope Wall',
#   'description': "There is a 40ft crag about 1-200' elevation above the Castle, just below the Turtle Snowfield on the approach to the Kautz Ice Chute. The rock quality is actually decent. This offers a great pastime at high camp. The Castle camp is at 9,200' and the Upper Castle is just under 9,400'.    The routes range from 5.6 (SE Prow) to much harder (S Face).",
#   'image': 'https://cdn2.apstatic.com/photos/climb/113173062_medium_1497764020.jpg',
#   'geo': {'@type': 'GeoCoordinates',
#    'latitude': '46.85290262',
#    'longitude': '-121.76047432'},
#   'aggregateRating': {'@type': 'AggregateRating',
#    'ratingValue': '0.5',
#    'reviewCount': '2'},
#   'climb_type': 'TR, Alpine, 40 ft (12 m)',
#   'protection': 'Toprope - there are some large boulders on top of the cliff, as well as a lot of loose blocks and flakes - so be careful.',
#   'difficulty_rating': '5.6 ',
#   'difficulty_rating_system': 'YDS',
#   'route_url': 'https://www.mountainproject.com/route/113173040/upper-castle-toprope-wall'}]

# %%
with open('yosemite_national_park_all_data.json', 'w') as f:
    json.dump(all_data, f)
