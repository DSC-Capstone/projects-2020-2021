# %%
import os
# move to project root
os.chdir('/home/rcgonzal/DSC180Malware/m2v-adversarial-hindroid/')

import pandas as pd
import numpy as np

from src.model.model import M2VDroid
from src.model.hindroid import Hindroid
from src.data.hindroid_etl import make_models
from src.analysis.analysis import create_performance_table
from src.utils import find_apps
from src.attack.attack import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Purpose
# This notebook should guide a user with some detail in how to use this package. Note: all paths should be relative to the project directory unless of course the root indicator is present i.e. `/`.
#
# # Data Selection
# We assume you should have access to Android apps already decompiled into their Smali representations. If you have not done this, please look into how to use Apktool and Smali to decompile Android APKs (We may provide a script in the future). What we do provide is the `find_app` function which, given a directory, will recursively look for decompiled apps and return a DataFrame with their locations. This is how the `app_list.csv` file begins.

# %%
find_apps('test/testdata/')
# Out:
#                          app_dir
# app
# testapp1  test/testdata/testapp1
# testapp2  test/testdata/testapp2

# %% [markdown]
# In some cases like the file `data/out/all-apps/app_list.csv`, we add more columns to this table such as what category an app is from and whether is it malware or not in order for us to label our examples.

# %%
all_apps = pd.read_csv('data/out/all-apps/app_list.csv', dtype=str, index_col='app')
all_apps
# Out:
#                                                                                      app_dir  \
# app
# com.kaktus.hyungkaktus                     /teams/DSC180A_FA20_A00/a04malware/random-apps...
# com.wedup.duduamzaleg                      /teams/DSC180A_FA20_A00/a04malware/random-apps...
# com.dublin_mobile123.cheat_gta_5           /teams/DSC180A_FA20_A00/a04malware/random-apps...
# com.appall.optimizationbox                 /teams/DSC180A_FA20_A00/a04malware/random-apps...
# live.wallpaper.t910001560                  /teams/DSC180A_FA20_A00/a04malware/random-apps...
# ...                                                                                      ...
# iseed.parumo1                              /teams/DSC180A_FA20_A00/a04malware/personal-gr...
# com.dailyblah.rajanikaparthy.talkingtimer  /teams/DSC180A_FA20_A00/a04malware/personal-gr...
# com.cakrabuana.lagunaffpopuler             /teams/DSC180A_FA20_A00/a04malware/personal-gr...
# com.odev.talkingtom                        /teams/DSC180A_FA20_A00/a04malware/personal-gr...
# com.golf.journey.classicsolitaire          /teams/DSC180A_FA20_A00/a04malware/personal-gr...
#
#                                               category malware
# app
# com.kaktus.hyungkaktus                     random-apps       0
# com.wedup.duduamzaleg                      random-apps       0
# com.dublin_mobile123.cheat_gta_5           random-apps       0
# com.appall.optimizationbox                 random-apps       0
# live.wallpaper.t910001560                  random-apps       0
# ...                                                ...     ...
# iseed.parumo1                              random-apps       0
# com.dailyblah.rajanikaparthy.talkingtimer  random-apps       0
# com.cakrabuana.lagunaffpopuler             random-apps       0
# com.odev.talkingtom                        random-apps       0
# com.golf.journey.classicsolitaire          random-apps       0
#
# [6421 rows x 3 columns]

# %%
all_apps.category.value_counts()
# Out:
# malware         5516
# random-apps      581
# popular-apps     324
# Name: category, dtype: int64

# %% [markdown]
# **Aside:** `all-apps` is a special folder in our out project because it houses all apps -- and their API data in `app-data`! When parsed in our ETL, each app is extracted into its own `.csv` containing every API call made within it, making it easy to pick and choose which apps we want to select just by knowing their names (or md5s for malware).
#
# With that said, let's return to selecting our data. We want to split our data into stratified halves, both with equal amounts of benign apps and malware. We also have a category `random-apps` which we will keep.

# %%
# all_apps = all_apps[all_apps.category != 'random-apps'] # no longer needed, we will be considering random apps
training_sample = (
    all_apps.groupby('malware')
    .apply(lambda x: x.sample(frac=1/3, random_state=42)) # perform stratified sample
    .drop(columns='malware').reset_index().drop(columns='malware').set_index('app') # reset the index
)
training_sample
# Out:
#                                                                                 app_dir  \
# app
# droom.sleepIfUCan                     /teams/DSC180A_FA20_A00/a04malware/popular-app...
# com.prowebce003423CECEAPROSO.android  /teams/DSC180A_FA20_A00/a04malware/random-apps...
# com.nurinmaru.farm0032                /teams/DSC180A_FA20_A00/a04malware/random-apps...
# com.hulu.plus                         /teams/DSC180A_FA20_A00/a04malware/popular-app...
# com.triovent.reciepeapp               /teams/DSC180A_FA20_A00/a04malware/random-apps...
# ...                                                                                 ...
# 868e4c839030f28c22998f8a0147f44d      /teams/DSC180A_FA20_A00/a04malware/malware/You...
# cfa8c24967ee5c269b83cfc7e50c6352      /teams/DSC180A_FA20_A00/a04malware/malware/You...
# 5de94bc0c4cc183c0ee5a48a7ae5ae43      /teams/DSC180A_FA20_A00/a04malware/malware/RuM...
# 51daa9651d546de844280eaf722c3e67      /teams/DSC180A_FA20_A00/a04malware/malware/Fak...
# 363614b438b3d73de0080401b1734444      /teams/DSC180A_FA20_A00/a04malware/malware/Dro...
#
#                                           category
# app
# droom.sleepIfUCan                     popular-apps
# com.prowebce003423CECEAPROSO.android   random-apps
# com.nurinmaru.farm0032                 random-apps
# com.hulu.plus                         popular-apps
# com.triovent.reciepeapp                random-apps
# ...                                            ...
# 868e4c839030f28c22998f8a0147f44d           malware
# cfa8c24967ee5c269b83cfc7e50c6352           malware
# 5de94bc0c4cc183c0ee5a48a7ae5ae43           malware
# 51daa9651d546de844280eaf722c3e67           malware
# 363614b438b3d73de0080401b1734444           malware
#
# [2024 rows x 2 columns]

# %%
testing_sample = all_apps[['app_dir', 'category']].loc[all_apps.index.difference(training_sample.index)]
testing_sample
# Out:
#                                                                             app_dir  \
# app
# 00268453be254779f0c7590de47db944  /teams/DSC180A_FA20_A00/a04malware/malware/Dro...
# 002a7270ec52ec68ea3d979c85261308  /teams/DSC180A_FA20_A00/a04malware/malware/Ban...
# 0030e0003b7226e9142683e49b41a423  /teams/DSC180A_FA20_A00/a04malware/malware/Fak...
# 00335946abb79777f9fe2d0d96651e03  /teams/DSC180A_FA20_A00/a04malware/malware/Vid...
# 0038be31cfed95e13a33d87142eada70  /teams/DSC180A_FA20_A00/a04malware/malware/Fak...
# ...                                                                             ...
# sts.al                            /teams/DSC180A_FA20_A00/a04malware/popular-app...
# taha.islam.renewal                /teams/DSC180A_FA20_A00/a04malware/random-apps...
# toolbox.m.incoming.stop           /teams/DSC180A_FA20_A00/a04malware/random-apps...
# ua.com.citysites.belorechensk     /teams/DSC180A_FA20_A00/a04malware/random-apps...
# vpn.free                          /teams/DSC180A_FA20_A00/a04malware/random-apps...
#
#                                       category
# app
# 00268453be254779f0c7590de47db944       malware
# 002a7270ec52ec68ea3d979c85261308       malware
# 0030e0003b7226e9142683e49b41a423       malware
# 00335946abb79777f9fe2d0d96651e03       malware
# 0038be31cfed95e13a33d87142eada70       malware
# ...                                        ...
# sts.al                            popular-apps
# taha.islam.renewal                 random-apps
# toolbox.m.incoming.stop            random-apps
# ua.com.citysites.belorechensk      random-apps
# vpn.free                           random-apps
#
# [4048 rows x 2 columns]

# %%
# create two separate directories for each sample and save both to their respective directory
os.makedirs('data/out/train-set', exist_ok=True)
os.makedirs('data/out/test-set', exist_ok=True)
training_sample.to_csv('data/out/train-set/app_list.csv')
testing_sample.to_csv('data/out/test-set/app_list.csv')

# %% [markdown]
# Now we must train a model on the training set. To do that we must run the ETL pipeline on that directory. Therefore we set `config/etl-params/etl-params.json` as shown below and then execute `python run.py data`. *This may take a few hours run especially the random walks!*
#
# ```json
# {
#     "outfolder": "data/out/train-half",
#     "parse_params": {
#         "nprocs": 16
#     },
#     "feature_params": {
#         "redo": false,
#         "walk_args": {
#             "nprocs": 16,
#             "length": 60,
#             "n": 3,
#             "metapaths": [
#                 ["app", "api", "app"],
#                 ["app", "api", "method", "api", "app"],
#                 ["app", "api", "package", "api", "app"],
#                 ["app", "api", "package", "api", "method", "api", "app"],
#                 ["app", "api", "method", "api", "package", "api", "app"]
#             ]
#         },
#         "w2v_args": {
#             "size": 128,
#             "window": 7,
#             "min_count": 0,
#             "negative": 5,
#             "sg": 1,
#             "workers": 16,
#             "iter": 5
#         }
#     },
#     "hindroid_params": {
#         "redo": false
#     }
# }
# ```

# %%
# %time !python run.py data
# Out:
# 2021-03-02 21:16:01.889695: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:16:01.889761: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-03-02 21:16:03.620259: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:16:03.620431: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-02 21:16:03.657845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:8a:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2021-03-02 21:16:03.658053: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:16:03.658166: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:16:03.658301: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:16:03.658364: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-02 21:16:03.658412: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-02 21:16:03.658473: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-02 21:16:03.658568: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:16:03.658601: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-03-02 21:16:03.658616: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-03-02 21:16:03.662513: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:16:03.662552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-02 21:16:03.662564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# STEP 1 - PARSING APPS
# 100%|███████████████████████████████████████| 2024/2024 [06:45<00:00,  4.99it/s]
# 2021-03-02 21:22:54.535948: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:54.535948: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:54.536012: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-03-02 21:22:54.536060: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-03-02 21:22:54.536227: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:54.536275: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-03-02 21:22:54.570527: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:54.570581: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-03-02 21:22:57.999809: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:57.999813: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:57.999949: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:57.999984: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-02 21:22:58.000008: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-02 21:22:58.000082: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:58.000143: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-02 21:22:58.000307: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-02 21:22:58.157711: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:8a:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2021-03-02 21:22:58.158044: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.158209: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.158349: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.158431: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-02 21:22:58.158493: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-02 21:22:58.158554: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-02 21:22:58.158677: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.158719: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-03-02 21:22:58.158737: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-03-02 21:22:58.160092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:8a:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2021-03-02 21:22:58.160306: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.160441: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.160574: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.160645: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-02 21:22:58.160700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-02 21:22:58.160784: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-02 21:22:58.160910: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.160946: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-03-02 21:22:58.160963: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-03-02 21:22:58.163246: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:58.163298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-02 21:22:58.163328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# 2021-03-02 21:22:58.164970: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:58.165009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-02 21:22:58.165022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# 2021-03-02 21:22:58.165261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:8a:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2021-03-02 21:22:58.165605: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.165810: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.165856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:8a:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2021-03-02 21:22:58.166021: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.166135: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-02 21:22:58.166188: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.166222: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-02 21:22:58.166303: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-02 21:22:58.166369: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.166477: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.166534: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-03-02 21:22:58.166544: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.166561: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-03-02 21:22:58.166644: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-02 21:22:58.166721: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-02 21:22:58.166794: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-02 21:22:58.166962: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-03-02 21:22:58.167012: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-03-02 21:22:58.167042: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-03-02 21:22:58.170421: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:58.170481: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-02 21:22:58.170504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# 2021-03-02 21:22:58.170678: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 21:22:58.170731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-02 21:22:58.170747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# Dask Cluster: LocalCluster('tcp://127.0.0.1:34509', workers=4, threads=8, memory=68.72 GB)
# Dashboard port: 8787
# Indexing apis
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 0)"
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 100)"
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 1)"
# distributed.core - ERROR - Exception while handling op heartbeat_worker
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 1028)"
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f8d44738d30>>, <Task finished name='Task-45' coro=<Worker.heartbeat() done, defined at /opt/conda/lib/python3.8/site-packages/distributed/worker.py:925> exception=KeyError("('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 1028)")>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 931, in heartbeat
#     response = await retry_operation(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 384, in retry_operation
#     return await retry(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 369, in retry
#     return await coro()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 852, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 651, in send_recv
#     raise exc.with_traceback(tb)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 1028)"
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f33968b3d90>>, <Task finished name='Task-36' coro=<Worker.heartbeat() done, defined at /opt/conda/lib/python3.8/site-packages/distributed/worker.py:925> exception=KeyError("('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 0)")>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 931, in heartbeat
#     response = await retry_operation(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 384, in retry_operation
#     return await retry(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 369, in retry
#     return await coro()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 852, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 651, in send_recv
#     raise exc.with_traceback(tb)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 0)"
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7ff93dcabb50>>, <Task finished name='Task-38' coro=<Worker.heartbeat() done, defined at /opt/conda/lib/python3.8/site-packages/distributed/worker.py:925> exception=KeyError("('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 1)")>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 931, in heartbeat
#     response = await retry_operation(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 384, in retry_operation
#     return await retry(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 369, in retry
#     return await coro()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 852, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 651, in send_recv
#     raise exc.with_traceback(tb)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 1)"
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fab1832dca0>>, <Task finished name='Task-34' coro=<Worker.heartbeat() done, defined at /opt/conda/lib/python3.8/site-packages/distributed/worker.py:925> exception=KeyError("('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 100)")>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 931, in heartbeat
#     response = await retry_operation(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 384, in retry_operation
#     return await retry(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 369, in retry
#     return await coro()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 852, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 651, in send_recv
#     raise exc.with_traceback(tb)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 487, in handle_comm
#     result = handler(comm, **msg)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2195, in heartbeat_worker
#     ws._executing = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/scheduler.py", line 2196, in <dictcomp>
#     self.tasks[key]: duration for key, duration in executing.items()
# KeyError: "('read-csv-d67618d38970bcc6dbfcdd8743c58ee1', 100)"
# ^C
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45678
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 187, in read
#     n_frames = await stream.read_bytes(8)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 2033, in gather_dep
#     response = await get_data_from_worker(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 3270, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 384, in retry_operation
#     return await retry(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 369, in retry
#     return await coro()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 3250, in _get_data
#     response = await send_recv(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 635, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 202, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7ff93dcabb50>>, <Task finished name='Task-1683' coro=<Worker.gather_dep() done, defined at /opt/conda/lib/python3.8/site-packages/distributed/worker.py:2001> exception=CommClosedError()>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/nanny.py", line 789, in _run
#     loop.run_sync(run)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/iostream.py", line 726, in _handle_events
#     self.io_loop.update_handler(self.fileno(), self._state)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 164, in update_handler
#     self.selector_loop.remove_reader(fd)
#   File "/opt/conda/lib/python3.8/asyncio/selector_events.py", line 339, in remove_reader
#     return self._remove_reader(fd)
#   File "/opt/conda/lib/python3.8/asyncio/selector_events.py", line 283, in _remove_reader
#     self._selector.unregister(fd)
#   File "/opt/conda/lib/python3.8/selectors.py", line 368, in unregister
#     self._selector.unregister(key.fd)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 2129, in gather_dep
#     self.batched_stream.send(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError
# distributed.comm.core.CommClosedError
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45051
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 187, in read
#     n_frames = await stream.read_bytes(8)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 2033, in gather_dep
#     response = await get_data_from_worker(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 3270, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 384, in retry_operation
#     return await retry(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 369, in retry
#     return await coro()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 3250, in _get_data
#     response = await send_recv(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 635, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 202, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45678
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 187, in read
#     n_frames = await stream.read_bytes(8)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 2033, in gather_dep
#     response = await get_data_from_worker(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 3270, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 384, in retry_operation
#     return await retry(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/utils_comm.py", line 369, in retry
#     return await coro()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 3250, in _get_data
#     response = await send_recv(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 635, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 202, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f33968b3d90>>, <Task finished name='Task-1585' coro=<Worker.gather_dep() done, defined at /opt/conda/lib/python3.8/site-packages/distributed/worker.py:2001> exception=CommClosedError()>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_common.py", line 447, in wrapper
#     ret = self._cache[fun]
# KeyError: <function Process._parse_stat_file at 0x7f339f0d45e0>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/nanny.py", line 789, in _run
#     loop.run_sync(run)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/system_monitor.py", line 46, in update
#     cpu = self.proc.cpu_percent()
#   File "/opt/conda/lib/python3.8/site-packages/psutil/__init__.py", line 995, in cpu_percent
#     pt2 = self._proc.cpu_times()
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1576, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1769, in cpu_times
#     values = self._parse_stat_file()
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1576, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_common.py", line 454, in wrapper
#     ret = self._cache[fun] = fun(self)
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1619, in _parse_stat_file
#     data = f.read()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 2129, in gather_dep
#     self.batched_stream.send(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError
# distributed.comm.core.CommClosedError
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f33968b3d90>>, <Task finished name='Task-1568' coro=<Worker.gather_dep() done, defined at /opt/conda/lib/python3.8/site-packages/distributed/worker.py:2001> exception=CommClosedError()>)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_common.py", line 447, in wrapper
#     ret = self._cache[fun]
# KeyError: <function Process._parse_stat_file at 0x7f339f0d45e0>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/nanny.py", line 789, in _run
#     loop.run_sync(run)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/system_monitor.py", line 46, in update
#     cpu = self.proc.cpu_percent()
#   File "/opt/conda/lib/python3.8/site-packages/psutil/__init__.py", line 995, in cpu_percent
#     pt2 = self._proc.cpu_times()
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1576, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1769, in cpu_times
#     values = self._parse_stat_file()
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1576, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_common.py", line 454, in wrapper
#     ret = self._cache[fun] = fun(self)
#   File "/opt/conda/lib/python3.8/site-packages/psutil/_pslinux.py", line 1619, in _parse_stat_file
#     data = f.read()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 2129, in gather_dep
#     self.batched_stream.send(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError
# distributed.comm.core.CommClosedError
# distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:45678 -> tcp://127.0.0.1:38932
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/nanny.py", line 789, in _run
#     loop.run_sync(run)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 1348, in get_data
#     compressed = await comm.write(msg, serializers=serializers)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 230, in write
#     frames = await to_frames(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/utils.py", line 52, in to_frames
#     return _to_frames()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/utils.py", line 32, in _to_frames
#     protocol.dumps(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/core.py", line 50, in dumps
#     data = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/core.py", line 51, in <dictcomp>
#     key: serialize(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/serialize.py", line 297, in serialize
#     header, frames = dumps(x, context=context) if wants_context else dumps(x)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/serialize.py", line 60, in pickle_dumps
#     frames[0] = pickle.dumps(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/pickle.py", line 49, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexes/range.py", line 170, in __reduce__
#     def __reduce__(self):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 187, in read
#     n_frames = await stream.read_bytes(8)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 1349, in get_data
#     response = await comm.read(deserializers=serializers)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 202, in read
#     convert_stream_closed_error(self, e)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/process.py", line 192, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/nanny.py", line 796, in _run
#     loop.run_sync(do_stop)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 476, in _handle_stream
#     await self.comm_handler(comm)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/core.py", line 491, in handle_comm
#     result = await result
#   File "/opt/conda/lib/python3.8/site-packages/distributed/nanny.py", line 789, in _run
#     loop.run_sync(run)
#   File "/opt/conda/lib/python3.8/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/opt/conda/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/opt/conda/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/opt/conda/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/worker.py", line 1348, in get_data
#     compressed = await comm.write(msg, serializers=serializers)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/tcp.py", line 230, in write
#     frames = await to_frames(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/utils.py", line 52, in to_frames
#     return _to_frames()
#   File "/opt/conda/lib/python3.8/site-packages/distributed/comm/utils.py", line 32, in _to_frames
#     protocol.dumps(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/core.py", line 50, in dumps
#     data = {
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/core.py", line 51, in <dictcomp>
#     key: serialize(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/serialize.py", line 297, in serialize
#     header, frames = dumps(x, context=context) if wants_context else dumps(x)
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/serialize.py", line 60, in pickle_dumps
#     frames[0] = pickle.dumps(
#   File "/opt/conda/lib/python3.8/site-packages/distributed/protocol/pickle.py", line 49, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
#   File "/opt/conda/lib/python3.8/site-packages/pandas/core/indexes/range.py", line 170, in __reduce__
#     def __reduce__(self):
# KeyboardInterrupt
# CPU times: user 8.32 s, sys: 2.71 s, total: 11 s
# Wall time: 8min 2s

# %%
# %time make_models('data/out/train-half/')
# Out:
# Fitting models:
#   0%|          | 0/31 [00:00<?, ?it/s]
# 	Fitting AAT model...
# 100%|██████████| 31/31 [00:29<00:00,  1.06it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# 	Fitting ABAT model...
# 100%|██████████| 31/31 [14:33<00:00, 28.17s/it]
#   0%|          | 0/31 [00:00<?, ?it/s]
# 	Fitting APAT model...
# 100%|██████████| 31/31 [01:10<00:00,  2.28s/it]
#   0%|          | 0/31 [00:00<?, ?it/s]
# 	Fitting ABPBTAT model...
# 100%|██████████| 31/31 [2:28:04<00:00, 286.59s/it]
#   0%|          | 0/31 [00:00<?, ?it/s]
# 	Fitting APBPTAT model...
# 100%|██████████| 31/31 [1:39:07<00:00, 191.84s/it]
#               acc    recall        f1
# kernel
# AAT      1.000000  1.000000  1.000000
# ABAT     0.991107  0.996737  0.995113
# APAT     1.000000  1.000000  1.000000
# ABPBTAT  1.000000  1.000000  1.000000
# APBPTAT  0.974638  0.989848  0.986094
# CPU times: user 4h 9min 28s, sys: 14min 44s, total: 4h 24min 13s
# Wall time: 4h 24min 11s

# %% [markdown]
# From here, we can create the models we will use. Note that we included `"hindroid_params"` in the config file. Therefore we also fitted a Hindroid model on the data. We will also describe how to utilize that class though both models are largely the same.

# %%
m2vDroid = M2VDroid('data/out/train-set/',
                    classifier_args={'max_depth':4, 'n_jobs':-1})
m2vDroid.name
# Out:
# 'train-set'

# %%
# also saves output table to a folder
m2vDroid.fit_predict('data/out/test-set/')
# Out:
# Computing new edges
# <stellargraph.core.graph.StellarGraph object at 0x7f3f87a43c40>
# Running random walk
# Running Word2Vec
# Fitting model
#               precision    recall  f1-score   support
#
#            0       0.99      0.46      0.62       371
#            1       0.95      1.00      0.97      3677
#
#     accuracy                           0.95      4048
#    macro avg       0.97      0.73      0.80      4048
# weighted avg       0.95      0.95      0.94      4048
#                                          0         1         2         3  \
# app
# 00268453be254779f0c7590de47db944 -0.449032 -1.202108  0.185910 -0.418299
# 002a7270ec52ec68ea3d979c85261308 -0.084931  0.368828  0.375811  0.661619
# 0030e0003b7226e9142683e49b41a423 -0.306066 -0.173652  0.162710  0.335997
# 00335946abb79777f9fe2d0d96651e03 -0.009991 -0.058666  0.460960  0.193677
# 0038be31cfed95e13a33d87142eada70 -0.630949 -0.440778  0.604206  0.669105
# ...                                    ...       ...       ...       ...
# sts.al                            0.506667  1.068946  0.662136 -0.435601
# taha.islam.renewal               -0.285983  0.002031  0.210271  0.330722
# toolbox.m.incoming.stop          -0.390785 -0.060382  0.877227  0.972244
# ua.com.citysites.belorechensk    -0.773604  0.247088 -0.386567  0.765891
# vpn.free                         -1.015142  0.440412  0.483036  1.190783
#
#                                          4         5         6         7  \
# app
# 00268453be254779f0c7590de47db944  0.197234 -0.032786  0.613179  0.312402
# 002a7270ec52ec68ea3d979c85261308 -0.839094 -0.181433 -0.071430 -0.349385
# 0030e0003b7226e9142683e49b41a423 -0.595538  0.178637  0.320537 -0.079408
# 00335946abb79777f9fe2d0d96651e03 -0.463901  0.467588 -0.112754 -0.119379
# 0038be31cfed95e13a33d87142eada70 -0.655404  0.723882  0.139422  0.250296
# ...                                    ...       ...       ...       ...
# sts.al                           -0.772628 -0.640351 -1.167849 -0.179379
# taha.islam.renewal               -0.141879  1.251570 -0.249743  0.435072
# toolbox.m.incoming.stop          -0.525150  0.317062 -0.876197 -0.210319
# ua.com.citysites.belorechensk    -0.562402  1.008386 -0.576490 -0.002315
# vpn.free                          0.618171  0.957494  0.610174 -0.240884
#
#                                          8         9  ...       120       121  \
# app                                                   ...
# 00268453be254779f0c7590de47db944  1.422977 -0.223549  ... -0.557727 -1.199390
# 002a7270ec52ec68ea3d979c85261308 -0.236794  0.133636  ... -0.484232 -0.394212
# 0030e0003b7226e9142683e49b41a423  0.039939 -0.155147  ... -0.180247 -0.208453
# 00335946abb79777f9fe2d0d96651e03 -0.077636  0.003909  ... -0.157391 -0.424092
# 0038be31cfed95e13a33d87142eada70 -0.206485 -0.573729  ...  0.289600 -0.139725
# ...                                    ...       ...  ...       ...       ...
# sts.al                            0.524084  0.052810  ... -0.067021 -0.169583
# taha.islam.renewal                0.036629  0.001042  ...  0.424430 -0.120964
# toolbox.m.incoming.stop           0.520908  0.025187  ... -1.273346 -0.143025
# ua.com.citysites.belorechensk     0.222517  0.223049  ...  0.236988 -0.269480
# vpn.free                         -0.281113 -0.958523  ... -0.705449 -1.744379
#
#                                        122       123       124       125  \
# app
# 00268453be254779f0c7590de47db944  0.237443 -1.451841  1.073622 -0.574838
# 002a7270ec52ec68ea3d979c85261308  0.019846 -0.543612 -0.315674 -0.232581
# 0030e0003b7226e9142683e49b41a423  0.366364 -0.232035 -0.093705 -0.380263
# 00335946abb79777f9fe2d0d96651e03  0.012341 -0.152814 -0.294870 -0.233297
# 0038be31cfed95e13a33d87142eada70  0.364534 -0.245115 -0.176167 -0.298281
# ...                                    ...       ...       ...       ...
# sts.al                           -0.728771 -0.780243 -0.442614  0.367091
# taha.islam.renewal                0.638874  0.292902 -0.041647 -0.279142
# toolbox.m.incoming.stop          -0.133812  0.456153  0.085507  0.146431
# ua.com.citysites.belorechensk    -1.312227  0.154840  0.035490 -1.143552
# vpn.free                         -0.999087 -1.062734 -1.704995  0.286218
#
#                                        126       127  m2vDroid  true
# app
# 00268453be254779f0c7590de47db944  0.175047 -0.162512         1     1
# 002a7270ec52ec68ea3d979c85261308  0.661621  0.060567         1     1
# 0030e0003b7226e9142683e49b41a423  0.103787 -0.079222         1     1
# 00335946abb79777f9fe2d0d96651e03  0.047864  0.281478         1     1
# 0038be31cfed95e13a33d87142eada70 -0.064914  0.179287         1     1
# ...                                    ...       ...       ...   ...
# sts.al                            0.368531  0.507996         0     0
# taha.islam.renewal               -0.014098 -0.191005         1     0
# toolbox.m.incoming.stop           0.255563 -1.298162         0     0
# ua.com.citysites.belorechensk     0.955441  0.136958         1     0
# vpn.free                         -0.323155  0.607571         1     0
#
# [4048 rows x 130 columns]

# %%
hindroid = Hindroid('data/out/train-set/')
# %time hindroid.fit_predict('data/out/test-set/')
# hindroid.fit_predict('data/out/test-sample/')
# Out:
# Computing unique APIs per app
# Building A-test matrix: 100%|██████████| 4048/4048 [01:11<00:00, 56.36it/s]
# Making predictions
# Predicting AAT, batch:   0%|          | 0/41 [00:00<?, ?it/s]
# Predicting AAT, batch: 100%|██████████| 41/41 [00:28<00:00,  1.44it/s]
# Predicting ABAT, batch:   0%|          | 0/41 [00:00<?, ?it/s]
# Predicting ABAT, batch: 100%|██████████| 41/41 [14:42<00:00, 21.53s/it]
# Predicting APAT, batch:   0%|          | 0/41 [00:00<?, ?it/s]
# Predicting APAT, batch: 100%|██████████| 41/41 [01:37<00:00,  2.38s/it]
# Predicting ABPBTAT, batch:   0%|          | 0/41 [00:00<?, ?it/s]
# Predicting ABPBTAT, batch: 100%|██████████| 41/41 [2:36:06<00:00, 228.45s/it]
# Predicting APBPTAT, batch:   0%|          | 0/41 [00:00<?, ?it/s]
# Predicting APBPTAT, batch: 100%|██████████| 41/41 [1:25:06<00:00, 124.55s/it]
# AAT:
#               precision    recall  f1-score   support
#
#            0       0.99      0.85      0.92       371
#            1       0.99      1.00      0.99      3677
#
#     accuracy                           0.99      4048
#    macro avg       0.99      0.93      0.95      4048
# weighted avg       0.99      0.99      0.99      4048
#
# ABAT:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87       371
#            1       0.98      0.99      0.99      3677
#
#     accuracy                           0.98      4048
#    macro avg       0.94      0.91      0.93      4048
# weighted avg       0.98      0.98      0.98      4048
#
# APAT:
#               precision    recall  f1-score   support
#
#            0       0.98      0.79      0.88       371
#            1       0.98      1.00      0.99      3677
#
#     accuracy                           0.98      4048
#    macro avg       0.98      0.90      0.93      4048
# weighted avg       0.98      0.98      0.98      4048
#
# ABPBTAT:
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92       371
#            1       0.99      1.00      0.99      3677
#
#     accuracy                           0.99      4048
#    macro avg       0.99      0.93      0.96      4048
# weighted avg       0.99      0.99      0.99      4048
#
# APBPTAT:
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86       371
#            1       0.98      0.99      0.99      3677
#
#     accuracy                           0.98      4048
#    macro avg       0.95      0.90      0.92      4048
# weighted avg       0.98      0.98      0.98      4048
#
# CPU times: user 4h 10min 18s, sys: 19min 5s, total: 4h 29min 24s
# Wall time: 4h 24min 22s
#                                   AAT  ABAT  APAT  ABPBTAT  APBPTAT  true
# app
# 00268453be254779f0c7590de47db944    1     1     1        1        1     1
# 002a7270ec52ec68ea3d979c85261308    1     1     1        1        1     1
# 0030e0003b7226e9142683e49b41a423    1     1     1        1        1     1
# 00335946abb79777f9fe2d0d96651e03    1     1     1        1        1     1
# 0038be31cfed95e13a33d87142eada70    1     1     1        1        1     1
# ...                               ...   ...   ...      ...      ...   ...
# sts.al                              0     0     0        0        0     0
# taha.islam.renewal                  0     1     1        1        1     0
# toolbox.m.incoming.stop             0     0     0        0        0     0
# ua.com.citysites.belorechensk       1     1     1        1        1     0
# vpn.free                            0     0     0        0        0     0
#
# [4048 rows x 6 columns]

# %% [markdown]
# Now that the code has finished running, let us view the results.

# %%
hindroid = Hindroid('data/out/train-set/')
# %time hindroid.fit_predict('data/out/all-apps/')
# hindroid.fit_predict('data/out/test-sample/')
# Out:
# Computing unique APIs per app
# Building A-test matrix: 100%|██████████| 6421/6421 [03:13<00:00, 33.24it/s]
# Making predictions
# Predicting AAT, batch:   0%|          | 0/65 [00:00<?, ?it/s]
# Predicting AAT, batch: 100%|██████████| 65/65 [00:48<00:00,  1.33it/s]
# Predicting ABAT, batch:   0%|          | 0/65 [00:00<?, ?it/s]
# Predicting ABAT, batch: 100%|██████████| 65/65 [20:23<00:00, 18.82s/it]
# Predicting APAT, batch:   0%|          | 0/65 [00:00<?, ?it/s]
# Predicting APAT, batch: 100%|██████████| 65/65 [02:07<00:00,  1.96s/it]
# Predicting ABPBTAT, batch:   0%|          | 0/65 [00:00<?, ?it/s]
# Predicting ABPBTAT, batch: 100%|██████████| 65/65 [3:28:29<00:00, 192.45s/it]
# Predicting APBPTAT, batch:   0%|          | 0/65 [00:00<?, ?it/s]
# Predicting APBPTAT, batch: 100%|██████████| 65/65 [2:34:52<00:00, 142.96s/it]
# AAT:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91       905
#            1       0.97      1.00      0.99      5516
#
#     accuracy                           0.98      6421
#    macro avg       0.99      0.92      0.95      6421
# weighted avg       0.98      0.98      0.98      6421
#
# ABAT:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86       905
#            1       0.97      0.99      0.98      5516
#
#     accuracy                           0.96      6421
#    macro avg       0.95      0.90      0.92      6421
# weighted avg       0.96      0.96      0.96      6421
#
# APAT:
#               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90       905
#            1       0.97      1.00      0.98      5516
#
#     accuracy                           0.97      6421
#    macro avg       0.98      0.91      0.94      6421
# weighted avg       0.97      0.97      0.97      6421
#
# ABPBTAT:
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93       905
#            1       0.98      1.00      0.99      5516
#
#     accuracy                           0.98      6421
#    macro avg       0.99      0.93      0.96      6421
# weighted avg       0.98      0.98      0.98      6421
#
# APBPTAT:
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85       905
#            1       0.97      0.99      0.98      5516
#
#     accuracy                           0.96      6421
#    macro avg       0.95      0.89      0.92      6421
# weighted avg       0.96      0.96      0.96      6421
#
# CPU times: user 6h 25min 6s, sys: 23min 28s, total: 6h 48min 35s
# Wall time: 6h 38min 55s
#                                            AAT  ABAT  APAT  ABPBTAT  APBPTAT  \
# app
# com.kaktus.hyungkaktus                       0     0     0        0        0
# com.wedup.duduamzaleg                        0     0     0        0        0
# com.dublin_mobile123.cheat_gta_5             0     0     0        0        0
# com.appall.optimizationbox                   1     0     1        1        1
# live.wallpaper.t910001560                    0     1     1        0        1
# ...                                        ...   ...   ...      ...      ...
# iseed.parumo1                                1     1     1        1        1
# com.dailyblah.rajanikaparthy.talkingtimer    0     0     0        0        0
# com.cakrabuana.lagunaffpopuler               0     0     0        0        0
# com.odev.talkingtom                          0     0     0        0        0
# com.golf.journey.classicsolitaire            0     0     0        0        0
#
#                                            true
# app
# com.kaktus.hyungkaktus                        0
# com.wedup.duduamzaleg                         0
# com.dublin_mobile123.cheat_gta_5              0
# com.appall.optimizationbox                    0
# live.wallpaper.t910001560                     0
# ...                                         ...
# iseed.parumo1                                 0
# com.dailyblah.rajanikaparthy.talkingtimer     0
# com.cakrabuana.lagunaffpopuler                0
# com.odev.talkingtom                           0
# com.golf.journey.classicsolitaire             0
#
# [6421 rows x 6 columns]

# %%
create_performance_table('data/out/test-set/m2v-train-set/predictions.csv', 
                         'data/out/test-set/hindroid-train-set/predictions.csv', 
                         'reports/assets/baseline_performance_chart.csv')
# Out:
# m2vDroid    int64
# AAT         int64
# ABAT        int64
# APAT        int64
# ABPBTAT     int64
# APBPTAT     int64
# true        int64
# dtype: object
#                ACC       TPR        F1    TP   TN   FP  FN
# m2vDroid  0.949852  0.999728  0.973130  3676  169  202   1
# AAT       0.985672  0.999184  0.992169  3674  316   55   3
# ABAT      0.976285  0.990481  0.986992  3642  310   61  35
# APAT      0.979249  0.998096  0.988685  3670  294   77   7
# ABPBTAT   0.986166  0.998640  0.992432  3672  320   51   5
# APBPTAT   0.975791  0.991841  0.986742  3647  303   68  30
